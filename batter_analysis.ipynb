# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
sns.set()

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %%
batting_records = pd.read_csv('batting_records.csv')

# %%
batting_records.head()
# Out:
#           name country       span  matches  innings  not_out  runs  \
# 0    RG Sharma   INDIA  2007-2022      125      117       15  3313
# 1   MJ Guptill      NZ  2009-2021      112      108        7  3299
# 2      V Kohli   INDIA  2010-2022       97       89       25  3296
# 3  PR Stirling     IRE  2009-2022      102      101        8  2776
# 4     AJ Finch     AUS  2011-2022       89       89       10  2741
#
#   highest_score average  balls_faced  strike_rate  100s  50s  duck   4s   6s
# 0           118   32.48         2374       139.55     4   26     7  293  155
# 1           105   32.66         2413       136.71     2   20     3  287  165
# 2           94*   51.50         2394       137.67     0   30     3  298   92
# 3          115*   29.84         2061       134.69     1   20     9  319   96
# 4           172   34.69         1892       144.87     2   16     7  273  113

# %%
batting_records.tail()
# Out:
#                  name country       span  matches  innings  not_out  runs  \
# 1995        L Sipamla      SA  2019-2021        9        2        1     8
# 1996        BV Vitori     ZIM  2012-2016       11        2        2     8
# 1997     Yasar Idrees     KUW  2019-2019        1        1        0     8
# 1998        Yasir Ali     BAN  2022-2022        1        1        0     8
# 1999  Al-Amin Hossain     BAN  2013-2020       31        6        4     7
#
#      highest_score average  balls_faced  strike_rate  100s  50s  duck  4s  6s
# 1995            8*    8.00           11        72.72     0    0     1   1   0
# 1996            7*       -            7       114.28     0    0     0   0   0
# 1997             8    8.00            4       200.00     0    0     0   0   1
# 1998             8    8.00            7       114.28     0    0     0   1   0
# 1999            5*    3.50           12        58.33     0    0     1   1   0

# %%
batting_records.describe()
# Out:
#            matches      innings      not_out         runs  balls_faced  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.00000
# mean     15.570000    11.909500     2.483000   200.152000    168.61950
# std      17.601733    15.033573     3.496974   361.160788    277.25944
# min       1.000000     1.000000     0.000000     7.000000      3.00000
# 25%       5.000000     4.000000     0.000000    26.000000     30.00000
# 50%       9.000000     7.000000     1.000000    72.000000     72.00000
# 75%      19.000000    14.000000     3.000000   197.000000    175.25000
# max     125.000000   117.000000    42.000000  3313.000000   2413.00000
#
#        strike_rate         100s          50s         duck           4s  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    106.713170     0.041500     0.823000     1.047000    17.074000
# std      33.053929     0.244556     2.300069     1.468969    33.305212
# min      25.000000     0.000000     0.000000     0.000000     0.000000
# 25%      84.610000     0.000000     0.000000     0.000000     2.000000
# 50%     106.660000     0.000000     0.000000     1.000000     5.000000
# 75%     126.400000     0.000000     1.000000     2.000000    17.000000
# max     300.000000     4.000000    30.000000    12.000000   319.000000
#
#                 6s
# count  2000.000000
# mean      6.983000
# std      14.560828
# min       0.000000
# 25%       0.000000
# 50%       2.000000
# 75%       6.000000
# max     165.000000

# %%
batting_records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           2000 non-null   object
#  1   country        1982 non-null   object
#  2   span           2000 non-null   object
#  3   matches        2000 non-null   int64
#  4   innings        2000 non-null   int64
#  5   not_out        2000 non-null   int64
#  6   runs           2000 non-null   int64
#  7   highest_score  2000 non-null   object
#  8   average        2000 non-null   object
#  9   balls_faced    2000 non-null   int64
#  10  strike_rate    2000 non-null   float64
#  11  100s           2000 non-null   int64
#  12  50s            2000 non-null   int64
#  13  duck           2000 non-null   int64
#  14  4s             2000 non-null   int64
#  15  6s             2000 non-null   int64
# dtypes: float64(1), int64(10), object(5)
# memory usage: 250.1+ KB

# %%
batting_records.duplicated().sum()
# Out:
# 0

# %%
batting_records.isnull().sum()
# Out:
# name              0
# country          18
# span              0
# matches           0
# innings           0
# not_out           0
# runs              0
# highest_score     0
# average           0
# balls_faced       0
# strike_rate       0
# 100s              0
# 50s               0
# duck              0
# 4s                0
# 6s                0
# dtype: int64

# %%
batting_records[batting_records.country.isnull()]
# Out:
#                  name country       span  matches  innings  not_out  runs  \
# 627     Muhammad Amin     NaN  2021-2021        6        6        0   150
# 774          C Forbes     NaN  2021-2021        6        6        0   110
# 901       J Ghadiyali     NaN  2021-2021        6        6        1    86
# 984        Naeem Gull     NaN  2021-2021        6        6        0    74
# 1048    Shehzad Patel     NaN  2021-2021        6        6        2    65
# 1100  Muhammad Saleem     NaN  2019-2019        4        4        0    59
# 1160        G Caisley     NaN  2019-2019        4        4        0    52
# 1243     Yasar Haroon     NaN  2019-2019        4        4        0    45
# 1247      Ismat Ullah     NaN  2019-2019        4        4        0    44
# 1362       M Magagula     NaN  2021-2021        6        4        0    35
# 1416        JJ Wright     NaN  2021-2021        5        5        1    32
# 1708     JR Singleton     NaN  2019-2019        3        3        0    17
# 1720       KK Bishnoi     NaN  2019-2019        3        2        1    16
# 1727     LF Goncalves     NaN  2019-2019        3        2        0    16
# 1864      Umair Qasim     NaN  2021-2021        6        5        0    12
# 1900          R Avery     NaN  2019-2019        4        3        0    10
# 1906        J Hansrod     NaN  2021-2021        4        3        0    10
# 1949      VRCF Poubel     NaN  2019-2019        3        3        2     9
#
#      highest_score average  balls_faced  strike_rate  100s  50s  duck  4s  6s
# 627             80   25.00          113       132.74     0    2     1  19   5
# 774             31   18.33          103       106.79     0    0     0  18   1
# 901            27*   17.20           96        89.58     0    0     2   8   1
# 984             20   12.33          104        71.15     0    0     0  10   0
# 1048           30*   16.25           54       120.37     0    0     0   4   4
# 1100            52   14.75           54       109.25     0    1     0   5   1
# 1160            38   13.00           59        88.13     0    0     1   3   2
# 1243            29   11.25           62        72.58     0    0     0   4   1
# 1247            42   11.00           47        93.61     0    0     1   4   1
# 1362            13    8.75           56        62.50     0    0     0   3   1
# 1416           19*    8.00           33        96.96     0    0     2   1   1
# 1708             7    5.66           26        65.38     0    0     0   3   0
# 1720            14   16.00           18        88.88     0    0     0   1   0
# 1727            13    8.00           21        76.19     0    0     0   1   0
# 1864             7    2.40           21        57.14     0    0     1   1   0
# 1900             9    3.33           24        41.66     0    0     1   0   0
# 1906             7    3.33           25        40.00     0    0     0   1   0
# 1949            5*    9.00           15        60.00     0    0     0   0   0

# %%
batting_records.dropna(axis=0,inplace=True)

# %%
batting_records.average.unique()
# Out:
# array(['32.48', '32.66', '51.50', '29.84', '34.69', '45.52', '32.74',
#        '26.46', '28.58', '31.21', '34.51', '35.66', '32.59', '30.07',
#        '23.83', '30.96', '21.21', '38.68', '26.15', '22.44', '27.92',
#        '28.19', '40.68', '33.83', '31.89', '24.08', '31.34', '31.96',
#        '26.00', '26.12', '25.96', '50.36', '31.01', '37.60', '29.29',
#        '23.60', '10.72', '7.37', '13.11', '29.50', '10.63', '38.66',
#        '11.60', '14.37', '19.16', '28.50', '10.27', '22.60', '14.12',
#        '13.87', '11.10', '12.33', '15.71', '15.57', '12.11', '36.00',
#        '21.60', '13.12', '11.55', '20.80', '8.66', '12.87', '20.40',
#        '25.50', '10.10', '20.20', '11.22', '16.83', '50.50', '11.11',
#        '19.80', '14.14', '24.50', '98.00', '10.77', '13.85', '9.50',
#        '15.83', '10.55', '31.33', '10.44', '15.66', '7.83', '23.25',
#        '15.33', '13.14', '18.40', '7.58', '22.75', '18.20', '30.33',
#        '8.27', '22.50', '11.25', '18.00', '10.00', '45.00', '17.80',
#        '29.66', '8.00', '14.66', '9.77', '17.60', '12.42', '43.50',
#        '8.70', '8.60', '17.20', '43.00', '10.75', '12.28', '7.08',
#        '14.16', '10.62', '42.50', '12.14', '16.80', '84.00', '9.33',
#        '27.66', '41.50', '9.22', '10.37', '7.45', '13.66', '82.00',
#        '10.25', '27.33', '16.20', '8.88', '13.16', '26.33', '15.60',
#        '7.60', '12.66', '10.85', '15.20', '25.33', '75.00', '6.81',
#        '9.37', '7.50', '24.66', '9.25', '12.16', '8.11', '36.50', '24.33',
#        '10.42', '10.28', '6.45', '8.75', '17.25', '9.85', '5.23', '7.55',
#        '68.00', '9.71', '13.60', '11.16', '7.33', '13.20', '9.28',
#        '10.83', '16.25', '21.33', '12.80', '10.66', '9.14', '7.11',
#        '7.87', '10.50', '9.00', '7.00', '-', '7.62', '8.57', '11.80',
#        '6.55', '3.93', '9.83', '58.00', '7.25', '11.40', '14.25', '57.00',
#        '7.85', '10.80', '6.00', '7.71', '54.00', '53.00', '10.60',
#        '17.33', '10.40', '7.42', '8.50', '10.20', '12.75', '8.33',
#        '50.00', '12.25', '49.00', '48.00', '6.85', '11.75', '6.71',
#        '9.40', '47.00', '9.20', '5.75', '7.66', '8.80', '4.40', '7.16',
#        '14.33', '5.37', '8.40', '4.10', '8.20', '6.83', '5.71', '9.75',
#        '38.00', '7.40', '11.66', '11.33', '4.85', '5.66', '6.80', '8.25',
#        '6.60', '6.40', '4.57', '5.16', '4.42', '7.75', '5.00', '9.66',
#        '5.80', '4.00', '5.60', '4.66', '6.75', '5.40', '3.85', '4.33',
#        '4.16', '6.25', '3.42', '4.60', '5.25', '4.20', '3.50', '6.66',
#        '4.75', '6.33', '3.80', '4.50', '3.60', '4.25', '2.42', '3.40',
#        '5.33', '3.20', '3.75', '3.00', '2.33', '6.50', '2.16', '3.25',
#        '2.40', '3.66', '2.75', '5.50', '3.33', '2.50', '2.25', '2.66',
#        '2.00', '1.60'], dtype=object)

# %%
batting_records.loc[batting_records.innings == batting_records.not_out].count()
# Out:
# name             54
# country          54
# span             54
# matches          54
# innings          54
# not_out          54
# runs             54
# highest_score    54
# average          54
# balls_faced      54
# strike_rate      54
# 100s             54
# 50s              54
# duck             54
# 4s               54
# 6s               54
# dtype: int64

# %%
batting_records[(batting_records.runs < 400) & (batting_records.country == 'INDIA')]
# Out:
  balls_faced  strike_rate  100s  50s  duck  4s  6s
# 1074           33*       -           58       106.89     0    0     0   5   1
# 1088           38*       -           31       193.54     0    0     0   4   5
# 1142           31*       -           52       105.76     0    0     0   2   3
# 1283           28*       -           33       124.24     0    0     0   4   0
# 1301           31*       -           26       153.84     0    0     0   4   1
# 1309           32*       -           41        95.12     0    0     0   5   1
# 1420           17*       -           23       134.78     0    0     0   2   1
# 1429           31*       -           22       140.90     0    0     0   2   1
# 1446           14*       -           22       136.36     0    0     0   1   2
# 1458           21*       -           20       145.00     0    0     0   1   1
# 1486           11*       -           16       168.75     0    0     0   3   1
# 1498           13*       -           27       100.00     0    0     0   2   1
# 1539           24*       -           15       160.00     0    0     0   4   0
# 1551           15*       -           16       143.75     0    0     0   1   1
# 1572           21*       -            9       244.44     0    0     0   2   1
# 1586           21*       -           28        75.00     0    0     0   2   0
# 1589           12*       -           18       116.66     0    0     0   0   2
# 1616           20*       -           19       105.26     0    0     0   0   0
# 1650           19*       -           15       126.66     0    0     0   1   1
# 1662           11*       -           14       128.57     0    0     0   3   0
# 1666           18*       -            9       200.00     0    0     0   0   1
# 1677           13*       -           25        72.00     0    0     0   2   0
# 1689           17*       -            9       188.88     0    0     0   0   2
# 1694           10*       -           18        94.44     0    0     0   1   0
# 1699           17*       -           15       113.33     0    0     0   1   1
# 1704           14*       -           18        94.44     0    0     0   1   0
# 1745           15*       -            6       250.00     0    0     0   1   1
# 1759           11*       -           26        57.69     0    0     0   0   0
# 1789            8*       -           19        73.68     0    0     0   1   0
# 1803           13*       -           13       107.69     0    0     0   2   0
# 1806            7*       -           27        51.85     0    0     0   0   0
# 1821           13*       -            6       216.66     0    0     0   2   0
# 1824           11*       -           24        54.16     0    0     0   0   0
# 1827           13*       -            6       216.66     0    0     0   1   1
# 1841           12*       -            8       150.00     0    0     0   0   1
# 1853           12*       -            7       171.42     0    0     0   2   0
# 1860           11*       -           11       109.09     0    0     0   2   0
# 1878           11*       -           15        73.33     0    0     0   0   1
# 1884            6*       -           12        91.66     0    0     0   0   0
# 1898            5*       -           13        84.61     0    0     0   1   0
# 1899           11*       -            7       157.14     0    0     0   1   0
# 1903            7*       -           13        76.92     0    0     0   0   0
# 1910           10*       -            8       125.00     0    0     0   0   0
# 1914           10*       -            6       166.66     0    0     0   0   1
# 1918            8*       -            6       166.66     0    0     0   0   1
# 1944            5*       -            3       300.00     0    0     0   2   0
# 1945            9*       -            5       180.00     0    0     0   0   0
# 1954            9*       -            7       128.57     0    0     0   1   0
# 1966            8*       -            9        88.88     0    0     0   1   0
# 1973            7*       -           13        61.53     0    0     0   0   0
# 1985            8*       -            6       133.33     0    0     0   1   0
# 1987            8*       -           29        27.58     0    0     0   1   0
# 1990            6*       -           15        53.33     0    0     0   0   0
# 1996            7*       -            7       114.28     0    0     0   0   0

# %%
highest_scores = batting_records.loc[batting_records.innings == batting_records.not_out]['highest_score'].tolist()
highest_scores = [ x[:-1] for x in highest_scores ]
highest_scores = [ int(x) for x in highest_scores ]

# %%
#batting_records.drop(batting_records[batting_records.innings == batting_records.not_out].index, inplace=True)
batting_records.loc[batting_records.average =='-', 'average'] = highest_scores

# %%
batting_records.loc[batting_records.innings == batting_records.not_out]
# Out:
#                   name country       span  matches  innings  not_out  runs  \
# 1074       MD du Preez     NAM  2021-2021        3        2        2    62
# 1088    Mohammad Adnan   Saudi  2019-2019        5        3        3    60

# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1982 non-null   object
#  1   country        1982 non-null   object
#  2   span           1982 non-null   object
#  3   matches        1982 non-null   int64
#  4   innings        1982 non-null   int64
#  5   not_out        1982 non-null   int64
#  6   runs           1982 non-null   int64
#  7   highest_score  1982 non-null   object
#  8   average        1982 non-null   float64
#  9   balls_faced    1982 non-null   int64
#  10  strike_rate    1982 non-null   float64
#  11  100s           1982 non-null   int64
#  12  50s            1982 non-null   int64
#  13  duck           1982 non-null   int64
#  14  4s             1982 non-null   int64
#  15  6s             1982 non-null   int64
# dtypes: float64(2), int64(10), object(4)
# memory usage: 263.2+ KB

# %%
batting_records.country.unique()
# Out:
# array(['INDIA', 'NZ', 'IRE', 'AUS', 'PAK', 'ENG', 'ICC/PAK', 'AFG', 'BAN',
#        'SA', 'WI', 'SL', 'SA/World', 'BAN/ICC/World', 'SCOT', 'ZIM',
#        'NED', 'ICC/SL/World', 'NEPAL', 'UAE', 'PNG', 'NAM', 'OMA', 'MAL',
#        'KENYA', 'CZK-R', 'ROM', 'CAN', 'HKG', 'QAT', 'KUW', 'MLT', 'JER',
#        'HKG/NZ', 'BUL', 'GIBR', 'UGA', 'WI/World', 'ENG/World', 'BHR',
#        'SGP', 'NGA', 'ENG/ICC', 'AUS/World', 'GER', 'NED/SA', 'DEN',
#        'ESP', 'BMUDA', 'ENG/IRE', 'ICC/INDIA', 'MOZ', 'Belg', 'NAM/SA',
#        'VAN', 'GUE', 'Mald', 'AUS/ICC/NZ', 'LUX', 'Saudi', 'USA', 'Fin',
#        'Bhm', 'MWI', 'Aut', 'TAN', 'USA/WI', 'ITA', 'Ghana', 'PORT',
#        'HUN', 'RWN', 'BOT', 'Arg', 'NOR', 'SRB', 'PNM', 'AFG/ICC', 'Caym',
#        'Blz', 'SWE', 'NZ/World', 'THAI', 'Mex', 'IOM', 'PHI', 'SEY',
#        'EST', 'SLE', 'CYP', 'GRC', 'LES', '3', 'SUI', 'Fran', 'CRC',
#        'Samoa', 'Peru', 'Chile', 'Iran', 'DEN/ENG', 'CAM', 'BHU',
#        'ICC/NEPAL', 'TKY', 'SA/USA', 'ENG/ITA', 'AFG/GER', 'ICC/NZ', '2',
#        'AUS/NED', '1'], dtype=object)

# %%
batting_records.loc[batting_records['country'] == 'ICC/SL/World']
# Out:
#            name       country       span  matches  innings  not_out  runs  \
# 61  NLTC Perera  ICC/SL/World  2010-2021       84       74       22  1204
#
#    highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  6s
# 61            61    23.15          794       151.63     0    3     8  88  64

# %%
batting_records.country.str.isnumeric().sum()
# Out:
# 4

# %%
batting_records[batting_records['country'].isin (['1','2','3'])]
# Out:
#                 name country       span  matches  innings  not_out  runs  \
# 719   Mohammad Nawaz       3  2016-2021       30       13        6   123
# 1545     Rameez Raja       2  2011-2011        2        2        0    24
# 1747     Aftab Ahmed       2  2019-2021        4        3        0    15
# 1983  Mohammad Wasim       1  2021-2022       11        3        2     8
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  6s
# 719            30*    17.57           92       133.69     0    0     2   9   7
# 1545            23    12.00           29        82.75     0    0     0   2   0
# 1747            10     5.00           27        55.55     0    0     0   1   0
# 1983             5     8.00           10        80.00     0    0     0   1   0

# %%
batting_records.loc[(batting_records['name'] == 'Aftab Ahmed') & (batting_records['country'] == '2'), 'country'] ='Den'
batting_records.loc[batting_records.country.str.isnumeric(),'country'] = 'Pak'

# %%
batting_records.country.str.isnumeric().sum()
# Out:
# 0

# %%
batting_records.nunique(axis=0)
# Out:
# name             1973
# country           111
# span              160
# matches            98
# innings            88
# not_out            27
# runs              543
# highest_score     228
# average           854
# balls_faced       507
# strike_rate      1379
# 100s                5
# 50s                21
# duck               12
# 4s                150
# 6s                 88
# dtype: int64

# %%
batting_records.loc[batting_records['name'].duplicated(keep = False)]
# Out:
#                   name country       span  matches  innings  not_out  runs  \
# 13    Mohammad Shahzad     AFG  2010-2021       70       70        3  2015
# 237          Yasir Ali     ESP  2019-2022       18       18        5   436
# 337     Manpreet Singh     SGP  2019-2020       15       14        2   312
# 367   Mohammad Shahzad     UAE  2015-2017       20       20        2   281
# 444        Aftab Ahmed     BAN  2006-2010       11       11        1   228
# 604    Junaid Siddique     BAN  2007-2012        7        7        0   159
# 605     Manpreet Singh     ITA  2019-2021       14       12        1   159
# 683      Abdul Shakoor     ROM  2019-2022       13        9        3   131
# 771       Sandeep Goud     OMA  2019-2022       22       12        4   111
# 803       Sultan Ahmed     OMA  2015-2017       17       12        3   104
# 851       Sandeep Goud     Bhm  2021-2022        9        7        1    94
# 1072      Sultan Ahmed     UAE  2017-2021       23       14        5    63
# 1357     Abdul Shakoor     UAE  2015-2019        6        4        2    35
# 1431          Ali Raza    Belg  2021-2021        3        2        1    31
# 1634          Ali Raza     EST  2021-2021        3        3        2    19
# 1747       Aftab Ahmed     Den  2019-2021        4        3        0    15
# 1760   Junaid Siddique     UAE  2019-2022       21        7        3    15
# 1998         Yasir Ali     BAN  2022-2022        1        1        0     8
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 13            118*    30.07         1508       133.62     1   12     4  225
# 237            80*    33.53          418       104.30     0    2     2   29
# 337            42*    26.00          267       116.85     0    0     0   21
# 367             52    15.61          239       117.57     0    1     2   25
# 444            62*    22.80          178       128.08     0    1     0   26
# 604             71    22.71          108       147.22     0    1     1   16
# 605             36    14.45          187        85.02     0    0     1   13
# 683            31*    21.83          119       110.08     0    0     1   13
# 771            31*    13.87          119        93.27     0    0     0    5
# 803            37*    11.55           83       125.30     0    0     3   14
# 851             25    15.66           67       140.29     0    0     0    6
# 1072            18     7.00           63       100.00     0    0     5    1
# 1357           20*    17.50           40        87.50     0    0     0    3
# 1431           31*    31.00           25       124.00     0    0     1    2
# 1634           17*    19.00           17       111.76     0    0     1    1
# 1747            10     5.00           27        55.55     0    0     0    1
# 1760           10*     3.75           21        71.42     0    0     2    0
# 1998             8     8.00            7       114.28     0    0     0    1
#
#       6s
# 13    75
# 237   17
# 337    6
# 367   11
# 444    6
# 604    7
# 605    2
# 683    1
# 771    3
# 803    0
# 851    6
# 1072   4
# 1357   0
# 1431   1
# 1634   1
# 1747   0
# 1760   1
# 1998   0

# %%
sns.boxplot(x='runs',data = batting_records)
plt.title("Runs")
plt.show()

# %%
sns.boxplot(x='strike_rate',data = batting_records)
plt.title("Strike Rate")
plt.show()

# %%
sns.boxplot(x='average',data = batting_records)
plt.title("Average")
plt.show()

# %%
batting_records[['matches','innings']].plot(kind='box')
plt.show()

# %%
# Dropping Players who have played 4 innings or less
batting_records.drop(batting_records[(batting_records.innings <= 3) | (batting_records.balls_faced < 25)].index, inplace=True)

# %%
batting_records[batting_records['country'].str.contains('/')]
# Out:
#                   name        country       span  matches  innings  not_out  \
# 9         Shoaib Malik        ICC/PAK  2006-2021      124      111       33
# 24           DA Miller       SA/World  2010-2021       95       83       27
# 26         Tamim Iqbal  BAN/ICC/World  2007-2020       78       78        5
# 40        F du Plessis       SA/World  2012-2020       50       50        7
# 50       Shahid Afridi        ICC/PAK  2006-2018       99       91       12
# 53             HM Amla       SA/World  2009-2018       44       44        6
# 61         NLTC Perera   ICC/SL/World  2010-2021       84       74       22
# 153         MS Chapman         HKG/NZ  2014-2021       33       31        4
# 167          DJG Sammy       WI/World  2007-2017       68       52       18
# 168     PD Collingwood      ENG/World  2005-2017       36       33        2
# 213        SW Billings        ENG/ICC  2015-2022       37       33        5
# 217          GJ Bailey      AUS/World  2012-2017       30       26        7
# 223   RE van der Merwe         NED/SA  2009-2021       46       32       12
# 256           EC Joyce        ENG/IRE  2006-2014       18       15        3
# 262         KD Karthik      ICC/INDIA  2006-2019       32       26       14
# 271            D Wiese         NAM/SA  2013-2022       36       27        9
# 286           L Ronchi     AUS/ICC/NZ  2008-2018       33       26        6
# 351        XM Marshall         USA/WI  2008-2021       20       18        1
# 540        Rashid Khan        AFG/ICC  2015-2022       58       29       13
# 575         GD Elliott       NZ/World  2009-2017       17       15        4
# 653           HR Walsh         USA/WI  2019-2022       31       15        5
# 934           TD Paine      AUS/World  2009-2017       12        9        1
# 1060         WB Rankin        ENG/IRE  2009-2020       50       15        8
# 1189            A Khan        DEN/ENG  2009-2022        9        7        0
# 1230      S Lamichhane      ICC/NEPAL  2018-2022       39       15        7
# 1252          S Badree       WI/World  2012-2018       52       16       10
# 1292       BCJ Cutting      AUS/World  2013-2017        7        5        1
# 1301          J Theron         SA/USA  2010-2021       13        5        5
# 1423       JW Dernbach        ENG/ITA  2011-2021       40       10        4
#
#       runs highest_score  average  balls_faced  strike_rate  100s  50s  duck  \
# 9     2435            75    31.21         1938       125.64     0    9     2
# 24    1786          101*    31.89         1270       140.62     1    4     0
# 26    1758          103*    24.08         1503       116.96     1    7     6
# 40    1528           119    35.53         1137       134.38     1   10     0
# 50    1416           54*    17.92          944       150.00     0    4     8
# 53    1277           97*    33.60          967       132.05     0    8     2
# 61    1204            61    23.15          794       151.63     0    3     8
# 153    619           63*    22.92          525       117.90     0    2     1
# 167    587           42*    17.26          398       147.48     0    0     3
# 168    583            79    18.80          459       127.01     0    3     3
# 213    478            87    17.07          368       129.89     0    2     1
# 217    473            63    24.89          346       136.70     0    2     1
# 223    460           75*    23.00          353       130.31     0    2     6
# 256    405           78*    33.75          431        93.96     0    1     0
# 262    399            48    33.25          278       143.52     0    0     2
# 271    387           66*    21.50          318       121.69     0    1     2
# 286    359           51*    17.95          256       140.23     0    1     5
# 351    300           47*    17.64          290       103.44     0    0     2
# 540    183            33    11.43          154       118.83     0    0     6
# 575    171            27    15.54          157       108.91     0    0     0
# 653    140            28    14.00          143        97.90     0    0     2
# 934     82            25    10.25           77       106.49     0    0     2
# 1060    64           16*     9.14           74        86.48     0    0     2
# 1189    49            16     7.00           54        90.74     0    0     0
# 1230    46           16*     5.75           51        90.19     0    0     2
# 1252    43           14*     7.16           65        66.15     0    0     0
# 1292    40            29    10.00           27       148.14     0    0     1
# 1301    40           31*    31.00           26       153.84     0    0     0
# 1423    31            12     5.16           32        96.87     0    0     1
#
#        4s  6s
# 9     196  69
# 24    119  79
# 26    188  45
# 40    140  50
# 50    103  73
# 53    146  26
# 61     88  64
# 153    53  17
# 167    45  31
# 168    37  24
# 213    41  16
# 217    37  20
# 223    37  13
# 256    30   5
# 262    42  15
# 271    24  15
# 286    30  14
# 351    26   9
# 540    11  11
# 575    12   2
# 653     9   4
# 934     7   3
# 1060    3   3
# 1189    2   1
# 1230    2   1
# 1252    1   1
# 1292    2   3
# 1301    4   1
# 1423    4   0

# %%
batting_records['country'] = batting_records['country'].str.replace(r'/World','',regex=True)
batting_records['country'] = batting_records['country'].str.replace(r'/ICC','',regex=True)
batting_records['country'] = batting_records['country'].str.replace(r'ICC/','',regex=True)

# %%
batting_records[batting_records['country'].str.contains('/')]
# Out:
#                   name  country       span  matches  innings  not_out  runs  \
# 153         MS Chapman   HKG/NZ  2014-2021       33       31        4   619
# 223   RE van der Merwe   NED/SA  2009-2021       46       32       12   460
# 256           EC Joyce  ENG/IRE  2006-2014       18       15        3   405
# 271            D Wiese   NAM/SA  2013-2022       36       27        9   387
# 286           L Ronchi   AUS/NZ  2008-2018       33       26        6   359
# 351        XM Marshall   USA/WI  2008-2021       20       18        1   300
# 653           HR Walsh   USA/WI  2019-2022       31       15        5   140
# 1060         WB Rankin  ENG/IRE  2009-2020       50       15        8    64
# 1189            A Khan  DEN/ENG  2009-2022        9        7        0    49
# 1301          J Theron   SA/USA  2010-2021       13        5        5    40
# 1423       JW Dernbach  ENG/ITA  2011-2021       40       10        4    31
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  6s
# 153            63*    22.92          525       117.90     0    2     1  53  17
# 223            75*    23.00          353       130.31     0    2     6  37  13
# 256            78*    33.75          431        93.96     0    1     0  30   5
# 271            66*    21.50          318       121.69     0    1     2  24  15
# 286            51*    17.95          256       140.23     0    1     5  30  14
# 351            47*    17.64          290       103.44     0    0     2  26   9
# 653             28    14.00          143        97.90     0    0     2   9   4
# 1060           16*     9.14           74        86.48     0    0     2   3   3
# 1189            16     7.00           54        90.74     0    0     0   2   1
# 1301           31*    31.00           26       153.84     0    0     0   4   1
# 1423            12     5.16           32        96.87     0    0     1   4   0

# %%
top10countries = ['INDIA','ENG','PAK','SA','NZ','AUS','WI','SL','BAN','AFG']

# %%
batting_records[batting_records.country.isin(top10countries)].sort_values('100s', ascending=False)
# Out:
#                name country       span  matches  innings  not_out  runs  \
# 0         RG Sharma   INDIA  2007-2022      125      117       15  3313
# 15       GJ Maxwell     AUS  2012-2022       84       77       13  1982
# 27          C Munro      NZ  2012-2020       65       62        7  1724
# 4          AJ Finch     AUS  2011-2022       89       89       10  2741
# 22         KL Rahul   INDIA  2016-2021       56       52        7  1831
# ...             ...     ...        ...      ...      ...      ...   ...
# 288       CJ Jordan     ENG  2014-2022       75       43       19   358
# 285   Nasir Jamshed     PAK  2012-2013       18       18        1   363
# 279   Nasir Hossain     BAN  2011-2016       31       24        4   370
# 276       AM Rahane   INDIA  2011-2016       20       20        2   375
# 1798   VD Philander      SA  2007-2007        7        4        0    14
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 0              118    32.48         2374       139.55     4   26     7  293
# 15            145*    30.96         1287       154.00     3    9     1  164
# 27            109*    31.34         1102       156.44     3   11     5  132
# 4              172    34.69         1892       144.87     2   16     7  273
# 22            110*    40.68         1285       142.49     2   16     4  164
# ...            ...      ...          ...          ...   ...  ...   ...  ...
# 288             36    14.91          271       132.10     0    0     3   24
# 285             56    21.35          320       113.43     0    2     1   34
# 279            50*    18.50          326       113.49     0    2     2   30
# 276             61    20.83          331       113.29     0    1     2   32
# 1798             6     3.50           28        50.00     0    0     0    0
#
#        6s
# 0     155
# 15     97
# 27    107
# 4     113
# 22     73
# ...   ...
# 288    18
# 285    12
# 279     7
# 276     6
# 1798    0
#
# [441 rows x 16 columns]

# %%
batting_records[(batting_records['100s'] + batting_records['50s']) > 3]
# Out:
#                 name country       span  matches  innings  not_out  runs  \
# 0          RG Sharma   INDIA  2007-2022      125      117       15  3313
# 1         MJ Guptill      NZ  2009-2021      112      108        7  3299
# 2            V Kohli   INDIA  2010-2022       97       89       25  3296
# 3        PR Stirling     IRE  2009-2022      102      101        8  2776
# 4           AJ Finch     AUS  2011-2022       89       89       10  2741
# ..               ...     ...        ...      ...      ...      ...   ...
# 214          L Bruce    GIBR  2021-2022       15       15        2   476
# 218  VB Chikkannaiah     GER  2019-2022       22       22        2   468
# 221         R Pathan     CAN  2021-2022       11       11        2   463
# 295         SA Yadav   INDIA  2021-2022       14       12        3   351
# 345        ML Hayden     AUS  2005-2007        9        9        3   308
#
#     highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 0             118    32.48         2374       139.55     4   26     7  293
# 1             105    32.66         2413       136.71     2   20     3  287
# 2             94*    51.50         2394       137.67     0   30     3  298
# 3            115*    29.84         2061       134.69     1   20     9  319
# 4             172    34.69         1892       144.87     2   16     7  273
# ..            ...      ...          ...          ...   ...  ...   ...  ...
# 214           99*    36.61          394       120.81     0    6     2   39
# 218           81*    23.40          488        95.90     0    4     1   35
# 221          107*    51.44          287       161.32     1    3     1   48
# 295            65    39.00          212       165.56     0    4     1   32
# 345           73*    51.33          214       143.92     0    4     0   37
#
#       6s
# 0    155
# 1    165
# 2     92
# 3     96
# 4    113
# ..   ...
# 214    6
# 218   11
# 221   21
# 295   20
# 345   13
#
# [143 rows x 16 columns]

# %%
batting_records[(batting_records['100s']) > 0]
# Out:
#             name country       span  matches  innings  not_out  runs  \
# 0      RG Sharma   INDIA  2007-2022      125      117       15  3313
# 1     MJ Guptill      NZ  2009-2021      112      108        7  3299
# 3    PR Stirling     IRE  2009-2022      102      101        8  2776
# 4       AJ Finch     AUS  2011-2022       89       89       10  2741
# 5     Babar Azam     PAK  2016-2022       74       69       10  2686
# ..           ...     ...        ...      ...      ...      ...   ...
# 406  Dylan Steyn   CZK-R  2022-2022        6        6        0   252
# 431      RE Levi      SA  2012-2012       13       13        2   236
# 452   MN van Wyk      SA  2007-2015        8        7        1   225
# 472    LA Dunbar     SRB  2019-2021        6        6        2   214
# 512     M Spoors     CAN  2022-2022        5        5        2   194
#
#     highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 0             118    32.48         2374       139.55     4   26     7  293
# 1             105    32.66         2413       136.71     2   20     3  287
# 3            115*    29.84         2061       134.69     1   20     9  319
# 4             172    34.69         1892       144.87     2   16     7  273
# 5             122    45.52         2075       129.44     1   26     3  278
# ..            ...      ...          ...          ...   ...  ...   ...  ...
# 406           106    42.00          165       152.72     1    1     0   31
# 431          117*    21.45          167       141.31     1    1     3   20
# 452          114*    37.50          157       143.31     1    1     0   19
# 472          104*    53.50          127       168.50     1    1     2   15
# 512          108*    64.66          141       137.58     1    1     1   24
#
#       6s
# 0    155
# 1    165
# 3     96
# 4    113
# 5     42
# ..   ...
# 406    6
# 431   15
# 452   14
# 472   19
# 512    5
#
# [68 rows x 16 columns]

# %%
batting_records[(batting_records['50s']) > 3]
# Out:
#                 name country       span  matches  innings  not_out  runs  \
# 0          RG Sharma   INDIA  2007-2022      125      117       15  3313
# 1         MJ Guptill      NZ  2009-2021      112      108        7  3299
# 2            V Kohli   INDIA  2010-2022       97       89       25  3296
# 3        PR Stirling     IRE  2009-2022      102      101        8  2776
# 4           AJ Finch     AUS  2011-2022       89       89       10  2741
# ..               ...     ...        ...      ...      ...      ...   ...
# 209       HS Gericke     MLT  2020-2022       18       17        0   490
# 214          L Bruce    GIBR  2021-2022       15       15        2   476
# 218  VB Chikkannaiah     GER  2019-2022       22       22        2   468
# 295         SA Yadav   INDIA  2021-2022       14       12        3   351
# 345        ML Hayden     AUS  2005-2007        9        9        3   308
#
#     highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 0             118    32.48         2374       139.55     4   26     7  293
# 1             105    32.66         2413       136.71     2   20     3  287
# 2             94*    51.50         2394       137.67     0   30     3  298
# 3            115*    29.84         2061       134.69     1   20     9  319
# 4             172    34.69         1892       144.87     2   16     7  273
# ..            ...      ...          ...          ...   ...  ...   ...  ...
# 209            91    28.82          296       165.54     0    4     0   42
# 214           99*    36.61          394       120.81     0    6     2   39
# 218           81*    23.40          488        95.90     0    4     1   35
# 295            65    39.00          212       165.56     0    4     1   32
# 345           73*    51.33          214       143.92     0    4     0   37
#
#       6s
# 0    155
# 1    165
# 2     92
# 3     96
# 4    113
# ..   ...
# 209   20
# 214    6
# 218   11
# 295   20
# 345   13
#
# [139 rows x 16 columns]

# %%
batting_records['country'] = batting_records['country'].str.upper()

# %%
batting_records
# Out:
#                  name country       span  matches  innings  not_out  runs  \
# 0           RG Sharma   INDIA  2007-2022      125      117       15  3313
# 1          MJ Guptill      NZ  2009-2021      112      108        7  3299
# 2             V Kohli   INDIA  2010-2022       97       89       25  3296
# 3         PR Stirling     IRE  2009-2022      102      101        8  2776
# 4            AJ Finch     AUS  2011-2022       89       89       10  2741
# ...               ...     ...        ...      ...      ...      ...   ...
# 1847          H Helva     TKY  2019-2019        4        4        0    12
# 1868  Apon Mustafizur     SRB  2019-2021        4        4        0    11
# 1895          W Uisuk    THAI  2020-2020        4        4        0    11
# 1941      I Katzarski     BUL  2019-2022       13        4        0     9
# 1969       JD Freyone    GIBR  2019-2019        4        4        0     8
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 0              118    32.48         2374       139.55     4   26     7  293
# 1              105    32.66         2413       136.71     2   20     3  287
# 2              94*    51.50         2394       137.67     0   30     3  298
# 3             115*    29.84         2061       134.69     1   20     9  319
# 4              172    34.69         1892       144.87     2   16     7  273
# ...            ...      ...          ...          ...   ...  ...   ...  ...
# 1847             7     3.00           25        48.00     0    0     2    2
# 1868            11     2.75           37        29.72     0    0     3    2
# 1895             5     2.75           40        27.50     0    0     0    1
# 1941             4     2.25           28        32.14     0    0     1    0
# 1969             4     2.00           29        27.58     0    0     2    0
#
#        6s
# 0     155
# 1     165
# 2      92
# 3      96
# 4     113
# ...   ...
# 1847    0
# 1868    0
# 1895    0
# 1941    0
# 1969    0
#
# [1400 rows x 16 columns]

# %%
plt.figure(figsize=(28,8))
sns.countplot(x='country',data=batting_records)
plt.xticks(rotation=45)
plt.show()

# %%
batting_records_by_country = batting_records.groupby('country').count()
countries_with_atleast_15_batters = batting_records_by_country[batting_records_by_country.name >15].index

# %%
plt.figure(figsize=(28,8))
sns.countplot(x='country',data=batting_records[batting_records['country'].isin(countries_with_atleast_15_batters)])
plt.xticks(rotation=45)
plt.show()

## In Dissertation generate this plot from tableau(sort accending)

# %%
boundaries = (batting_records['4s'] + batting_records['6s'])
batting_records['boundary_per_ball'] = np.round(boundaries/batting_records['balls_faced'],3)

# %%
batting_records
# Out:
#                  name country       span  matches  innings  not_out  runs  \
# 0           RG Sharma   INDIA  2007-2022      125      117       15  3313
# 1          MJ Guptill      NZ  2009-2021      112      108        7  3299
# 2             V Kohli   INDIA  2010-2022       97       89       25  3296
# 3         PR Stirling     IRE  2009-2022      102      101        8  2776
# 4            AJ Finch     AUS  2011-2022       89       89       10  2741
# ...               ...     ...        ...      ...      ...      ...   ...
# 1847          H Helva     TKY  2019-2019        4        4        0    12
# 1868  Apon Mustafizur     SRB  2019-2021        4        4        0    11
# 1895          W Uisuk    THAI  2020-2020        4        4        0    11
# 1941      I Katzarski     BUL  2019-2022       13        4        0     9
# 1969       JD Freyone    GIBR  2019-2019        4        4        0     8
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 0              118    32.48         2374       139.55     4   26     7  293
# 1              105    32.66         2413       136.71     2   20     3  287
# 2              94*    51.50         2394       137.67     0   30     3  298
# 3             115*    29.84         2061       134.69     1   20     9  319
# 4              172    34.69         1892       144.87     2   16     7  273
# ...            ...      ...          ...          ...   ...  ...   ...  ...
# 1847             7     3.00           25        48.00     0    0     2    2
# 1868            11     2.75           37        29.72     0    0     3    2
# 1895             5     2.75           40        27.50     0    0     0    1
# 1941             4     2.25           28        32.14     0    0     1    0
# 1969             4     2.00           29        27.58     0    0     2    0
#
#        6s  boundary_per_ball
# 0     155              0.189
# 1     165              0.187
# 2      92              0.163
# 3      96              0.201
# 4     113              0.204
# ...   ...                ...
# 1847    0              0.080
# 1868    0              0.054
# 1895    0              0.025
# 1941    0              0.000
# 1969    0              0.000
#
# [1400 rows x 17 columns]

# %%
sns.boxplot(x='boundary_per_ball',data = batting_records)
plt.title("Boundary per ball")
plt.show()

# %%
batting_records.loc[batting_records['boundary_per_ball']>0.3].sort_values('boundary_per_ball',ascending=False)
# Out:
#                      name country       span  matches  innings  not_out  runs  \
# 611              FH Allen      NZ  2021-2021        6        6        0   156
# 949         SC Kuggeleijn      NZ  2019-2021       18        8        4    79
# 990         Khalid Ahmadi    BELG  2020-2021        9        6        4    73
# 1109             ED Silva     KUW  2021-2021        4        4        1    58
# 616   Hadisullah Tarakhel    BELG  2021-2021        5        5        1   154
# 147       Taranjeet Singh     ROM  2021-2022       14       14        2   633
# 306           Faisal Khan   SAUDI  2019-2021       11       11        1   337
# 390      Zeeshan Kukikhel     HUN  2021-2021        4        4        0   263
# 618           Mirza Ahsan     AUT  2019-2021        8        7        4   153
# 793            Sami Ullah     ROM  2020-2021        9        7        1   106
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  \
# 611             71    26.00           82       190.24     0    1     1  19
# 949            35*    19.75           37       213.51     0    0     2   5
# 990            31*    36.50           37       197.29     0    0     0   9
# 1109            58    19.33           31       187.09     0    1     2   6
# 616             78    38.50           84       183.33     0    1     0  16
# 147            110    52.75          347       182.42     1    5     1  79
# 306            83*    33.70          185       182.16     0    1     1  38
# 390             82    65.75          150       175.33     0    3     0  37
# 618            52*    51.00           67       228.35     0    2     0   9
# 793             33    17.66           55       192.72     0    0     1  13
#
#       6s  boundary_per_ball
# 611    8              0.329
# 949    7              0.324
# 990    3              0.324
# 1109   4              0.323
# 616   11              0.321
# 147   30              0.314
# 306   20              0.314
# 390   10              0.313
# 618   12              0.313
# 793    4              0.309

# %%
batting_records['boundary_index'] = np.round(boundaries / batting_records.innings,3)

# %%
sns.boxplot(x='boundary_index',data = batting_records)
plt.title("Boundary Per innings")
plt.show()

# %%
batting_records.loc[batting_records['boundary_index']>5].sort_values('boundary_index',ascending=False)
# Out:
#                     name country       span  matches  innings  not_out  runs  \
# 390     Zeeshan Kukikhel     HUN  2021-2021        4        4        0   263
# 372         Azhar Andani    PORT  2021-2021        4        4        0   276
# 147      Taranjeet Singh     ROM  2021-2022       14       14        2   633
# 221             R Pathan     CAN  2021-2022       11       11        2   463
# 406          Dylan Steyn   CZK-R  2022-2022        6        6        0   252
# 197      Muhammad Waseem     UAE  2021-2022       12       12        1   506
# 109             S Davizi   CZK-R  2019-2022       19       19        2   779
# 110          R Satheesan     ROM  2019-2022       23       21        4   775
# 512             M Spoors     CAN  2022-2022        5        5        2   194
# 472            LA Dunbar     SRB  2019-2021        6        6        2   214
# 313         Adnan Idrees     KUW  2019-2021       10       10        0   332
# 392         Bilal Zalmai     AUT  2019-2021        8        7        1   259
# 345            ML Hayden     AUS  2005-2007        9        9        3   308
# 182             TH David     SGP  2019-2020       14       14        2   558
# 174         Sarfaraz Ali     BHR  2019-2022       17       17        1   569
# 616  Hadisullah Tarakhel    BELG  2021-2021        5        5        1   154
# 398         Saim Hussain     BUL  2022-2022        6        6        1   257
# 306          Faisal Khan   SAUDI  2019-2021       11       11        1   337
# 138         R Sandaruwan     KUW  2019-2021       19       19        2   655
# 349          II Selemani     TAN  2021-2021       10       10        1   302
# 120    Hazratullah Zazai     AFG  2016-2022       22       22        2   727
#
#     highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  6s  \
# 390            82    65.75          150       175.33     0    3     0  37  10
# 372           100    69.00          179       154.18     1    1     0  27   6
# 147           110    52.75          347       182.42     1    5     1  79  30
# 221          107*    51.44          287       161.32     1    3     1  48  21
# 406           106    42.00          165       152.72     1    1     0  31   6
# 197           112    46.00          330       153.33     2    3     1  40  32
# 109          115*    45.82          522       149.23     2    4     1  83  29
# 110           92*    45.58          420       184.52     0    7     1  83  39
# 512          108*    64.66          141       137.58     1    1     1  24   5
# 472          104*    53.50          127       168.50     1    1     2  15  19
# 313            80    33.20          209       158.85     0    3     0  44  12
# 392          111*    43.16          148       175.00     1    0     0  23  16
# 345           73*    51.33          214       143.92     0    4     0  37  13
# 182           92*    46.50          352       158.52     0    4     0  50  26
# 174           69*    35.56          338       168.34     0    4     0  49  43
# 616            78    38.50           84       183.33     0    1     0  16  11
# 398          108*    51.40          159       161.63     1    2     1  22  10
# 306           83*    33.70          185       182.16     0    1     1  38  20
# 138           103    38.52          409       160.14     1    4     3  62  37
# 349            81    33.55          183       165.02     0    2     1  36  16
# 120          162*    36.35          500       145.40     1    3     2  61  51
#
#      boundary_per_ball  boundary_index
# 390              0.313          11.750
# 372              0.184           8.250
# 147              0.314           7.786
# 221              0.240           6.273
# 406              0.224           6.167
# 197              0.218           6.000
# 109              0.215           5.895
# 110              0.290           5.810
# 512              0.206           5.800
# 472              0.268           5.667
# 313              0.268           5.600
# 392              0.264           5.571
# 345              0.234           5.556
# 182              0.216           5.429
# 174              0.272           5.412
# 616              0.321           5.400
# 398              0.201           5.333
# 306              0.314           5.273
# 138              0.242           5.211
# 349              0.284           5.200
# 120              0.224           5.091

# %%
batting_records['finishing_index'] = np.round(batting_records['not_out'] / batting_records.innings, 3)

# %%
sns.boxplot(x='finishing_index',data = batting_records)
plt.title("Finishing innings")
plt.show()

# %%
batting_records.loc[(batting_records['finishing_index']>0.8)]
# Out:
#             name country       span  matches  innings  not_out  runs  \
# 1176  HA Varaiya   KENYA  2007-2013       25       12       11    51
# 1301    J Theron  SA/USA  2010-2021       13        5        5    40
# 1309     KB Ahir     PNM  2019-2021        8        5        5    39
# 1388    AF Milne      NZ  2010-2021       31       10        9    33
# 1548     P Useni     NGA  2021-2021       16        8        7    24
# 1677  Raza Hasan     PAK  2012-2014       10        4        4    18
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  \
# 1176           18*     51.0           81        62.96     0    0     0   1
# 1301           31*     31.0           26       153.84     0    0     0   4
# 1309           32*     32.0           41        95.12     0    0     0   5
# 1388           10*     33.0           33       100.00     0    0     0   1
# 1548            7*     24.0           32        75.00     0    0     0   2
# 1677           13*     13.0           25        72.00     0    0     0   2
#
#       6s  boundary_per_ball  boundary_index  finishing_index
# 1176   0              0.012           0.083            0.917
# 1301   1              0.192           1.000            1.000
# 1309   1              0.146           1.200            1.000
# 1388   1              0.061           0.200            0.900
# 1548   0              0.062           0.250            0.875
# 1677   0              0.080           0.500            1.000

# %%
batting_records['duck_index'] = np.round(batting_records['duck'] / batting_records.innings, 3)

# %%
sns.boxplot(x='duck_index',data = batting_records)
plt.title("Duck index")
plt.show()

# %%
batting_records.loc[batting_records['duck_index']>0.35]
# Out:
#                    name country       span  matches  innings  not_out  runs  \
# 551      Imran Ali Butt     BHR  2019-2021       12       10        0   179
# 743   Shamsudheen Purat   SAUDI  2019-2020        6        5        1   118
# 763           G Stewart     ITA  2021-2021        6        5        0   113
# 827         Irfan Bhima     MWI  2019-2019        4        4        0    98
# 842            MH Yardy     ENG  2006-2011       14        8        5    96
# 861         BJ McCarthy     IRE  2017-2022       19       12        5    92
# 967        NFI McCallum    SCOT  2007-2010       11        7        0    76
# 1067          LJ Barker     GUE  2019-2020       10        8        0    63
# 1072       Sultan Ahmed     UAE  2017-2021       23       14        5    63
# 1107            SK Atai     PNG  2019-2022       12        9        1    58
# 1109           ED Silva     KUW  2021-2021        4        4        1    58
# 1110          CJO Smith    SCOT  2007-2009        8        6        1    58
# 1114          DK Anefie   GHANA  2019-2021       11        7        3    57
# 1132        N Deonarine      WI  2010-2013        8        7        2    55
# 1136            S Jamil    BELG  2019-2021        9        8        1    55
# 1145         HS Baidwan     CAN  2008-2013       17       11        2    54
# 1179            T Filer     EST  2021-2021        5        5        0    50
# 1209           C Zhuwao     ZIM  2008-2018        7        7        0    48
# 1244      Zohaib Sarwar    PORT  2019-2019        4        4        1    45
# 1245         JM Davison     CAN  2008-2010        5        5        0    44
# 1276          AT Rayudu   INDIA  2014-2016        6        5        1    42
# 1298         ACF Stokes     GUE  2019-2022       11        7        0    40
# 1311             D Ahir     PNM  2021-2021        5        5        0    38
# 1336          AM Kimote     TAN  2021-2021       10        5        2    37
# 1407       CE McConchie      NZ  2021-2021        5        4        2    32
# 1437           JC Darji     TAN  2021-2021        7        6        0    30
# 1438           E Ernest     SLE  2021-2021       10        7        2    30
# 1451           SR Mohan     SEY  2021-2021        6        5        2    29
# 1456          M Simmons   BMUDA  2019-2021        6        4        1    29
# 1464          R Goodwin     PHI  2019-2022        9        9        2    28
# 1471            A Nehra   INDIA  2009-2017       27        5        0    28
# 1510          L Shafeeg    MALD  2019-2021        8        5        2    26
# 1531        A Srivastav   CHILE  2019-2019        4        4        0    25
# 1554        DL Brangman   BMUDA  2019-2019        5        4        2    23
# 1561          MV Matsau     LES  2021-2021        5        5        2    23
# 1643     Jaspreet Singh     ITA  2019-2021       11        4        0    19
# 1687        Awais Malik     QAT  2019-2020       18        7        0    17
# 1762            AC Kose     TKY  2019-2019        4        4        0    15
# 1766      Nasrulla Rana     HKG  2019-2020       11        6        2    15
# 1788            G Dutta     MEX  2019-2019        7        6        0    14
# 1818         SP Gauchan   NEPAL  2014-2015        9        5        2    13
# 1847            H Helva     TKY  2019-2019        4        4        0    12
# 1868    Apon Mustafizur     SRB  2019-2021        4        4        0    11
# 1969         JD Freyone    GIBR  2019-2019        4        4        0     8
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  du
# 1276   0              0.100           1.000            0.200       0.400
# 1298   0              0.143           0.857            0.000       0.429
# 1311   2              0.139           1.000            0.000       0.400
# 1336   0              0.129           0.800            0.400       0.400
# 1407   0              0.107           0.750            0.500       0.500
# 1437   0              0.091           0.667            0.000       0.500
# 1438   0              0.040           0.286            0.286       0.429
# 1451   0              0.038           0.400            0.400       0.400
# 1456   1              0.071           0.500            0.250       0.500
# 1464   0              0.018           0.111            0.222       0.444
# 1471   2              0.077           0.600            0.000       0.600
# 1510   1              0.111           0.600            0.400       0.600
# 1531   0              0.054           0.500            0.000       0.500
# 1554   1              0.120           0.750            0.500       0.500
# 1561   0              0.071           0.400            0.400       0.400
# 1643   0              0.037           0.250            0.000       0.500
# 1687   0              0.037           0.143            0.000       0.429
# 1762   0              0.091           0.750            0.000       0.750
# 1766   0              0.000           0.000            0.333       0.500
# 1788   0              0.036           0.167            0.000       0.500
# 1818   0              0.000           0.000            0.400       0.400
# 1847   0              0.080           0.500            0.000       0.500
# 1868   0              0.054           0.500            0.000       0.750
# 1969   0              0.000           0.000            0.000       0.500

# %%
runs_without_boundaries = batting_records.runs - (4*batting_records['4s'] + 6*batting_records['6s'])
batting_records['runs_without_boundary_index'] = np.round(runs_without_boundaries / batting_records.innings,3)

# %%
batting_records
# Out:
#                  name country       span  matches  innings  not_out  runs  \
# 0           RG Sharma   INDIA  2007-2022      125      117       15  3313
# 1          MJ Guptill      NZ  2009-2021      112      108        7  3299
# 2             V Kohli   INDIA  2010-2022       97       89       25  3296
# 3         PR Stirling     IRE  2009-2022      102      101        8  2776
# 4            AJ Finch     AUS  2011-2022       89       89       10  2741
# ...               ...     ...        ...      ...      ...      ...   ...
# 1847          H Helva     TKY  2019-2019        4        4        0    12
# 1868  Apon Mustafizur     SRB  2019-2021        4        4        0    11
# 1895          W Uisuk    THAI  2020-2020        4        4        0    11
# 1941      I Katzarski     BUL  2019-2022       13        4        0     9
# 1969       JD Freyone    GIBR  2019-2019        4        4        0     8
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 0              118    32.48         2374       139.55     4   26     7  293
# 1              105    32.66         2413       136.71     2   20     3  287
# 2              94*    51.50         2394       137.67     0   30     3  298
# 3             115*    29.84         2061       134.69     1   20     9  319
# 4              172    34.69         1892       144.87     2   16     7  273
# ...            ...      ...          ...          ...   ...  ...   ...  ...
# 1847             7     3.00           25        48.00     0    0     2    2
# 1868            11     2.75           37        29.72     0    0     3    2
# 1895             5     2.75           40        27.50     0    0     0    1
# 1941             4     2.25           28        32.14     0    0     1    0
# 1969             4     2.00           29        27.58     0    0     2    0
#
#        6s  boundary_per_ball  boundary_index  finishing_index  duck_index  \
# 0     155              0.189           3.829            0.128       0.060
# 1     165              0.187           4.185            0.065       0.028
# 2      92              0.163           4.382            0.281       0.034
# 3      96              0.201           4.109            0.079       0.089
# 4     113              0.204           4.337            0.112       0.079
# ...   ...                ...             ...              ...         ...
# 1847    0              0.080           0.500            0.000       0.500
# 1868    0              0.054           0.500            0.000       0.750
# 1895    0              0.025           0.250            0.000       0.000
# 1941    0              0.000           0.000            0.000       0.250
# 1969    0              0.000           0.000            0.000       0.500
#
#       runs_without_boundary_index
# 0                          10.350
# 1                          10.750
# 2                          17.438
# 3                           9.149
# 4                          10.910
# ...                           ...
# 1847                        1.000
# 1868                        0.750
# 1895                        1.750
# 1941                        2.250
# 1969                        2.000
#
# [1400 rows x 21 columns]

# %%
sns.boxplot(x='runs_without_boundary_index',data = batting_records)
plt.title("Runs without boundary index")
plt.show()

# %%
batting_records.loc[batting_records.runs_without_boundary_index > 15].sort_values('runs_without_boundary_index',ascending = False)
# Out:
#                   name  country       span  matches  innings  not_out  runs  \
# 372       Azhar Andani     PORT  2021-2021        4        4        0   276
# 161             BA Pai     GIBR  2019-2022       15       15        3   595
# 598          A McAuley      IOM  2020-2021        5        5        1   162
# 366            A Bagai      CAN  2008-2013        9        9        2   284
# 5           Babar Azam      PAK  2016-2022       74       69       10  2686
# 658           AC Voges      AUS  2007-2013        7        5        2   139
# 214            L Bruce     GIBR  2021-2022       15       15        2   476
# 398       Saim Hussain      BUL  2022-2022        6        6        1   257
# 362        AN Kervezee      NED  2009-2012       10       10        1   289
# 2              V Kohli    INDIA  2010-2022       97       89       25  3296
# 339        Sami Sohail      MWI  2019-2021       13       11        7   312
# 32     Mohammad Rizwan      PAK  2015-2022       56       45       12  1662
# 579            J Broad      GER  2022-2022        5        5        1   169
# 256           EC Joyce  ENG/IRE  2006-2014       18       15        3   405
# 250          MW Machan     SCOT  2013-2016       13       13        3   407
# 154            H Lakov      BUL  2019-2022       24       24        5   619
# 330         NG Collins      FIN  2019-2022       12       12        1   319
# 294          TC Barker      LUX  2019-2021       12       12        0   352
# 232           HAM Shah      DEN  2019-2022       15       14        0   445
# 654            P Heron     CAYM  2022-2022        5        5        1   139
# 158          DP Conway       NZ  2020-2021       20       17        5   602
# 406        Dylan Steyn    CZK-R  2022-2022        6        6        0   252
# 87   HE van der Dussen       SA  2018-2021       34       31        7   933
# 859   J Trembeath-Moro      ESP  2022-2022        4        4        1    93
# 427            K Dasan      BUL  2019-2020       10        9        1   237
#
#     highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 372           100    69.00          179       154.18     1    1     0   27
# 161          107*    49.58          472       126.05     1    4     0   54
# 598            45    40.50          164        98.78     0    0     0   13
# 366           67*    40.57          249       114.05     0    2     0   27
# 5             122    45.52         2075       129.44     1   26     3  278
# 658            51    46.33          114       121.92     0    1     0    8
# 214           99*    36.61          394       120.81     0    6     2   39
# 398          108*    51.40          159       161.63     1    2     1   22
# 362           58*    32.11          262       110.30     0    2     0   19
# 2             94*    51.50         2394       137.67     0   30     3  298
# 339           84*    78.00          272       114.70     0    2     1   23
# 32           104*    50.36         1290       128.83     1   13     3  151
# 579            62    42.25          140       120.71     0    2     0   18
# 256           78*    33.75          431        93.96     0    1     0   30
# 250           67*    40.70          318       127.98     0    3     0   37
# 154            80    32.57          574       107.83     0    6     0   49
# 330           64*    29.00          321        99.37     0    3     0   28
# 294            78    29.33          288       122.22     0    2     0   32
# 232            99    31.78          392       113.52     0    3     0   43
# 654            59    34.75          113       123.00     0    2     0    9
# 158           99*    50.16          432       139.35     0    4     0   62
# 406           106    42.00          165       152.72     1    1     0   31
# 87            94*    38.87          713       130.85     0    6     1   55
# 859            39    31.00          116        80.17     0    0     0    5
# 427            74    29.62          222       106.75     0    1     0   19
#
#      6s  boundary_per_ball  boundary_index  finishing_index  duck_index  \
# 372   6              0.184           8.250            0.000       0.000
# 161  11              0.138           4.333            0.200       0.000
# 598   1              0.085           2.800            0.200       0.000
# 366   0              0.108           3.000            0.222       0.000
# 5    42              0.154           4.638            0.145       0.043
# 658   2              0.088           2.000            0.400       0.000
# 214   6              0.114           3.000            0.133       0.133
# 398  10              0.201           5.333            0.167       0.167
# 362   6              0.095           2.500            0.100       0.000
# 2    92              0.163           4.382            0.281       0.034
# 339   5              0.103           2.545            0.636       0.091
# 32   48              0.154           4.422            0.267       0.067
# 579   2              0.143           4.000            0.200       0.000
# 256   5              0.081           2.333            0.200       0.000
# 250   7              0.138           3.385            0.231       0.000
# 154   5              0.094           2.250            0.208       0.000
# 330   2              0.093           2.500            0.083       0.000
# 294   5              0.128           3.083            0.000       0.000
# 232   8              0.130           3.643            0.000       0.000
# 654   4              0.115           2.600            0.200       0.000
# 158  15              0.178           4.529            0.294       0.000
# 406   6              0.224           6.167            0.000       0.000
# 87   40              0.133           3.065            0.226       0.032
# 859   2              0.060           1.750            0.250       0.000
# 427   4              0.104           2.556            0.111       0.000
#
#      runs_without_boundary_index
# 372                       33.000
# 161                       20.867
# 598                       20.800
# 366                       19.556
# 5                         19.159
# 658                       19.000
# 214                       18.933
# 398                       18.167
# 362                       17.700
# 2                         17.438
# 339                       17.273
# 32                        17.111
# 579                       17.000
# 256                       17.000
# 250                       16.692
# 154                       16.375
# 330                       16.250
# 294                       16.167
# 232                       16.071
# 654                       15.800
# 158                       15.529
# 406                       15.333
# 87                        15.258
# 859                       15.250
# 427                       15.222

# %%
batting_records['big_match_index'] = np.round(((2 * batting_records['100s']) + batting_records['50s']) / batting_records.innings,3)

# %%
sns.boxplot(x='big_match_index',data = batting_records)
plt.title("Big Match Index")
plt.show()

# %%
batting_records.loc[(batting_records.big_match_index > 0.1) & batting_records.country.isin(top10countries)].sort_values('big_match_index',ascending = False)
# Out:
#            name country       span  matches  innings  not_out  runs  \
# 345   ML Hayden     AUS  2005-2007        9        9        3   308
# 452  MN van Wyk      SA  2007-2015        8        7        1   225
# 5    Babar Azam     PAK  2016-2022       74       69       10  2686
# 22     KL Rahul   INDIA  2016-2021       56       52        7  1831
# 60     DJ Malan     ENG  2017-2021       36       35        5  1239
# ..          ...     ...        ...      ...      ...      ...   ...
# 480   CA Ingram      SA  2010-2012        9        9        1   210
# 90    Liton Das     BAN  2015-2022       48       47        1   917
# 36     SK Raina   INDIA  2006-2018       78       66       11  1605
# 319    RJ Nicol      NZ  2010-2013       21       19        0   327
# 29   Umar Akmal     PAK  2009-2019       84       79       14  1690
#
#     highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 345           73*    51.33          214       143.92     0    4     0   37
# 452          114*    37.50          157       143.31     1    1     0   19
# 5             122    45.52         2075       129.44     1   26     3  278
# 22           110*    40.68         1285       142.49     2   16     4  164
# 60           103*    41.30          903       137.20     1   11     0  128
# ..            ...      ...          ...          ...   ...  ...   ...  ...
# 480            78    26.25          162       129.62     0    1     1   23
# 90             61    19.93          743       123.41     0    5     4   84
# 36            101    29.18         1190       134.87     1    5     3  145
# 319            58    17.21          296       110.47     0    2     2   33
# 29             94    26.00         1377       122.73     0    8    10  122
#
#      6s  boundary_per_ball  boundary_index  finishing_index  duck_index  \
# 345  13              0.234           5.556            0.333       0.000
# 452  14              0.210           4.714            0.143       0.000
# 5    42              0.154           4.638            0.145       0.043
# 22   73              0.184           4.558            0.135       0.077
# 60   41              0.187           4.829            0.143       0.000
# ..   ..                ...             ...              ...         ...
# 480   7              0.185           3.333            0.111       0.111
# 90   30              0.153           2.426            0.021       0.085
# 36   58              0.171           3.076            0.167       0.045
# 319  11              0.149           2.316            0.000       0.105
# 29   55              0.129           2.241            0.177       0.127
#
#      runs_without_boundary_index  big_match_index
# 345                        9.111            0.444
# 452                        9.286            0.429
# 5                         19.159            0.406
# 22                        14.173            0.385
# 60                        13.743            0.371
# ..                           ...              ...
# 480                        8.444            0.111
# 90                         8.532            0.106
# 36                        10.258            0.106
# 319                        6.789            0.105
# 29                        11.038            0.101
#
# [127 rows x 22 columns]

# %%
batting_records[batting_records['100s'] > 0]
# Out:
#             name country       span  matches  innings  not_out  runs  \
# 0      RG Sharma   INDIA  2007-2022      125      117       15  3313
# 1     MJ Guptill      NZ  2009-2021      112      108        7  3299
# 3    PR Stirling     IRE  2009-2022      102      101        8  2776
# 4       AJ Finch     AUS  2011-2022       89       89       10  2741
# 5     Babar Azam     PAK  2016-2022       74       69       10  2686
# ..           ...     ...        ...      ...      ...      ...   ...
# 406  Dylan Steyn   CZK-R  2022-2022        6        6        0   252
# 431      RE Levi      SA  2012-2012       13       13        2   236
# 452   MN van Wyk      SA  2007-2015        8        7        1   225
# 472    LA Dunbar     SRB  2019-2021        6        6        2   214
# 512     M Spoors     CAN  2022-2022        5        5        2   194
#
#     highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# 0             118    32.48         2374       139.55     4   26     7  293
# 1             105    32.66         2413       136.71     2   20     3  287
# 3            115*    29.84         2061       134.69     1   20     9  319
# 4             172    34.69         1892       144.87     2   16     7  273
# 5             122    45.52         2075       129.44     1   26     3  278
# ..            ...      ...          ...          ...   ...  ...   ...  ...
# 406           106    42.00          165       152.72     1    1     0   31
# 431          117*    21.45          167       141.31     1    1     3   20
# 452          114*    37.50          157       143.31     1    1     0   19
# 472          104*    53.50          127       168.50     1    1     2   15
# 512          108*    64.66          141       137.58     1    1     1   24
#
#       6s  boundary_per_ball  boundary_index  finishing_index  duck_index  \
# 0    155              0.189           3.829            0.128       0.060
# 1    165              0.187           4.185            0.065       0.028
# 3     96              0.201           4.109            0.079       0.089
# 4    113              0.204           4.337            0.112       0.079
# 5     42              0.154           4.638            0.145       0.043
# ..   ...                ...             ...              ...         ...
# 406    6              0.224           6.167            0.000       0.000
# 431   15              0.210           2.692            0.154       0.231
# 452   14              0.210           4.714            0.143       0.000
# 472   19              0.268           5.667            0.333       0.333
# 512    5              0.206           5.800            0.400       0.200
#
#      runs_without_boundary_index  big_match_index
# 0                         10.350            0.291
# 1                         10.750            0.222
# 3                          9.149            0.218
# 4                         10.910            0.225
# 5                         19.159            0.406
# ..                           ...              ...
# 406                       15.333            0.500
# 431                        5.077            0.231
# 452                        9.286            0.429
# 472                        6.667            0.500
# 512                       13.600            0.600
#
# [68 rows x 22 columns]

# %%
batting_records.describe()
# Out:
#            matches      innings      not_out         runs      average  \
# count  1400.000000  1400.000000  1400.000000  1400.000000  1400.000000
# mean     19.850714    15.789286     3.167857   275.316429    18.953021
# std      19.102369    16.487542     3.912513   409.096720    10.228776
# min       4.000000     4.000000     0.000000     8.000000     2.000000
# 25%       8.000000     6.000000     1.000000    61.000000    11.500000
# 50%      13.000000    10.000000     2.000000   126.500000    17.280000
# 75%      24.250000    18.000000     4.000000   300.500000    24.285000
# max     125.000000   117.000000    42.000000  3313.000000    78.000000
#
#        balls_faced  strike_rate         100s          50s         duck  \
# count  1400.000000  1400.000000  1400.000000  1400.000000  1400.000000
# mean    229.812857   109.212200     0.059286     1.161429     1.360000
# std     311.790289    28.321358     0.290521     2.675641     1.613152
# min      25.000000    25.000000     0.000000     0.000000     0.000000
# 25%      64.000000    90.360000     0.000000     0.000000     0.000000
# 50%     118.500000   110.320000     0.000000     0.000000     1.000000
# 75%     251.500000   127.370000     0.000000     1.000000     2.000000
# max    2413.000000   228.350000     4.000000    30.000000    12.000000
#
#                 4s           6s  boundary_per_ball  boundary_index  \
# count  1400.000000  1400.000000        1400.000000     1400.000000
# mean     23.561429     9.683571           0.124407        1.722287
# std      37.975903    16.675879           0.057675        1.215380
# min       0.000000     0.000000           0.000000        0.000000
# 25%       4.000000     1.000000           0.087000        0.812000
# 50%      10.000000     4.000000           0.124000        1.500000
# 75%      25.000000    11.000000           0.161250        2.400000
# max     319.000000   165.000000           0.329000       11.750000
#
#        finishing_index   duck_index  runs_without_boundary_index  \
# count      1400.000000  1400.000000                  1400.000000
# mean          0.211580     0.097247                     6.880801
# std           0.187866     0.110682                     3.459666
# min           0.000000     0.000000                     0.500000
# 25%           0.056000     0.000000                     4.250000
# 50%           0.176500     0.071000                     6.362000
# 75%           0.333000     0.154000                     9.010500
# max           1.000000     0.750000                    33.000000
#
#        big_match_index
# count      1400.000000
# mean          0.054154
# std           0.094235
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.091000
# max           0.750000

# %%
batter = batting_records[['name','country','average','strike_rate','boundary_per_ball','boundary_index','finishing_index','runs_without_boundary_index','big_match_index']]

# %%
batter.describe()
# Out:
#            average  strike_rate  boundary_per_ball  boundary_index  \
# count  1400.000000  1400.000000        1400.000000     1400.000000
# mean     18.953021   109.212200           0.124407        1.722287
# std      10.228776    28.321358           0.057675        1.215380
# min       2.000000    25.000000           0.000000        0.000000
# 25%      11.500000    90.360000           0.087000        0.812000
# 50%      17.280000   110.320000           0.124000        1.500000
# 75%      24.285000   127.370000           0.161250        2.400000
# max      78.000000   228.350000           0.329000       11.750000
#
#        finishing_index  runs_without_boundary_index  big_match_index
# count      1400.000000                  1400.000000      1400.000000
# mean          0.211580                     6.880801         0.054154
# std           0.187866                     3.459666         0.094235
# min           0.000000                     0.500000         0.000000
# 25%           0.056000                     4.250000         0.000000
# 50%           0.176500                     6.362000         0.000000
# 75%           0.333000                     9.010500         0.091000
# max           1.000000                    33.000000         0.750000

# %%
batter_for_clustering = batter.copy().drop(['name','country'],axis=1)
batter_for_clustering
# Out:
#       average  strike_rate  boundary_per_ball  boundary_index  \
# 0       32.48       139.55              0.189           3.829
# 1       32.66       136.71              0.187           4.185
# 2       51.50       137.67              0.163           4.382
# 3       29.84       134.69              0.201           4.109
# 4       34.69       144.87              0.204           4.337
# ...       ...          ...                ...             ...
# 1847     3.00        48.00              0.080           0.500
# 1868     2.75        29.72              0.054           0.500
# 1895     2.75        27.50              0.025           0.250
# 1941     2.25        32.14              0.000           0.000
# 1969     2.00        27.58              0.000           0.000
#
#       finishing_index  runs_without_boundary_index  big_match_index
# 0               0.128                       10.350            0.291
# 1               0.065                       10.750            0.222
# 2               0.281                       17.438            0.337
# 3               0.079                        9.149            0.218
# 4               0.112                       10.910            0.225
# ...               ...                          ...              ...
# 1847            0.000                        1.000            0.000
# 1868            0.000                        0.750            0.000
# 1895            0.000                        1.750            0.000
# 1941            0.000                        2.250            0.000
# 1969            0.000                        2.000            0.000
#
# [1400 rows x 7 columns]

# %%
batting_records['prelim_metric'] = np.round((batting_records['average'] * batting_records['strike_rate']) / 100,3)

# %%
batting_records[['name','country','runs','average','strike_rate','prelim_metric']]
# Out:
#                  name country  runs  average  strike_rate  prelim_metric
# 0           RG Sharma   INDIA  3313    32.48       139.55         45.326
# 1          MJ Guptill      NZ  3299    32.66       136.71         44.649
# 2             V Kohli   INDIA  3296    51.50       137.67         70.900
# 3         PR Stirling     IRE  2776    29.84       134.69         40.191
# 4            AJ Finch     AUS  2741    34.69       144.87         50.255
# ...               ...     ...   ...      ...          ...            ...
# 1847          H Helva     TKY    12     3.00        48.00          1.440
# 1868  Apon Mustafizur     SRB    11     2.75        29.72          0.817
# 1895          W Uisuk    THAI    11     2.75        27.50          0.756
# 1941      I Katzarski     BUL     9     2.25        32.14          0.723
# 1969       JD Freyone    GIBR     8     2.00        27.58          0.552
#
# [1400 rows x 6 columns]

# %%
batting_records[['name','country','runs','average','strike_rate','prelim_metric']].describe()
# Out:
#               runs      average  strike_rate  prelim_metric
# count  1400.000000  1400.000000  1400.000000    1400.000000
# mean    275.316429    18.953021   109.212200      22.383954
# std     409.096720    10.228776    28.321358      15.956009
# min       8.000000     2.000000    25.000000       0.552000
# 25%      61.000000    11.500000    90.360000      10.897250
# 50%     126.500000    17.280000   110.320000      18.911500
# 75%     300.500000    24.285000   127.370000      29.630000
# max    3313.000000    78.000000   228.350000     124.995000

# %%
batting_records.loc[((batting_records['prelim_metric'] > 30) & (batting_records.runs >= 500)), 'pre-rank'] = 'Best'
batting_records.loc[((batting_records['prelim_metric'] > 30) & (batting_records.runs < 500)), 'pre-rank'] = 'Good'
batting_records.loc[((batting_records['prelim_metric'] > 20) & (batting_records['prelim_metric'] < 30) ), 'pre-rank'] = 'Good'
batting_records.loc[((batting_records['prelim_metric'] > 10) & (batting_records['prelim_metric'] < 20)), 'pre-rank'] = 'Average'
batting_records.loc[((batting_records['prelim_metric'] < 10)), 'pre-rank'] = 'Poor'
batting_records.loc[(batting_records.runs < 100), 'pre-rank'] = 'Poor'

# %%
batting_records['pre-rank'].value_counts()
# Out:
# pre-rank
# Poor       604
# Good       456
# Average    209
# Best       131
# Name: count, dtype: int64

# %%
batter['prelim_metric'] = batting_records['prelim_metric']
batter['pre-rank'] = batting_records['pre-rank']

# %%
batting_test = batter.sample(frac = 0.070 , random_state= 25)

# %%
batting_test.shape
# Out:
# (98, 11)

# %%
batting_train = batter.drop(batting_test.index)

# %%
batting_train.shape
# Out:
# (1302, 11)

# %%
batting_test['pre-rank'].value_counts()
# Out:
# pre-rank
# Poor       50
# Good       29
# Best       10
# Average     9
# Name: count, dtype: int64

# %%
from pathlib import Path
filepath_batter_for_clustering = Path('batter_for_clustering.csv') 
batting_train.to_csv(filepath_batter_for_clustering,index=False)

filepath_batter_for_clustering = Path('batter_test.csv') 
batting_test.to_csv(filepath_batter_for_clustering,index=False)

# %%
from sklearn import metrics
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering

# %%
columns = batter_for_clustering.columns.tolist()

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# #### Normal Data

# %%
wcss = []
for i in range(1,11,1):
  model = KMeans(i).fit(batter_for_clustering)
  wcss.append(model.inertia_)
plt.plot(np.arange(1,11,1),wcss)
plt.show()

# %%
plt.figure(figsize=(17,8)) 
sns.boxplot(data=batter_for_clustering)
plt.show()

# %%
batter_for_clustering.describe()
# Out:
#            average  strike_rate  boundary_per_ball  boundary_index  \
# count  1400.000000  1400.000000        1400.000000     1400.000000
# mean     18.953021   109.212200           0.124407        1.722287
# std      10.228776    28.321358           0.057675        1.215380
# min       2.000000    25.000000           0.000000        0.000000
# 25%      11.500000    90.360000           0.087000        0.812000
# 50%      17.280000   110.320000           0.124000        1.500000
# 75%      24.285000   127.370000           0.161250        2.400000
# max      78.000000   228.350000           0.329000       11.750000
#
#        finishing_index  runs_without_boundary_index  big_match_index
# count      1400.000000                  1400.000000      1400.000000
# mean          0.211580                     6.880801         0.054154
# std           0.187866                     3.459666         0.094235
# min           0.000000                     0.500000         0.000000
# 25%           0.056000                     4.250000         0.000000
# 50%           0.176500                     6.362000         0.000000
# 75%           0.333000                     9.010500         0.091000
# max           1.000000                    33.000000         0.750000

# %%
fig = plt.figure(figsize = (15,10))
ax = fig.gca()
batter_for_clustering.hist(ax=ax)
plt.show()

# %%
range_n_clusters = [2, 3, 4, 5, 6,7,8,9,10]

for n_clusters in range_n_clusters:

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(batter_for_clustering)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(batter_for_clustering, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.48417489242592493
# For n_clusters = 3 The average silhouette_score is : 0.427172910577394
# For n_clusters = 4 The average silhouette_score is : 0.4024804879697247
# For n_clusters = 5 The average silhouette_score is : 0.3789989308176317
# For n_clusters = 6 The average silhouette_score is : 0.3444540325515059
# For n_clusters = 7 The average silhouette_score is : 0.357821615640624
# For n_clusters = 8 The average silhouette_score is : 0.3483541756340547
# For n_clusters = 9 The average silhouette_score is : 0.34324441928612115
# For n_clusters = 10 The average silhouette_score is : 0.3518694987033261

# %%
corr_normal = batter_for_clustering.corr()
plt.figure(figsize = (10,6))
sns.heatmap(corr_normal,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
batter_std_Scaler= scaler.fit_transform(batter_for_clustering)

batter_std_Scaler = pd.DataFrame(batter_std_Scaler,columns = columns)
batter_std_Scaler
# Out:
#        average  strike_rate  boundary_per_ball  boundary_index  \
# 0     1.322916     1.071581           1.120355        1.733997
# 1     1.340520     0.971268           1.085666        2.027014
# 2     3.183040     1.005177           0.669388        2.189162
# 3     1.064728     0.899918           1.328494        1.964460
# 4     1.539050     1.259493           1.380528        2.152123
# ...        ...          ...                ...             ...
# 1395 -1.560179    -2.162116          -0.770237       -1.006042
# 1396 -1.584629    -2.807796          -1.221203       -1.006042
# 1397 -1.584629    -2.886210          -1.724205       -1.211813
# 1398 -1.633528    -2.722318          -2.157827       -1.417583
# 1399 -1.657977    -2.883385          -2.157827       -1.417583
#
#       finishing_index  runs_without_boundary_index  big_match_index
# 0           -0.445051                     1.003114         2.514264
# 1           -0.780516                     1.118773         1.781788
# 2            0.369651                     3.052598         3.002581
# 3           -0.705968                     0.655846         1.739326
# 4           -0.530248                     1.165037         1.813635
# ...               ...                          ...              ...
# 1395        -1.126631                    -1.700425        -0.574872
# 1396        -1.126631                    -1.772712        -0.574872
# 1397        -1.126631                    -1.483563        -0.574872
# 1398        -1.126631                    -1.338989        -0.574872
# 1399        -1.126631                    -1.411276        -0.574872
#
# [1400 rows x 7 columns]

# %%
batter_std_Scaler.describe()
# Out:
#            average   strike_rate  boundary_per_ball  boundary_index  \
# count  1400.000000  1.400000e+03       1.400000e+03    1.400000e+03
# mean      0.000000 -3.654220e-16      -1.624098e-16   -2.436147e-16
# std       1.000357  1.000357e+00       1.000357e+00    1.000357e+00
# min      -1.657977 -2.974515e+00      -2.157827e+00   -1.417583e+00
# 25%      -0.728893 -6.658910e-01      -6.488224e-01   -7.492409e-01
# 50%      -0.163619  3.912933e-02      -7.061844e-03   -1.829605e-01
# 75%       0.521459  6.413636e-01       6.390349e-01    5.578132e-01
# max       5.774696  4.208145e+00       3.548638e+00    8.253629e+00
#
#        finishing_index  runs_without_boundary_index  big_match_index
# count     1.400000e+03                 1.400000e+03      1400.000000
# mean      4.060244e-17                -1.624098e-16         0.000000
# std       1.000357e+00                 1.000357e+00         1.000357
# min      -1.126631e+00                -1.844999e+00        -0.574872
# 25%      -8.284395e-01                -7.606921e-01        -0.574872
# 50%      -1.867956e-01                -1.500105e-01        -0.574872
# 75%       6.465428e-01                 6.157994e-01         0.391146
# max       4.198215e+00                 7.552328e+00         7.386818

# %%
plt.figure(figsize=(17,8)) 
sns.boxplot(data=batter_std_Scaler)
plt.show()

# %%
fig = plt.figure(figsize = (15,10))
ax = fig.gca()
batter_std_Scaler.hist(ax=ax)
plt.show()

# %%
wcss = []
for i in range(1,11,1):
  model = KMeans(i).fit(batter_std_Scaler)
  wcss.append(model.inertia_)
plt.plot(np.arange(1,11,1),wcss)
plt.show()

# %%
range_n_clusters = [2, 3, 4, 5, 6,7,8,9,10]

for n_clusters in range_n_clusters:

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(batter_std_Scaler)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(batter_std_Scaler, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.3355473743615212
# For n_clusters = 3 The average silhouette_score is : 0.23899198903287447
# For n_clusters = 4 The average silhouette_score is : 0.25166139999326764
# For n_clusters = 5 The average silhouette_score is : 0.24410982878124782
# For n_clusters = 6 The average silhouette_score is : 0.22791586145451412
# For n_clusters = 7 The average silhouette_score is : 0.22494892935073754
# For n_clusters = 8 The average silhouette_score is : 0.22218877416584526
# For n_clusters = 9 The average silhouette_score is : 0.22115850840070725
# For n_clusters = 10 The average silhouette_score is : 0.2220549963493807

# %%
corr_std_scaler = batter_std_Scaler.corr()
plt.figure(figsize = (10,6))
sns.heatmap(corr_std_scaler,annot=True)
# Out:
# <Axes: >
