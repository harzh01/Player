# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_samples, silhouette_score, calinski_harabasz_score
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from itertools import product
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
  
pd.set_option('display.max_rows', 15)
np.random.seed(5)

import warnings
warnings.filterwarnings('ignore')

sns.set()

# %%
batter = pd.read_csv('batter_for_clustering.csv')

# %%
batter
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 0           RG Sharma   INDIA    32.48       139.55              0.189
# 1          MJ Guptill      NZ    32.66       136.71              0.187
# 2             V Kohli   INDIA    51.50       137.67              0.163
# 3         PR Stirling     IRE    29.84       134.69              0.201
# 4            AJ Finch     AUS    34.69       144.87              0.204
# ...               ...     ...      ...          ...                ...
# 1297          H Helva     TKY     3.00        48.00              0.080
# 1298  Apon Mustafizur     SRB     2.75        29.72              0.054
# 1299          W Uisuk    THAI     2.75        27.50              0.025
# 1300      I Katzarski     BUL     2.25        32.14              0.000
# 1301       JD Freyone    GIBR     2.00        27.58              0.000
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 0              3.829            0.128                       10.350
# 1              4.185            0.065                       10.750
# 2              4.382            0.281                       17.438
# 3              4.109            0.079                        9.149
# 4              4.337            0.112                       10.910
# ...              ...              ...                          ...
# 1297           0.500            0.000                        1.000
# 1298           0.500            0.000                        0.750
# 1299           0.250            0.000                        1.750
# 1300           0.000            0.000                        2.250
# 1301           0.000            0.000                        2.000
#
#       big_match_index  prelim_metric pre-rank
# 0               0.291         45.326     Best
# 1               0.222         44.649     Best
# 2               0.337         70.900     Best
# 3               0.218         40.191     Best
# 4               0.225         50.255     Best
# ...               ...            ...      ...
# 1297            0.000          1.440     Poor
# 1298            0.000          0.817     Poor
# 1299            0.000          0.756     Poor
# 1300            0.000          0.723     Poor
# 1301            0.000          0.552     Poor
#
# [1302 rows x 11 columns]

# %%
batter_for_clustering = batter.copy().drop(['name','country','prelim_metric','pre-rank'],axis=1)
batter_for_clustering
# Out:
#       average  strike_rate  boundary_per_ball  boundary_index  \
# 0       32.48       139.55              0.189           3.829
# 1       32.66       136.71              0.187           4.185
# 2       51.50       137.67              0.163           4.382
# 3       29.84       134.69              0.201           4.109
# 4       34.69       144.87              0.204           4.337
# ...       ...          ...                ...             ...
# 1297     3.00        48.00              0.080           0.500
# 1298     2.75        29.72              0.054           0.500
# 1299     2.75        27.50              0.025           0.250
# 1300     2.25        32.14              0.000           0.000
# 1301     2.00        27.58              0.000           0.000
#
#       finishing_index  runs_without_boundary_index  big_match_index
# 0               0.128                       10.350            0.291
# 1               0.065                       10.750            0.222
# 2               0.281                       17.438            0.337
# 3               0.079                        9.149            0.218
# 4               0.112                       10.910            0.225
# ...               ...                          ...              ...
# 1297            0.000                        1.000            0.000
# 1298            0.000                        0.750            0.000
# 1299            0.000                        1.750            0.000
# 1300            0.000                        2.250            0.000
# 1301            0.000                        2.000            0.000
#
# [1302 rows x 7 columns]

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
batter_for_clustering_scaled= scaler.fit_transform(batter_for_clustering)

# %%
columns = batter_for_clustering.columns.tolist()

# %%
batter_for_clustering_scaled = pd.DataFrame(batter_for_clustering_scaled,columns = columns)
batter_for_clustering_scaled
# Out:
#        average  strike_rate  boundary_per_ball  boundary_index  \
# 0     1.306106     1.077291           1.128480        1.723832
# 1     1.323618     0.976775           1.093709        2.016256
# 2     3.156513     1.010752           0.676458        2.178075
# 3     1.049267     0.905282           1.337106        1.953828
# 4     1.521111     1.265579           1.389262        2.141111
# ...        ...          ...                ...             ...
# 1297 -1.561929    -2.162907          -0.766536       -1.010660
# 1298 -1.586250    -2.809885          -1.218559       -1.010660
# 1299 -1.586250    -2.888457          -1.722737       -1.216014
# 1300 -1.634894    -2.724235          -2.157374       -1.421368
# 1301 -1.659216    -2.885625          -2.157374       -1.421368
#
#       finishing_index  runs_without_boundary_index  big_match_index
# 0           -0.439546                     0.981672         2.497986
# 1           -0.775858                     1.096572         1.769106
# 2            0.377209                     3.017696         2.983906
# 3           -0.701122                     0.636686         1.726852
# 4           -0.524959                     1.142532         1.800797
# ...               ...                          ...              ...
# 1297        -1.122845                    -1.704109        -0.575985
# 1298        -1.122845                    -1.775921        -0.575985
# 1299        -1.122845                    -1.488672        -0.575985
# 1300        -1.122845                    -1.345047        -0.575985
# 1301        -1.122845                    -1.416860        -0.575985
#
# [1302 rows x 7 columns]

# %%
batter_scaled = batter_for_clustering_scaled.copy()
batter_scaled['name'] = batter['name']
batter_scaled['country'] = batter['country']

cols = batter_scaled.columns.tolist()
cols = cols[-2:] + cols[:-2]


batter_scaled = batter_scaled [cols]
batter_scaled
# Out:
#                  name country   average  strike_rate  boundary_per_ball  \
# 0           RG Sharma   INDIA  1.306106     1.077291           1.128480
# 1          MJ Guptill      NZ  1.323618     0.976775           1.093709
# 2             V Kohli   INDIA  3.156513     1.010752           0.676458
# 3         PR Stirling     IRE  1.049267     0.905282           1.337106
# 4            AJ Finch     AUS  1.521111     1.265579           1.389262
# ...               ...     ...       ...          ...                ...
# 1297          H Helva     TKY -1.561929    -2.162907          -0.766536
# 1298  Apon Mustafizur     SRB -1.586250    -2.809885          -1.218559
# 1299          W Uisuk    THAI -1.586250    -2.888457          -1.722737
# 1300      I Katzarski     BUL -1.634894    -2.724235          -2.157374
# 1301       JD Freyone    GIBR -1.659216    -2.885625          -2.157374
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 0           1.723832        -0.439546                     0.981672
# 1           2.016256        -0.775858                     1.096572
# 2           2.178075         0.377209                     3.017696
# 3           1.953828        -0.701122                     0.636686
# 4           2.141111        -0.524959                     1.142532
# ...              ...              ...                          ...
# 1297       -1.010660        -1.122845                    -1.704109
# 1298       -1.010660        -1.122845                    -1.775921
# 1299       -1.216014        -1.122845                    -1.488672
# 1300       -1.421368        -1.122845                    -1.345047
# 1301       -1.421368        -1.122845                    -1.416860
#
#       big_match_index
# 0            2.497986
# 1            1.769106
# 2            2.983906
# 3            1.726852
# 4            1.800797
# ...               ...
# 1297        -0.575985
# 1298        -0.575985
# 1299        -0.575985
# 1300        -0.575985
# 1301        -0.575985
#
# [1302 rows x 9 columns]

# %% [markdown]
# # K-Means Clustering

# %%
wcss = []
for i in range(1,11,1):
  model = KMeans(i).fit(batter_for_clustering_scaled)
  wcss.append(model.inertia_)
plt.plot(np.arange(1,11,1),wcss)
plt.show()

# %%
range_n_clusters = [2, 3, 4, 5, 6,7,8,9,10]

for n_clusters in range_n_clusters:
    
    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(batter_for_clustering_scaled)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(batter_for_clustering_scaled, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.3340559865647996
# For n_clusters = 3 The average silhouette_score is : 0.23695239695255818
# For n_clusters = 4 The average silhouette_score is : 0.2548365498035142
# For n_clusters = 5 The average silhouette_score is : 0.24528633596344346
# For n_clusters = 6 The average silhouette_score is : 0.22727556485541975
# For n_clusters = 7 The average silhouette_score is : 0.22527092167383234
# For n_clusters = 8 The average silhouette_score is : 0.2275675789199521
# For n_clusters = 9 The average silhouette_score is : 0.224139919524574
# For n_clusters = 10 The average silhouette_score is : 0.21730372843114565

# %%
kmodel =  KMeans(n_clusters=4)
ypred_kmeans = kmodel.fit_predict(batter_for_clustering_scaled)

# %%
ypred_kmeans
# Out:
# array([3, 3, 3, ..., 1, 1, 1])

# %%
print('Silhouette score :',np.round(silhouette_score(batter_for_clustering_scaled, ypred_kmeans, metric='euclidean'),3))
print('Calinski-Harabasz Index :',np.round(metrics.calinski_harabasz_score(batter_for_clustering_scaled, ypred_kmeans),3))
print('Davies-Bouldin Index  :',np.round(metrics.davies_bouldin_score(batter_for_clustering_scaled, ypred_kmeans),3))
# Out:
# Silhouette score : 0.253
# Calinski-Harabasz Index : 525.024
# Davies-Bouldin Index  : 1.291

# %%
results = batter_scaled
results['kmeans'] = ypred_kmeans

# %%
results
# Out:
#                  name country   average  strike_rate  boundary_per_ball  \
# 0           RG Sharma   INDIA  1.306106     1.077291           1.128480
# 1          MJ Guptill      NZ  1.323618     0.976775           1.093709
# 2             V Kohli   INDIA  3.156513     1.010752           0.676458
# 3         PR Stirling     IRE  1.049267     0.905282           1.337106
# 4            AJ Finch     AUS  1.521111     1.265579           1.389262
# ...               ...     ...       ...          ...                ...
# 1297          H Helva     TKY -1.561929    -2.162907          -0.766536
# 1298  Apon Mustafizur     SRB -1.586250    -2.809885          -1.218559
# 1299          W Uisuk    THAI -1.586250    -2.888457          -1.722737
# 1300      I Katzarski     BUL -1.634894    -2.724235          -2.157374
# 1301       JD Freyone    GIBR -1.659216    -2.885625          -2.157374
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 0           1.723832        -0.439546                     0.981672
# 1           2.016256        -0.775858                     1.096572
# 2           2.178075         0.377209                     3.017696
# 3           1.953828        -0.701122                     0.636686
# 4           2.141111        -0.524959                     1.142532
# ...              ...              ...                          ...
# 1297       -1.010660        -1.122845                    -1.704109
# 1298       -1.010660        -1.122845                    -1.775921
# 1299       -1.216014        -1.122845                    -1.488672
# 1300       -1.421368        -1.122845                    -1.345047
# 1301       -1.421368        -1.122845                    -1.416860
#
#       big_match_index  kmeans
# 0            2.497986       3
# 1            1.769106       3
# 2            2.983906       3
# 3            1.726852       3
# 4            1.800797       3
# ...               ...     ...
# 1297        -0.575985       1
# 1298        -0.575985       1
# 1299        -0.575985       1
# 1300        -0.575985       1
# 1301        -0.575985       1
#
# [1302 rows x 10 columns]

# %%
results['kmeans'].value_counts()
# Out:
# kmeans
# 1    458
# 0    431
# 2    292
# 3    121
# Name: count, dtype: int64

# %%
plt.pie(results['kmeans'].value_counts(), colors= sns.color_palette('pastel'), autopct='%.0f%%', labels = ['Less Contribution Batters','Floaters','Finishers','Specialist Batters'])
plt.show()

# %%
np.round(kmodel.cluster_centers_,3)
# Out:
# array([[ 0.406,  0.239,  0.263,  0.538, -0.469,  0.659,  0.283],
#        [-0.799, -0.989, -0.945, -0.842,  0.081, -0.564, -0.56 ],
#        [-0.115,  0.729,  0.617, -0.29 ,  0.666, -0.663, -0.466],
#        [ 1.856,  1.134,  1.15 ,  1.972, -0.241,  1.387,  2.237]])

# %%
columns = batter_for_clustering_scaled.columns
columns
# Out:
# Index(['average', 'strike_rate', 'boundary_per_ball', 'boundary_index',
#        'finishing_index', 'runs_without_boundary_index', 'big_match_index'],
#       dtype='object')

# %%
cluster_center = pd.DataFrame(data=np.round(kmodel.cluster_centers_,3) , columns = columns, index=('Floaters','Less Contribution Batters','Finishers','Specialist Batters'))
cluster_center['No. of Batters'] = [431,458,292,121]

cols = cluster_center.columns.tolist()
cols = cols[-1:] + cols[:-1]


cluster_center = cluster_center [cols]
cluster_center
# Out:
#                            No. of Batters  average  strike_rate  \
# Floaters                              431    0.406        0.239
# Less Contribution Batters             458   -0.799       -0.989
# Finishers                             292   -0.115        0.729
# Specialist Batters                    121    1.856        1.134
#
#                            boundary_per_ball  boundary_index  finishing_index  \
# Floaters                               0.263           0.538           -0.469
# Less Contribution Batters             -0.945          -0.842            0.081
# Finishers                              0.617          -0.290            0.666
# Specialist Batters                     1.150           1.972           -0.241
#
#                            runs_without_boundary_index  big_match_index
# Floaters                                         0.659            0.283
# Less Contribution Batters                       -0.564           -0.560
# Finishers                                       -0.663           -0.466
# Specialist Batters                               1.387            2.237

# %%
top10countries = ['INDIA','ENG','PAK','SA','NZ','AUS','WI','SL','BAN','AFG']

# %%
results[(results.country.isin(top10countries)) & (results['kmeans'] == 3)].head(7)
# Out:
#          name country   average  strike_rate  boundary_per_ball  \
# 0   RG Sharma   INDIA  1.306106     1.077291           1.128480
# 1  MJ Guptill      NZ  1.323618     0.976775           1.093709
# 2     V Kohli   INDIA  3.156513     1.010752           0.676458
# 4    AJ Finch     AUS  1.521111     1.265579           1.389262
# 5  Babar Azam     PAK  2.574734     0.719471           0.519988
# 6   DA Warner     AUS  1.331401     1.110206           1.180636
# 9  JC Buttler     ENG  1.503599     1.134273           0.989396
#
#    boundary_index  finishing_index  runs_without_boundary_index  \
# 0        1.723832        -0.439546                     0.981672
# 1        2.016256        -0.775858                     1.096572
# 2        2.178075         0.377209                     3.017696
# 4        2.141111        -0.524959                     1.142532
# 5        2.388357        -0.348796                     3.512052
# 6        1.836366        -0.514282                     1.142245
# 9        1.391980         0.078266                     1.110934
#
#    big_match_index  kmeans
# 0         2.497986       3
# 1         1.769106       3
# 2         2.983906       3
# 4         1.800797       3
# 5         3.712786       3
# 6         2.181082       3
# 9         1.663472       3

# %%
results[(results.country.isin(top10countries)) & (results['kmeans'] == 2)].head(10)
# Out:
#               name country   average  strike_rate  boundary_per_ball  \
# 48   Shahid Afridi     PAK -0.110400     1.447144           1.076323
# 59     NLTC Perera      SL  0.398414     1.504834           1.163251
# 110     AD Russell      WI  0.043315     1.659500           1.650044
# 135         MM Ali     ENG -0.031597     0.986331           0.902469
# 136       D Ramdin      WI -0.034515     0.223266           0.050581
# 155      DJG Sammy      WI -0.174609     1.357954           1.163251
# 161      JA Morkel      SA  0.206758     1.173912           0.780771
# 166     MP Stoinis     AUS  0.894580     1.075521           1.024167
# 167  Gulbadin Naib     AFG -0.024787     0.367314           0.311363
# 171      HH Pandya   INDIA  0.138656     1.315837           0.885083
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 48         0.167250        -0.418193                    -0.204668
# 59         0.265819         0.462622                    -0.174794
# 110        0.077715         0.654799                    -0.978517
# 135        0.109750         0.088943                    -0.391954
# 136       -0.271386         0.585402                    -0.164453
# 155       -0.220459         0.724197                    -0.770549
# 161        0.048144         0.419915                    -0.313248
# 166        0.420245         0.980434                     0.019387
# 167       -0.141603         0.489313                    -0.348005
# 171        0.084287         0.211723                    -0.196050
#
#      big_match_index  kmeans
# 48         -0.111192       2
# 59         -0.142883       2
# 110        -0.385843       2
# 135         0.385291       2
# 136        -0.364716       2
# 155        -0.575985       2
# 161        -0.575985       2
# 166        -0.259081       2
# 167        -0.333025       2
# 171        -0.575985       2

# %%
results[(results.country.isin(top10countries)) & (results['kmeans'] == 0)].head(10)
# Out:
#                name country   average  strike_rate  boundary_per_ball  \
# 7        EJG Morgan     ENG  0.926685     0.957663           0.798156
# 8      Shoaib Malik     PAK  1.182551     0.584979           0.224435
# 13      Mahmudullah     BAN  0.464569     0.323427           0.067966
# 16      LRPL Taylor      NZ  0.690276     0.469245          -0.018961
# 17  Shakib Al Hasan     BAN  0.329340     0.377224           0.363519
# 19       TM Dilshan      SL  0.888743     0.404476           0.676458
# 22        DA Miller      SA  1.248706     1.115161           0.554759
# 23         S Dhawan   INDIA  0.862475     0.610461           0.850312
# 24      Tamim Iqbal     BAN  0.488891     0.277770           0.537374
# 27       Umar Akmal     PAK  0.675683     0.481986           0.085352
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 7         0.927880        -0.076544                     0.677188
# 8         0.539351         0.462622                     1.209748
# 13        0.237070         0.024883                     0.736074
# 16        0.256784         0.067589                     1.061528
# 17        0.576314        -0.562327                     0.754171
# 19        1.240840        -0.311428                     0.913881
# 22        0.538529         0.612093                     0.901817
# 23        1.578441        -0.882623                     1.033377
# 24        1.032200        -0.781196                     0.719126
# 27        0.419424        -0.177971                     1.179300
#
#     big_match_index  kmeans
# 7          0.807830       0
# 8          0.279656       0
# 13         0.015569       0
# 16         0.205712       0
# 17         0.427545       0
# 19         1.431075       0
# 22         0.184585       0
# 23         1.188115       0
# 24         0.638814       0
# 27         0.490926       0

# %%
results[(results.country.isin(top10countries)) & (results['kmeans'] == 1)].head(15)
# Out:
#                  name country   average  strike_rate  boundary_per_ball  \
# 285      WIA Fernando      SL -0.686341    -0.512194          -0.540525
# 324       NL McCullum      NZ -0.734985    -0.298776          -0.575296
# 354      BR McDermott     AUS -0.314703    -0.521396          -0.696994
# 355        MV Boucher      SA -0.116237    -0.412740          -0.644838
# 399       Nurul Hasan     BAN -0.640616     0.113548          -0.349285
# 404          AT Carey     AUS -0.774873    -0.026253          -0.053732
# 432      Mahedi Hasan     BAN -0.618240    -0.238962          -0.418827
# 456        DL Vettori      NZ -0.607539    -0.043241          -0.696994
# 463  Mosaddek Hossain     BAN  0.091958    -0.116504          -0.592682
# 474        Fawad Alam     PAK -0.138613     0.200968          -0.714380
# 525         LPC Silva      SL -0.544302    -0.362483          -0.001576
# 538        GD Elliott      NZ -0.341944    -0.007141          -0.610067
# 564       JP Faulkner     AUS -0.447987     0.215833          -0.644838
# 622        SL Malinga      SL -1.224341    -0.872137          -0.644838
# 646         PG Fulton      NZ -0.731094    -0.651287          -0.540525
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 285       -0.517811        -0.765181                    -0.172208
# 324       -0.880055         0.830962                    -0.765378
# 354       -0.482490        -0.108574                     0.156118
# 355       -0.482490         0.403901                     0.306636
# 399       -0.726450         0.313150                    -0.433605
# 404       -0.599953        -0.097897                    -0.720855
# 432       -0.671416         0.270444                    -0.542760
# 456       -0.824199         0.334503                    -0.202657
# 463       -0.490704         0.654799                     0.306636
# 474       -0.744522         0.761565                     0.103838
# 525       -0.216351        -0.412855                    -0.440212
# 538       -0.654987         0.302473                     0.134287
# 564       -0.873484         0.953743                    -0.379602
# 622       -1.073088         0.820286                    -1.382103
# 646       -0.531775        -0.679769                    -0.483299
#
#      big_match_index  kmeans
# 285        -0.575985       1
# 324        -0.575985       1
# 354        -0.068938       1
# 355        -0.575985       1
# 399        -0.575985       1
# 404        -0.575985       1
# 432        -0.575985       1
# 456        -0.575985       1
# 463        -0.575985       1
# 474        -0.575985       1
# 525        -0.575985       1
# 538        -0.575985       1
# 564        -0.575985       1
# 622        -0.575985       1
# 646        -0.575985       1

# %%
results = np.round(results,3)

# %% [markdown]
# # Defining accuracy Metrics

# %%
def get_accuracy_metrics(y_pred,y_test):

  bal_acc = metrics.balanced_accuracy_score(y_test, y_pred)
  print ('The balanced accuracy on test data is %s' % (round(bal_acc,5)))

  f1_micro = metrics.f1_score(y_test, y_pred,average='micro')
  print('F1 score micro :',round(f1_micro ,5))

  f1_macro = metrics.f1_score(y_test, y_pred,average='macro')
  print('F1 score macro :',round(f1_macro ,5))

  f1_weighted = metrics.f1_score(y_test, y_pred,average='weighted')
  print('F1 score weighted :',round(f1_weighted,5))

  recall = metrics.recall_score(y_test, y_pred, average='macro')
  print('Recall score :',recall)

  precision = metrics.precision_score(y_test, y_pred, average='macro')
  print('Precision score :',precision)

  print('\n\n\n\n\n\n\n\n')

  confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
  sns.heatmap(confusion_matrix,annot=True, fmt="d",cmap="YlGnBu")

# %% [markdown]
# # Classification

# %% [markdown]
# ## Random Forest

# %%
X_train, X_test, y_train, y_test = train_test_split(results.drop('kmeans',axis=1), results['kmeans'], test_size=0.3, random_state=42)
X_train.drop(['name','country'],axis=1,inplace=True)
X_test.drop(['name','country'],axis=1,inplace=True)

# %%
X_train
# Out:
#       average  strike_rate  boundary_per_ball  boundary_index  \
# 1122   -0.525        0.819             -1.027          -1.186
# 438     0.469        0.588              0.694           0.669
# 579     0.245        1.228              1.320           1.043
# 842    -0.200        2.277              1.737          -0.418
# 1161   -1.173       -1.047             -0.575          -0.764
# ...       ...          ...                ...             ...
# 1095   -0.998       -0.476              0.485          -0.463
# 1130   -0.557       -0.850             -1.045          -0.805
# 1294   -1.513       -2.446             -2.157          -1.421
# 860    -0.845        0.003             -0.106          -0.929
# 1126   -0.881        1.381              1.059          -0.600
#
#       finishing_index  runs_without_boundary_index  big_match_index
# 1122            1.925                       -0.719           -0.576
# 438            -0.151                        0.437            0.385
# 579            -1.123                        0.019            0.935
# 842             1.247                       -1.002           -0.576
# 1161           -1.123                       -0.900           -0.576
# ...               ...                          ...              ...
# 1095           -0.231                       -1.321           -0.576
# 1130            0.212                       -0.268           -0.576
# 1294           -0.055                       -1.187           -0.576
# 860             1.370                       -1.245           -0.576
# 1126           -0.055                       -1.187           -0.576
#
# [911 rows x 7 columns]

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
ypred_rfc = rfc.predict(X_test)

# %%
fi_ovr = np.round(rfc.feature_importances_.tolist(),3)

# %%
dict_ovr = dict(zip(columns,np.array(fi_ovr)))
dict_ovr
# Out:
# {'average': 0.154,
#  'strike_rate': 0.178,
#  'boundary_per_ball': 0.153,
#  'boundary_index': 0.236,
#  'finishing_index': 0.079,
#  'runs_without_boundary_index': 0.12,
#  'big_match_index': 0.08}

# %%
get_accuracy_metrics(ypred_rfc,y_test)
# Out:
# The balanced accuracy on test data is 0.95165
# F1 score micro : 0.95652
# F1 score macro : 0.94968
# F1 score weighted : 0.95649
# Recall score : 0.9516501834074609
# Precision score : 0.9478370407217882

# %%
final_index = results.copy()

# %%
final_index['rfc_score'] = 0
for i in columns:
  final_index['rfc_score'] = np.round(final_index['rfc_score'] + (final_index[i] * dict_ovr.get(i)),3)

# %%
final_index[final_index.country.isin(top10countries)].sort_values('rfc_score',ascending = False).head(10)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 318        ML Hayden     AUS    3.140        1.232              1.911
# 2            V Kohli   INDIA    3.157        1.011              0.676
# 284        A Symonds     AUS    2.830        2.132              1.598
# 5         Babar Azam     PAK    2.575        0.719              0.520
# 148        DP Conway      NZ    3.026        1.070              0.937
# 30   Mohammad Rizwan     PAK    3.046        0.698              0.520
# 271         SA Yadav   INDIA    1.940        1.998              2.102
# 58          DJ Malan     ENG    2.164        0.994              1.094
# 20          KL Rahul   INDIA    2.104        1.181              1.042
# 420       MN van Wyk      SA    1.794        1.210              1.494
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 318           3.142            0.655                        0.626
# 2             2.178            0.377                        3.018
# 284           1.790            0.820                        1.795
# 5             2.388           -0.349                        3.512
# 148           2.299            0.447                        2.469
# 30            2.211            0.302                        2.924
# 271           2.138            0.212                        0.474
# 58            2.545           -0.359                        1.956
# 20            2.323           -0.402                        2.080
# 420           2.451           -0.359                        0.676
#
#      big_match_index  kmeans  rfc_score
# 318            4.114       3      2.193
# 2              2.984       3      1.914
# 284            1.347       3      1.869
# 5              3.713       3      1.859
# 148            1.906       3      1.825
# 30             2.942       3      1.805
# 271            2.942       3      1.791
# 58             3.343       3      1.752
# 20             3.491       3      1.738
# 420            3.956       3      1.667

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
ypred_knn = knn.predict(X_test)

# %%
get_accuracy_metrics(ypred_knn,y_test)
# Out:
# The balanced accuracy on test data is 0.93795
# F1 score micro : 0.94629
# F1 score macro : 0.94039
# F1 score weighted : 0.94638
# Recall score : 0.9379523939528994
# Precision score : 0.9430932379006809

# %% [markdown]
# ## XGBoost

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
ypred_xgb = xgb.predict(X_test)

# %%
get_accuracy_metrics(ypred_xgb,y_test)
# Out:
# The balanced accuracy on test data is 0.94376
# F1 score micro : 0.95141
# F1 score macro : 0.93975
# F1 score weighted : 0.9516
# Recall score : 0.9437631911329811
# Precision score : 0.9360322302377215

# %%
importance = np.round(xgb.feature_importances_,3)
dict_xgb = dict(zip(columns,importance))
dict_xgb
# Out:
# {'average': 0.083,
#  'strike_rate': 0.274,
#  'boundary_per_ball': 0.076,
#  'boundary_index': 0.25,
#  'finishing_index': 0.042,
#  'runs_without_boundary_index': 0.114,
#  'big_match_index': 0.161}

# %%
final_index['xgb_score'] = 0
for i in columns:
  final_index['xgb_score'] = np.round(final_index['xgb_score'] + (final_index[i] * dict_xgb.get(i)),3)

# %%
final_index[final_index.country.isin(top10countries)].sort_values('xgb_score',ascending = False).head(10).drop(['rfc_score'],axis=1)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 318        ML Hayden     AUS    3.140        1.232              1.911
# 5         Babar Azam     PAK    2.575        0.719              0.520
# 2            V Kohli   INDIA    3.157        1.011              0.676
# 20          KL Rahul   INDIA    2.104        1.181              1.042
# 271         SA Yadav   INDIA    1.940        1.998              2.102
# 58          DJ Malan     ENG    2.164        0.994              1.094
# 420       MN van Wyk      SA    1.794        1.210              1.494
# 30   Mohammad Rizwan     PAK    3.046        0.698              0.520
# 284        A Symonds     AUS    2.830        2.132              1.598
# 148        DP Conway      NZ    3.026        1.070              0.937
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 318           3.142            0.655                        0.626
# 5             2.388           -0.349                        3.512
# 2             2.178            0.377                        3.018
# 20            2.323           -0.402                        2.080
# 271           2.138            0.212                        0.474
# 58            2.545           -0.359                        1.956
# 420           2.451           -0.359                        0.676
# 30            2.211            0.302                        2.924
# 284           1.790            0.820                        1.795
# 148           2.299            0.447                        2.469
#
#      big_match_index  kmeans  xgb_score
# 318            4.114       3      2.291
# 5              3.713       3      2.031
# 2              2.984       3      1.974
# 20             3.491       3      1.941
# 271            2.942       3      1.939
# 58             3.343       3      1.917
# 420            3.956       3      1.907
# 30             2.942       3      1.857
# 284            1.347       3      1.844
# 148            1.906       3      1.797

# %% [markdown]
# ## Voting  Ensembles

# %%
xgb = XGBClassifier()
dtree = DecisionTreeClassifier(random_state=42)
rfc = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
voting = VotingClassifier(
    estimators=[('random_forest', rfc), ('xg_boost', xgb), ('decision_tree', dtree)],
    voting='hard')

# %%
voting.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('random_forest',
#                               RandomForestClassifier(n_jobs=-1,
#                                                      random_state=42)),
#                              ('xg_boost',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             grow_...
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             random_state=None, ...)),
#                              ('decision_tree',
#                               DecisionTreeClassifier(random_state=42))])

# %%
for clf in (rfc,dtree,xgb,voting):
  clf.fit(X_train,y_train)
  y_pred = clf.predict(X_test)
  print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# RandomForestClassifier 0.9539641943734015
# DecisionTreeClassifier 0.9156010230179028
# XGBClassifier 0.9514066496163683
# VotingClassifier 0.9539641943734015

# %%
ypred_voting = voting.predict(X_test)

# %%
get_accuracy_metrics(ypred_voting,y_test)
# Out:
# The balanced accuracy on test data is 0.94678
# F1 score micro : 0.95396
# F1 score macro : 0.94512
# F1 score weighted : 0.95404
# Recall score : 0.9467752393257522
# Precision score : 0.9436446179457378

# %%
def compute_feature_importance(voting, weights):

    feature_importance = dict()
    for est in voting.estimators_:
        feature_importance[str(est)] = est.feature_importances_
    
    ## print(feature_importance.values())

    fe_scores = [0]*len(list(feature_importance.values())[0])

    ## print(fe_scores)
    for idx, imp_score in enumerate(feature_importance.values()):
        ## print(imp_score)
        imp_score_with_weight = imp_score*weights[idx]
        fe_scores = list(np.add(fe_scores, list(imp_score_with_weight)))
    return fe_scores

# %%
dict_voting = dict(zip(columns,np.round(compute_feature_importance(voting, [1/3,1/3,1/3]),3)))
dict_voting
# Out:
# {'average': 0.11,
#  'strike_rate': 0.242,
#  'boundary_per_ball': 0.083,
#  'boundary_index': 0.261,
#  'finishing_index': 0.057,
#  'runs_without_boundary_index': 0.125,
#  'big_match_index': 0.122}

# %%
final_index['voting_score'] = 0
for i in columns:
  final_index['voting_score'] = np.round(final_index['voting_score'] + (final_index[i] * dict_voting.get(i)),3)

# %%
final_index[final_index.country.isin(top10countries)].sort_values('voting_score',ascending = False).head(10).drop(['rfc_score','xgb_score'],axis=1)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 318        ML Hayden     AUS    3.140        1.232              1.911
# 5         Babar Azam     PAK    2.575        0.719              0.520
# 2            V Kohli   INDIA    3.157        1.011              0.676
# 20          KL Rahul   INDIA    2.104        1.181              1.042
# 58          DJ Malan     ENG    2.164        0.994              1.094
# 30   Mohammad Rizwan     PAK    3.046        0.698              0.520
# 284        A Symonds     AUS    2.830        2.132              1.598
# 271         SA Yadav   INDIA    1.940        1.998              2.102
# 148        DP Conway      NZ    3.026        1.070              0.937
# 420       MN van Wyk      SA    1.794        1.210              1.494
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 318           3.142            0.655                        0.626
# 5             2.388           -0.349                        3.512
# 2             2.178            0.377                        3.018
# 20            2.323           -0.402                        2.080
# 58            2.545           -0.359                        1.956
# 30            2.211            0.302                        2.924
# 284           1.790            0.820                        1.795
# 271           2.138            0.212                        0.474
# 148           2.299            0.447                        2.469
# 420           2.451           -0.359                        0.676
#
#      big_match_index  kmeans  voting_score
# 318            4.114       3         2.239
# 5              3.713       3         1.995
# 2              2.984       3         1.978
# 20             3.491       3         1.872
# 58             3.343       3         1.866
# 30             2.942       3         1.865
# 284            1.347       3         1.862
# 271            2.942       3         1.859
# 148            1.906       3         1.837
# 420            3.956       3         1.801

# %%
middle_ovr = pd.DataFrame()

# %% [markdown]
# # One against all

# %% [markdown]
# ## For 0

# %%
results_new = results.copy()
results_new['kmeans'] = results_new.kmeans.map({1:0,2:0,3:0,0:1})
X_train, X_test, y_train, y_test = train_test_split(results_new.drop('kmeans',axis=1), results_new['kmeans'], test_size=0.3, random_state=42)
X_train.drop(['name','country'],axis=1,inplace=True)

# %%
rfc_0 = RandomForestClassifier()
rfc_0.fit(X_train, y_train)
ypred_rfc_0 = rfc.predict(X_test.drop(['name','country'],axis=1))
fi_0 = np.round(rfc_0.feature_importances_,3)
dict_0 = dict(zip(columns,fi_0))
dict_0
# Out:
# {'average': 0.171,
#  'strike_rate': 0.075,
#  'boundary_per_ball': 0.074,
#  'boundary_index': 0.276,
#  'finishing_index': 0.096,
#  'runs_without_boundary_index': 0.186,
#  'big_match_index': 0.122}

# %%
results_new[results_new.kmeans == 1]
# Out:
#              name country  average  strike_rate  boundary_per_ball  \
# 7      EJG Morgan     ENG    0.927        0.958              0.798
# 8    Shoaib Malik     PAK    1.183        0.585              0.224
# 13    Mahmudullah     BAN    0.465        0.323              0.068
# 14     KJ O'Brien     IRE    0.210        0.772              0.694
# 16    LRPL Taylor      NZ    0.690        0.469             -0.019
# ..            ...     ...      ...          ...                ...
# 960     M Bhanuka      SL   -0.297       -0.430             -0.315
# 970  Usman Waheed     KUW    0.221       -0.149             -0.158
# 971  N Wijesekera     AUT   -0.297        0.112             -0.627
# 976       M Dixit     LUX   -0.322       -0.534             -0.089
# 981       AN Cook     ENG   -0.370        0.136              1.059
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 7             0.928           -0.077                        0.677
# 8             0.539            0.463                        1.210
# 13            0.237            0.025                        0.736
# 14            0.548           -0.605                        0.298
# 16            0.257            0.068                        1.062
# ..              ...              ...                          ...
# 960           0.016           -1.123                        0.594
# 970           0.016            0.212                        0.450
# 971          -0.395           -1.123                        1.025
# 976           0.221           -1.123                       -0.052
# 981           0.632           -1.123                       -0.483
#
#      big_match_index  kmeans
# 7              0.808       1
# 8              0.280       1
# 13             0.016       1
# 14             0.142       1
# 16             0.206       1
# ..               ...     ...
# 960           -0.576       1
# 970           -0.576       1
# 971           -0.576       1
# 976           -0.576       1
# 981           -0.576       1
#
# [431 rows x 10 columns]

# %%
results_new['rbml_score'] = 0
for i in columns:
  results_new['rbml_score'] = np.round(results_new['rbml_score'] + (results_new[i] * dict_0.get(i)),3)

# %%
results_new[results_new.kmeans == 1].sort_values('rbml_score',ascending=False).head(10).drop(['kmeans'],axis=1)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 559         A McAuley     IOM    2.086       -0.366             -0.680
# 516         JP Inglis     AUS    1.629        1.289              0.816
# 682        DK Mathias     BHR    2.005       -0.033              0.364
# 334       AN Kervezee     NED    1.270        0.042             -0.506
# 270         TC Barker     LUX    1.000        0.464              0.068
# 178  RN ten Doeschate     NED    2.135        0.842             -0.158
# 116         MK Pandey   INDIA    2.457        0.603             -0.054
# 660   Mohammed Asghar     KUW    1.162        0.961              1.285
# 50      KC Sangakkara      SL    1.201        0.369              0.242
# 127          SJ Baard     NAM    1.086        0.196              0.120
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 559           0.879           -0.055                        3.983
# 516           1.454           -0.231                        2.269
# 682           1.864            0.212                        1.384
# 334           0.632           -0.589                        3.093
# 270           1.111           -1.123                        2.653
# 178           0.221            1.199                        1.893
# 116           0.272            1.626                        1.482
# 660           2.275           -1.123                        1.025
# 50            1.043           -0.215                        1.835
# 127           1.076           -0.482                        1.743
#
#      big_match_index  rbml_score
# 559           -0.576       1.189
# 516           -0.576       1.167
# 682           -0.576       1.089
# 334            1.537       1.063
# 270            1.188       1.048
# 178            0.797       1.041
# 116            0.385       1.015
# 660           -0.576       1.007
# 50             1.019       0.983
# 127            1.537       0.973

# %%
middle_ovr = results_new[results_new.kmeans == 1].copy()

# %% [markdown]
# ## For 1

# %%
results_new = results.copy()
results_new['kmeans'] = results_new.kmeans.map({1:1,2:0,3:0,0:0})
X_train, X_test, y_train, y_test = train_test_split(results_new.drop('kmeans',axis=1), results_new['kmeans'], test_size=0.3, random_state=42)
X_train.drop(['name','country'],axis=1,inplace=True)

# %%
rfc_1 = RandomForestClassifier()
rfc_1.fit(X_train, y_train)
ypred_rfc_1 = rfc.predict(X_test.drop(['name','country'],axis=1))
fi_1 = np.round(rfc_1.feature_importances_,3)
dict_1 = dict(zip(columns,fi_1))
dict_1
# Out:
# {'average': 0.152,
#  'strike_rate': 0.383,
#  'boundary_per_ball': 0.199,
#  'boundary_index': 0.161,
#  'finishing_index': 0.027,
#  'runs_without_boundary_index': 0.054,
#  'big_match_index': 0.025}

# %%
results_new[results_new.kmeans == 1]
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 258        Aizaz Khan     HKG   -0.492       -0.028             -0.506
# 275           L Siaka     PNG   -0.652       -0.173             -0.071
# 285      WIA Fernando      SL   -0.686       -0.512             -0.541
# 319      Waqas Barkat     HKG   -0.497       -0.599             -0.853
# 324       NL McCullum      NZ   -0.735       -0.299             -0.575
# ...               ...     ...      ...          ...                ...
# 1297          H Helva     TKY   -1.562       -2.163             -0.767
# 1298  Apon Mustafizur     SRB   -1.586       -2.810             -1.219
# 1299          W Uisuk    THAI   -1.586       -2.888             -1.723
# 1300      I Katzarski     BUL   -1.635       -2.724             -2.157
# 1301       JD Freyone    GIBR   -1.659       -2.886             -2.157
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 258           -0.648            0.132                       -0.099
# 275           -0.326           -0.765                       -0.364
# 285           -0.518           -0.765                       -0.172
# 319           -0.600           -0.482                        0.387
# 324           -0.880            0.831                       -0.765
# ...              ...              ...                          ...
# 1297          -1.011           -1.123                       -1.704
# 1298          -1.011           -1.123                       -1.776
# 1299          -1.216           -1.123                       -1.489
# 1300          -1.421           -1.123                       -1.345
# 1301          -1.421           -1.123                       -1.417
#
#       big_match_index  kmeans
# 258            -0.576       1
# 275            -0.576       1
# 285            -0.576       1
# 319            -0.576       1
# 324            -0.576       1
# ...               ...     ...
# 1297           -0.576       1
# 1298           -0.576       1
# 1299           -0.576       1
# 1300           -0.576       1
# 1301           -0.576       1
#
# [458 rows x 10 columns]

# %%
results_new['rbml_score'] = 0
for i in columns:
  results_new['rbml_score'] = np.round(results_new['rbml_score'] + (results_new[i] * dict_1.get(i)),3)

# %%
results_new[results_new.kmeans == 1].sort_values('rbml_score',ascending=False).head(10).drop(['kmeans'],axis=1)
# Out:
#                   name country  average  strike_rate  boundary_per_ball  \
# 474         Fawad Alam     PAK   -0.139        0.201             -0.714
# 1104     SE Rutherford      WI   -0.808        0.366             -0.228
# 463   Mosaddek Hossain     BAN    0.092       -0.117             -0.593
# 776            V Mbazo     BOT    0.034       -0.248             -0.506
# 994           DR Flynn      NZ   -0.706        0.232             -0.454
# 564        JP Faulkner     AUS   -0.448        0.216             -0.645
# 442             RG Aga   KENYA   -0.559       -0.016             -0.384
# 399        Nurul Hasan     BAN   -0.641        0.114             -0.349
# 728        Suraj Kumar     OMA   -0.676       -0.042             -0.089
# 445       Anwar Arudin     MAL   -0.877       -0.254              0.450
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 474           -0.745            0.762                        0.104
# 1104          -0.600           -1.123                       -0.483
# 463           -0.491            0.655                        0.307
# 776           -0.365            0.404                        0.430
# 994           -0.600           -1.123                       -0.210
# 564           -0.873            0.954                       -0.380
# 442           -0.509           -0.530                       -0.029
# 399           -0.726            0.313                       -0.434
# 728           -0.525           -0.151                       -0.555
# 445           -0.209           -1.123                       -0.993
#
#       big_match_index  rbml_score
# 474            -0.576      -0.193
# 1104           -0.576      -0.195
# 463            -0.576      -0.207
# 776            -0.576      -0.230
# 994            -0.576      -0.260
# 564            -0.576      -0.263
# 442             0.016      -0.265
# 399            -0.576      -0.268
# 728            -0.576      -0.270
# 445            -0.576      -0.272

# %%
middle_ovr = pd.concat([middle_ovr, results_new[results_new.kmeans == 1]], ignore_index=True)

# %% [markdown]
# ## For 2

# %%
results_new = results.copy()
results_new['kmeans'] = results_new.kmeans.map({1:0,2:1,3:0,0:0})
X_train, X_test, y_train, y_test = train_test_split(results_new.drop('kmeans',axis=1), results_new['kmeans'], test_size=0.3, random_state=42)
X_train.drop(['name','country'],axis=1,inplace=True)

# %%
rfc_2 = RandomForestClassifier()
rfc_2.fit(X_train, y_train)
ypred_rfc_2 = rfc.predict(X_test.drop(['name','country'],axis=1))
fi_2 = np.round(rfc_2.feature_importances_,3)
dict_2 = dict(zip(columns,fi_2))
dict_2
# Out:
# {'average': 0.084,
#  'strike_rate': 0.212,
#  'boundary_per_ball': 0.166,
#  'boundary_index': 0.149,
#  'finishing_index': 0.158,
#  'runs_without_boundary_index': 0.176,
#  'big_match_index': 0.055}

# %%
results_new[results_new.kmeans == 1]
# Out:
#                name country  average  strike_rate  boundary_per_ball  \
# 48    Shahid Afridi     PAK   -0.110        1.447              1.076
# 59      NLTC Perera      SL    0.398        1.505              1.163
# 86     E Chigumbura     ZIM   -0.005        1.115              0.972
# 110      AD Russell      WI    0.043        1.659              1.650
# 135          MM Ali     ENG   -0.032        0.986              0.902
# ...             ...     ...      ...          ...                ...
# 1186     D Wheatley     BHM   -1.051        0.166              0.833
# 1193   CE McConchie      NZ   -0.297        0.183             -0.297
# 1195    SNJ O'Keefe     AUS   -1.231        0.494              1.181
# 1198  R Abdulkareem     NGA   -0.346       -0.433              0.016
# 1201  GBW Munaweera     QAT   -0.346       -0.205             -0.419
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 48             0.167           -0.418                       -0.205
# 59             0.266            0.463                       -0.175
# 86             0.251           -0.263                       -0.293
# 110            0.078            0.655                       -0.979
# 135            0.110            0.089                       -0.392
# ...              ...              ...                          ...
# 1186          -0.600           -0.055                       -1.359
# 1193          -0.805            1.546                       -0.555
# 1195          -0.600           -1.123                       -1.417
# 1198          -0.600            1.546                       -0.914
# 1201          -0.929            2.080                       -0.900
#
#       big_match_index  kmeans
# 48             -0.111       1
# 59             -0.143       1
# 86             -0.006       1
# 110            -0.386       1
# 135             0.385       1
# ...               ...     ...
# 1186           -0.576       1
# 1193           -0.576       1
# 1195           -0.576       1
# 1198           -0.576       1
# 1201           -0.576       1
#
# [292 rows x 10 columns]

# %%
results_new['rbml_score'] = 0
for i in columns:
  results_new['rbml_score'] = np.round(results_new['rbml_score'] + (results_new[i] * dict_2.get(i)),3)

# %%
results_new[results_new.kmeans == 1].sort_values('rbml_score',ascending=False).head(10).drop(['kmeans'],axis=1)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 913    Khalid Ahmadi    BELG    1.697        3.121              3.476
# 762   Mohammed Nurji     MWI    3.059        2.197              1.963
# 731      Ritik Tomar   CZK-R    1.649        2.617              1.963
# 876    SC Kuggeleijn      NZ    0.068        3.695              3.476
# 591       R Shepherd      WI    2.880        1.635              1.354
# 536    Nouman Sarwar     QAT    3.724        0.894              0.833
# 631          VR Iyer   INDIA    1.381        1.879              2.085
# 922          DR Sams     AUS    0.481        2.844              2.415
# 697      Abrar Bilal     AUT    1.907        1.470              1.685
# 1002       Abu Hider     BAN    3.789        0.912              1.476
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 913            0.221            2.438                       -1.082
# 762            0.879            2.080                       -0.096
# 731            0.495            1.546                        0.019
# 876           -0.189            1.546                       -1.381
# 591            1.180            1.546                        0.115
# 536            0.586            2.438                        0.307
# 631            0.925            1.167                       -0.227
# 922            0.221            1.012                       -0.613
# 697            0.906            1.546                       -0.172
# 1002           0.057            3.148                       -1.187
#
#       big_match_index  rbml_score
# 913            -0.576       1.578
# 762            -0.576       1.460
# 731            -0.576       1.309
# 876            -0.576       1.307
# 591            -0.576       1.222
# 536            -0.576       1.135
# 631            -0.576       1.110
# 922            -0.576       1.097
# 697            -0.576       1.069
# 1002           -0.576       1.020

# %%
middle_ovr = pd.concat([middle_ovr, results_new[results_new.kmeans == 1]], ignore_index=True)

# %% [markdown]
# ## For 3

# %%
results_new = results.copy()
results_new['kmeans'] = results_new.kmeans.map({1:0,2:0,3:1,0:0})
X_train, X_test, y_train, y_test = train_test_split(results_new.drop('kmeans',axis=1), results_new['kmeans'], test_size=0.3, random_state=42)
X_train.drop(['name','country'],axis=1,inplace=True)

# %%
rfc_3 = RandomForestClassifier()
rfc_3.fit(X_train, y_train)
ypred_rfc_3 = rfc.predict(X_test.drop(['name','country'],axis=1))
fi_3 = np.round(rfc_3.feature_importances_,3)
dict_3 = dict(zip(columns,fi_3))
dict_3
# Out:
# {'average': 0.266,
#  'strike_rate': 0.065,
#  'boundary_per_ball': 0.061,
#  'boundary_index': 0.244,
#  'finishing_index': 0.027,
#  'runs_without_boundary_index': 0.085,
#  'big_match_index': 0.251}

# %%
results_new[results_new.kmeans == 1]
# Out:
#                   name country  average  strike_rate  boundary_per_ball  \
# 0            RG Sharma   INDIA    1.306        1.077              1.128
# 1           MJ Guptill      NZ    1.324        0.977              1.094
# 2              V Kohli   INDIA    3.157        1.011              0.676
# 3          PR Stirling     IRE    1.049        0.905              1.337
# 4             AJ Finch     AUS    1.521        1.266              1.389
# ..                 ...     ...      ...          ...                ...
# 709           DL Maddy     ENG    0.895        1.137              1.111
# 715         AP Devcich      NZ    0.846        1.111              2.033
# 772        Irfan Bhima     MWI    0.530        0.080              0.798
# 865      K Birkenstock     NAM    0.773        2.509              2.867
# 897  S Ashwathnarayana     HUN    5.443        2.037              0.555
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 0             1.724           -0.440                        0.982
# 1             2.016           -0.776                        1.097
# 2             2.178            0.377                        3.018
# 3             1.954           -0.701                        0.637
# 4             2.141           -0.525                        1.143
# ..              ...              ...                          ...
# 709           1.659           -1.123                        1.384
# 715           2.480           -1.123                        0.235
# 772           1.659           -1.123                        0.450
# 865           1.248            0.212                       -0.483
# 897           0.016            2.881                        0.809
#
#      big_match_index  kmeans
# 0              2.498       1
# 1              1.769       1
# 2              2.984       1
# 3              1.727       1
# 4              1.801       1
# ..               ...     ...
# 709            2.065       1
# 715            2.065       1
# 772            2.065       1
# 865            2.065       1
# 897           -0.576       1
#
# [121 rows x 10 columns]

# %%
results_new['rbml_score'] = 0
for i in columns:
  results_new['rbml_score'] = np.round(results_new['rbml_score'] + (results_new[i] * dict_3.get(i)),3)

# %%
results_new[results_new.kmeans == 1].sort_values('rbml_score',ascending=False).head(10).drop(['kmeans'],axis=1)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 361  Zeeshan Kukikhel     HUN    4.543        2.344              3.284
# 343      Azhar Andani    PORT    4.859        1.595              1.042
# 478          M Spoors     CAN    4.437        1.008              1.424
# 138   Taranjeet Singh     ROM    3.278        2.595              3.302
# 369      Saim Hussain     BUL    3.147        1.859              1.337
# 184   Muhammad Waseem     UAE    2.621        1.565              1.633
# 440         LA Dunbar     SRB    3.351        2.102              2.502
# 376       Dylan Steyn   CZK-R    2.232        1.543              1.737
# 318         ML Hayden     AUS    3.140        1.232              1.911
# 102          S Davizi   CZK-R    2.604        1.420              1.581
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 361           8.230           -1.123                        1.958
# 343           5.355           -1.123                        7.488
# 478           3.343            1.012                        1.915
# 138           4.974           -0.359                        0.820
# 369           2.959           -0.231                        3.227
# 184           3.507           -0.680                        1.695
# 440           3.234            0.655                       -0.076
# 376           3.644           -1.123                        2.413
# 318           3.142            0.655                        0.626
# 102           3.421           -0.562                        2.136
#
#      big_match_index  rbml_score
# 361            7.347       5.548
# 343            7.347       5.217
# 478            5.762       3.785
# 138            4.706       3.697
# 369            6.470       3.654
# 184            5.583       3.282
# 440            4.706       3.163
# 376            4.706       3.045
# 318            4.114       2.903
# 102            3.871       2.855

# %%
middle_ovr = pd.concat([middle_ovr, results_new[results_new.kmeans == 1]], ignore_index=True)

# %% [markdown]
# # Role Based Metrics

# %%
middle_ovr
# Out:
#                    name country  average  strike_rate  boundary_per_ball  \
# 0            EJG Morgan     ENG    0.927        0.958              0.798
# 1          Shoaib Malik     PAK    1.183        0.585              0.224
# 2           Mahmudullah     BAN    0.465        0.323              0.068
# 3            KJ O'Brien     IRE    0.210        0.772              0.694
# 4           LRPL Taylor      NZ    0.690        0.469             -0.019
# ...                 ...     ...      ...          ...                ...
# 1297           DL Maddy     ENG    0.895        1.137              1.111
# 1298         AP Devcich      NZ    0.846        1.111              2.033
# 1299        Irfan Bhima     MWI    0.530        0.080              0.798
# 1300      K Birkenstock     NAM    0.773        2.509              2.867
# 1301  S Ashwathnarayana     HUN    5.443        2.037              0.555
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 0              0.928           -0.077                        0.677
# 1              0.539            0.463                        1.210
# 2              0.237            0.025                        0.736
# 3              0.548           -0.605                        0.298
# 4              0.257            0.068                        1.062
# ...              ...              ...                          ...
# 1297           1.659           -1.123                        1.384
# 1298           2.480           -1.123                        0.235
# 1299           1.659           -1.123                        0.450
# 1300           1.248            0.212                       -0.483
# 1301           0.016            2.881                        0.809
#
#       big_match_index  kmeans  rbml_score
# 0               0.808       1       0.764
# 1               0.280       1       0.715
# 2               0.016       1       0.315
# 3               0.142       1       0.310
# 4               0.206       1       0.453
# ...               ...     ...         ...
# 1297            2.065       1       1.391
# 1298            2.065       1       1.534
# 1299            2.065       1       1.126
# 1300            2.065       1       1.332
# 1301           -0.576       1       1.620
#
# [1302 rows x 11 columns]

# %%
final_index = pd.merge(final_index,middle_ovr[['name','country','rbml_score']],on=['name','country'],how='left')

# %%
final_index[final_index.country.isin(top10countries)].sort_values('rbml_score',ascending = False).head(10).drop(['rfc_score','xgb_score','voting_score'],axis=1)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 318        ML Hayden     AUS    3.140        1.232              1.911
# 5         Babar Azam     PAK    2.575        0.719              0.520
# 2            V Kohli   INDIA    3.157        1.011              0.676
# 30   Mohammad Rizwan     PAK    3.046        0.698              0.520
# 58          DJ Malan     ENG    2.164        0.994              1.094
# 20          KL Rahul   INDIA    2.104        1.181              1.042
# 420       MN van Wyk      SA    1.794        1.210              1.494
# 148        DP Conway      NZ    3.026        1.070              0.937
# 271         SA Yadav   INDIA    1.940        1.998              2.102
# 284        A Symonds     AUS    2.830        2.132              1.598
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 318           3.142            0.655                        0.626
# 5             2.388           -0.349                        3.512
# 2             2.178            0.377                        3.018
# 30            2.211            0.302                        2.924
# 58            2.545           -0.359                        1.956
# 20            2.323           -0.402                        2.080
# 420           2.451           -0.359                        0.676
# 148           2.299            0.447                        2.469
# 271           2.138            0.212                        0.474
# 284           1.790            0.820                        1.795
#
#      big_match_index  kmeans  rbml_score
# 318            4.114       3       2.903
# 5              3.713       3       2.569
# 2              2.984       3       2.494
# 30             2.942       3       2.421
# 58             3.343       3       2.324
# 20             3.491       3       2.310
# 420            3.956       3       2.285
# 148            1.906       3       2.193
# 271            2.942       3       2.080
# 284            1.347       3       1.939

# %%
final_index
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 0           RG Sharma   INDIA    1.306        1.077              1.128
# 1          MJ Guptill      NZ    1.324        0.977              1.094
# 2             V Kohli   INDIA    3.157        1.011              0.676
# 3         PR Stirling     IRE    1.049        0.905              1.337
# 4            AJ Finch     AUS    1.521        1.266              1.389
# ...               ...     ...      ...          ...                ...
# 1297          H Helva     TKY   -1.562       -2.163             -0.767
# 1298  Apon Mustafizur     SRB   -1.586       -2.810             -1.219
# 1299          W Uisuk    THAI   -1.586       -2.888             -1.723
# 1300      I Katzarski     BUL   -1.635       -2.724             -2.157
# 1301       JD Freyone    GIBR   -1.659       -2.886             -2.157
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 0              1.724           -0.440                        0.982
# 1              2.016           -0.776                        1.097
# 2              2.178            0.377                        3.018
# 3              1.954           -0.701                        0.637
# 4              2.141           -0.525                        1.143
# ...              ...              ...                          ...
# 1297          -1.011           -1.123                       -1.704
# 1298          -1.011           -1.123                       -1.776
# 1299          -1.216           -1.123                       -1.489
# 1300          -1.421           -1.123                       -1.345
# 1301          -1.421           -1.123                       -1.417
#
#       big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 0               2.498       3      1.256      1.416         1.352       1.605
# 1               1.769       3      1.234      1.342         1.308       1.491
# 2               2.984       3      1.914      1.974         1.978       2.494
# 3               1.727       3      1.148      1.248         1.206       1.365
# 4               1.801       3      1.417      1.512         1.480       1.629
# ...               ...     ...        ...        ...           ...         ...
# 1297           -0.576       1     -1.321     -1.368        -1.370      -1.517
# 1298           -0.576       1     -1.518     -1.590        -1.575      -1.863
# 1299           -0.576       1     -1.623     -1.668        -1.653      -2.010
# 1300           -0.576       1     -1.698     -1.694        -1.691      -2.067
# 1301           -0.576       1     -1.739     -1.750        -1.741      -2.136
#
# [1302 rows x 14 columns]

# %%
final_index[final_index.country.isin(top10countries)].sort_values('rbml_score',ascending = False).head(10)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 318        ML Hayden     AUS    3.140        1.232              1.911
# 5         Babar Azam     PAK    2.575        0.719              0.520
# 2            V Kohli   INDIA    3.157        1.011              0.676
# 30   Mohammad Rizwan     PAK    3.046        0.698              0.520
# 58          DJ Malan     ENG    2.164        0.994              1.094
# 20          KL Rahul   INDIA    2.104        1.181              1.042
# 420       MN van Wyk      SA    1.794        1.210              1.494
# 148        DP Conway      NZ    3.026        1.070              0.937
# 271         SA Yadav   INDIA    1.940        1.998              2.102
# 284        A Symonds     AUS    2.830        2.132              1.598
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 318           3.142            0.655                        0.626
# 5             2.388           -0.349                        3.512
# 2             2.178            0.377                        3.018
# 30            2.211            0.302                        2.924
# 58            2.545           -0.359                        1.956
# 20            2.323           -0.402                        2.080
# 420           2.451           -0.359                        0.676
# 148           2.299            0.447                        2.469
# 271           2.138            0.212                        0.474
# 284           1.790            0.820                        1.795
#
#      big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 318            4.114       3      2.193      2.291         2.239       2.903
# 5              3.713       3      1.859      2.031         1.995       2.569
# 2              2.984       3      1.914      1.974         1.978       2.494
# 30             2.942       3      1.805      1.857         1.865       2.421
# 58             3.343       3      1.752      1.917         1.866       2.324
# 20             3.491       3      1.738      1.941         1.872       2.310
# 420            3.956       3      1.667      1.907         1.801       2.285
# 148            1.906       3      1.825      1.797         1.837       2.193
# 271            2.942       3      1.791      1.939         1.859       2.080
# 284            1.347       3      1.869      1.844         1.862       1.939

# %%
final_index.sort_values('rfc_score',ascending = False).head(10)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 361  Zeeshan Kukikhel     HUN    4.543        2.344              3.284
# 343      Azhar Andani    PORT    4.859        1.595              1.042
# 138   Taranjeet Singh     ROM    3.278        2.595              3.302
# 478          M Spoors     CAN    4.437        1.008              1.424
# 369      Saim Hussain     BUL    3.147        1.859              1.337
# 440         LA Dunbar     SRB    3.351        2.102              2.502
# 103       R Satheesan     ROM    2.581        2.669              2.884
# 184   Muhammad Waseem     UAE    2.621        1.565              1.633
# 376       Dylan Steyn   CZK-R    2.232        1.543              1.737
# 577       Mirza Ahsan     AUT    3.108        4.220              3.284
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 361           8.230           -1.123                        1.958
# 343           5.355           -1.123                        7.488
# 138           4.974           -0.359                        0.820
# 478           3.343            1.012                        1.915
# 369           2.959           -0.231                        3.227
# 440           3.234            0.655                       -0.076
# 103           3.351           -0.109                        0.867
# 184           3.507           -0.680                        1.695
# 376           3.644           -1.123                        2.413
# 577           1.043            1.925                       -0.145
#
#      big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 361            7.347       3      4.295      4.686         4.565       5.548
# 343            7.347       3      3.853      4.248         4.172       5.217
# 138            4.706       3      3.092      3.314         3.218       3.697
# 478            5.762       3      2.640      2.777         2.723       3.785
# 369            6.470       3      2.606      3.012         2.858       3.654
# 440            4.706       3      2.455      2.629         2.532       3.163
# 103            2.942       3      2.434      2.570         2.505       2.663
# 184            5.583       3      2.357      2.711         2.572       3.282
# 376            4.706       3      2.322      2.637         2.526       3.045
# 577            2.445       3      2.309      2.383         2.298       2.209

# %%
final_index.sort_values('xgb_score',ascending = False).head(10)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 361  Zeeshan Kukikhel     HUN    4.543        2.344              3.284
# 343      Azhar Andani    PORT    4.859        1.595              1.042
# 138   Taranjeet Singh     ROM    3.278        2.595              3.302
# 369      Saim Hussain     BUL    3.147        1.859              1.337
# 478          M Spoors     CAN    4.437        1.008              1.424
# 184   Muhammad Waseem     UAE    2.621        1.565              1.633
# 376       Dylan Steyn   CZK-R    2.232        1.543              1.737
# 440         LA Dunbar     SRB    3.351        2.102              2.502
# 103       R Satheesan     ROM    2.581        2.669              2.884
# 102          S Davizi   CZK-R    2.604        1.420              1.581
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 361           8.230           -1.123                        1.958
# 343           5.355           -1.123                        7.488
# 138           4.974           -0.359                        0.820
# 369           2.959           -0.231                        3.227
# 478           3.343            1.012                        1.915
# 184           3.507           -0.680                        1.695
# 376           3.644           -1.123                        2.413
# 440           3.234            0.655                       -0.076
# 103           3.351           -0.109                        0.867
# 102           3.421           -0.562                        2.136
#
#      big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 361            7.347       3      4.295      4.686         4.565       5.548
# 343            7.347       3      3.853      4.248         4.172       5.217
# 138            4.706       3      3.092      3.314         3.218       3.697
# 369            6.470       3      2.606      3.012         2.858       3.654
# 478            5.762       3      2.640      2.777         2.723       3.785
# 184            5.583       3      2.357      2.711         2.572       3.282
# 376            4.706       3      2.322      2.637         2.526       3.045
# 440            4.706       3      2.455      2.629         2.532       3.163
# 103            2.942       3      2.434      2.570         2.505       2.663
# 102            3.871       3      2.225      2.423         2.361       2.855

# %%
final_index.sort_values('rbml_score',ascending = False).head(10)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 361  Zeeshan Kukikhel     HUN    4.543        2.344              3.284
# 343      Azhar Andani    PORT    4.859        1.595              1.042
# 478          M Spoors     CAN    4.437        1.008              1.424
# 138   Taranjeet Singh     ROM    3.278        2.595              3.302
# 369      Saim Hussain     BUL    3.147        1.859              1.337
# 184   Muhammad Waseem     UAE    2.621        1.565              1.633
# 440         LA Dunbar     SRB    3.351        2.102              2.502
# 376       Dylan Steyn   CZK-R    2.232        1.543              1.737
# 318         ML Hayden     AUS    3.140        1.232              1.911
# 102          S Davizi   CZK-R    2.604        1.420              1.581
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 361           8.230           -1.123                        1.958
# 343           5.355           -1.123                        7.488
# 478           3.343            1.012                        1.915
# 138           4.974           -0.359                        0.820
# 369           2.959           -0.231                        3.227
# 184           3.507           -0.680                        1.695
# 440           3.234            0.655                       -0.076
# 376           3.644           -1.123                        2.413
# 318           3.142            0.655                        0.626
# 102           3.421           -0.562                        2.136
#
#      big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 361            7.347       3      4.295      4.686         4.565       5.548
# 343            7.347       3      3.853      4.248         4.172       5.217
# 478            5.762       3      2.640      2.777         2.723       3.785
# 138            4.706       3      3.092      3.314         3.218       3.697
# 369            6.470       3      2.606      3.012         2.858       3.654
# 184            5.583       3      2.357      2.711         2.572       3.282
# 440            4.706       3      2.455      2.629         2.532       3.163
# 376            4.706       3      2.322      2.637         2.526       3.045
# 318            4.114       3      2.193      2.291         2.239       2.903
# 102            3.871       3      2.225      2.423         2.361       2.855

# %%
final_index.sort_values('voting_score',ascending = False).head(10)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 361  Zeeshan Kukikhel     HUN    4.543        2.344              3.284
# 343      Azhar Andani    PORT    4.859        1.595              1.042
# 138   Taranjeet Singh     ROM    3.278        2.595              3.302
# 369      Saim Hussain     BUL    3.147        1.859              1.337
# 478          M Spoors     CAN    4.437        1.008              1.424
# 184   Muhammad Waseem     UAE    2.621        1.565              1.633
# 440         LA Dunbar     SRB    3.351        2.102              2.502
# 376       Dylan Steyn   CZK-R    2.232        1.543              1.737
# 103       R Satheesan     ROM    2.581        2.669              2.884
# 102          S Davizi   CZK-R    2.604        1.420              1.581
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 361           8.230           -1.123                        1.958
# 343           5.355           -1.123                        7.488
# 138           4.974           -0.359                        0.820
# 369           2.959           -0.231                        3.227
# 478           3.343            1.012                        1.915
# 184           3.507           -0.680                        1.695
# 440           3.234            0.655                       -0.076
# 376           3.644           -1.123                        2.413
# 103           3.351           -0.109                        0.867
# 102           3.421           -0.562                        2.136
#
#      big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 361            7.347       3      4.295      4.686         4.565       5.548
# 343            7.347       3      3.853      4.248         4.172       5.217
# 138            4.706       3      3.092      3.314         3.218       3.697
# 369            6.470       3      2.606      3.012         2.858       3.654
# 478            5.762       3      2.640      2.777         2.723       3.785
# 184            5.583       3      2.357      2.711         2.572       3.282
# 440            4.706       3      2.455      2.629         2.532       3.163
# 376            4.706       3      2.322      2.637         2.526       3.045
# 103            2.942       3      2.434      2.570         2.505       2.663
# 102            3.871       3      2.225      2.423         2.361       2.855

# %%
final_index[final_index.country == 'INDIA'].sort_values('rfc_score',ascending = False).head(10)
# Out:
#              name country  average  strike_rate  boundary_per_ball  \
# 2         V Kohli   INDIA    3.157        1.011              0.676
# 271      SA Yadav   INDIA    1.940        1.998              2.102
# 20       KL Rahul   INDIA    2.104        1.181              1.042
# 0       RG Sharma   INDIA    1.306        1.077              1.128
# 95        SS Iyer   INDIA    1.723        1.144              0.850
# 631       VR Iyer   INDIA    1.381        1.879              2.085
# 333  Ishan Kishan   INDIA    1.270        0.436              0.902
# 23       S Dhawan   INDIA    0.862        0.610              0.850
# 116     MK Pandey   INDIA    2.457        0.603             -0.054
# 34       SK Raina   INDIA    0.985        0.912              0.816
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 2             2.178            0.377                        3.018
# 271           2.138            0.212                        0.474
# 20            2.323           -0.402                        2.080
# 0             1.724           -0.440                        0.982
# 95            1.120            0.543                        1.195
# 631           0.925            1.167                       -0.227
# 333           2.029           -0.589                        1.025
# 23            1.578           -0.883                        1.033
# 116           0.272            1.626                        1.482
# 34            1.105           -0.231                        0.955
#
#      big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 2              2.984       3      1.914      1.974         1.978       2.494
# 271            2.942       3      1.791      1.939         1.859       2.080
# 20             3.491       3      1.738      1.941         1.872       2.310
# 0              2.498       3      1.256      1.416         1.352       1.605
# 95             1.410       3      1.162      1.187         1.182       1.328
# 631           -0.576       2      1.103      0.949         0.990       1.110
# 333            1.537       3      1.090      1.139         1.133       1.373
# 23             1.188       0      0.893      0.970         0.950       0.944
# 116            0.385       0      0.878      0.732         0.808       1.015
# 34             0.544       0      0.841      0.857         0.857       0.823

# %%
final_index[final_index.country == 'INDIA'].sort_values('voting_score',ascending = False).tail(10)
# Out:
#                    name country  average  strike_rate  boundary_per_ball  \
# 665            R Ashwin   INDIA    1.138       -0.077              0.103
# 544             M Vijay   INDIA   -0.028        0.022              0.207
# 296           RA Jadeja   INDIA    0.260        0.542              0.033
# 527           SV Samson   INDIA   -0.443        0.444              0.033
# 881            AR Patel   INDIA    0.043        0.591             -0.193
# 1076  Washington Sundar   INDIA   -1.201        1.336              1.650
# 730     Harbhajan Singh   INDIA   -0.540        0.532              0.833
# 1115          AT Rayudu   INDIA   -0.832       -0.889             -0.419
# 1010            B Kumar   INDIA   -0.745       -1.207             -2.157
# 1221            A Nehra   INDIA   -1.309       -1.321             -0.819
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 665           -0.301            2.272                       -0.399
# 544            0.495           -1.123                        0.211
# 296           -0.487            1.456                       -0.228
# 527           -0.189           -1.123                        0.067
# 881           -0.846            2.080                       -0.727
# 1076          -0.899            0.820                       -1.652
# 730           -0.473            0.932                       -1.107
# 1115          -0.600           -0.055                       -0.727
# 1010          -1.421            2.160                       -0.732
# 1221          -0.929           -1.123                       -1.302
#
#       big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 665            -0.576       2      0.191     -0.037         0.046       0.309
# 544            -0.576       0      0.039      0.028         0.040       0.010
# 296            -0.576       2      0.068     -0.006         0.020       0.227
# 527            -0.576       0     -0.156     -0.091        -0.114      -0.259
# 881            -0.576       2     -0.087     -0.149        -0.131       0.140
# 1076           -0.576       2     -0.086     -0.081        -0.136       0.129
# 730            -0.576       2     -0.078     -0.134        -0.139       0.056
# 1115           -0.576       1     -0.629     -0.673        -0.663      -0.700
# 1010           -0.576       1     -0.958     -0.997        -0.963      -1.229
# 1221           -0.576       1     -1.072     -1.053        -1.071      -1.132

# %%
final_index[final_index.country.isin(top10countries)].sort_values('voting_score',ascending = False).head(10)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 318        ML Hayden     AUS    3.140        1.232              1.911
# 5         Babar Azam     PAK    2.575        0.719              0.520
# 2            V Kohli   INDIA    3.157        1.011              0.676
# 20          KL Rahul   INDIA    2.104        1.181              1.042
# 58          DJ Malan     ENG    2.164        0.994              1.094
# 30   Mohammad Rizwan     PAK    3.046        0.698              0.520
# 284        A Symonds     AUS    2.830        2.132              1.598
# 271         SA Yadav   INDIA    1.940        1.998              2.102
# 148        DP Conway      NZ    3.026        1.070              0.937
# 420       MN van Wyk      SA    1.794        1.210              1.494
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 318           3.142            0.655                        0.626
# 5             2.388           -0.349                        3.512
# 2             2.178            0.377                        3.018
# 20            2.323           -0.402                        2.080
# 58            2.545           -0.359                        1.956
# 30            2.211            0.302                        2.924
# 284           1.790            0.820                        1.795
# 271           2.138            0.212                        0.474
# 148           2.299            0.447                        2.469
# 420           2.451           -0.359                        0.676
#
#      big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 318            4.114       3      2.193      2.291         2.239       2.903
# 5              3.713       3      1.859      2.031         1.995       2.569
# 2              2.984       3      1.914      1.974         1.978       2.494
# 20             3.491       3      1.738      1.941         1.872       2.310
# 58             3.343       3      1.752      1.917         1.866       2.324
# 30             2.942       3      1.805      1.857         1.865       2.421
# 284            1.347       3      1.869      1.844         1.862       1.939
# 271            2.942       3      1.791      1.939         1.859       2.080
# 148            1.906       3      1.825      1.797         1.837       2.193
# 420            3.956       3      1.667      1.907         1.801       2.285

# %%
final_index[final_index.country.isin(top10countries)].sort_values('voting_score',ascending = False).tail(10)
# Out:
#                    name country  average  strike_rate  boundary_per_ball  \
# 1221            A Nehra   INDIA   -1.309       -1.321             -0.819
# 1098           S Badree      WI   -1.157       -1.521             -1.618
# 998   Mustafizur Rahman     BAN   -1.471       -1.405             -0.923
# 1265        SS Cottrell      WI   -1.416       -1.665             -0.958
# 1247      Shafiul Islam     BAN   -1.406       -1.395             -1.097
# 1289          R Rampaul      WI   -1.124       -2.031             -2.157
# 1259      Rubel Hossain     BAN   -1.465       -1.896             -1.671
# 1117       Abdur Razzak     BAN   -1.455       -1.901             -1.914
# 1229     Shapoor Zadran     AFG   -1.479       -2.392             -1.358
# 1293       VD Philander      SA   -1.513       -2.092             -2.157
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 1221          -0.929           -1.123                       -1.302
# 1098          -1.319            2.214                       -1.399
# 998           -1.197            0.575                       -1.613
# 1265          -1.257            2.080                       -1.704
# 1247          -1.148           -0.231                       -1.369
# 1289          -1.421            2.689                       -1.376
# 1259          -1.366            2.438                       -1.685
# 1117          -1.380            1.546                       -1.460
# 1229          -1.232            1.343                       -1.793
# 1293          -1.421           -1.123                       -0.986
#
#       big_match_index  kmeans  rfc_score  xgb_score  voting_score  rbml_score
# 1221           -0.576       1     -1.072     -1.053        -1.071      -1.132
# 1098           -0.576       1     -1.047     -1.125        -1.092      -1.323
# 998            -0.576       1     -1.095     -1.129        -1.130      -1.224
# 1265           -0.576       1     -1.044     -1.161        -1.131      -1.296
# 1247           -0.576       1     -1.132     -1.128        -1.138      -1.245
# 1289           -0.576       1     -1.199     -1.305        -1.255      -1.622
# 1259           -0.576       1     -1.196     -1.293        -1.258      -1.541
# 1117           -0.576       1     -1.280     -1.326        -1.303      -1.603
# 1229           -0.576       1     -1.308     -1.430        -1.394      -1.684
# 1293           -0.576       1     -1.523     -1.470        -1.479      -1.786

# %% [markdown]
# # PCA

# %%
from sklearn.feature_selection import VarianceThreshold

pca = PCA(n_components=2)
pca.fit(batter_for_clustering_scaled)
x_pca = pca.transform(batter_for_clustering_scaled)

# Checking shapes
print(batter_for_clustering_scaled.shape)
print(x_pca.shape)

# Plotting the PCA results with Seaborn scatterplot
fig = plt.figure(figsize=(15, 8))
sns.scatterplot(x=x_pca[:, 0], y=x_pca[:, 1], hue=results['kmeans'].map({0:'FL', 1:'LCB', 2:'F', 3:'SB'}), palette='Dark2')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.show()

# Creating a DataFrame for PCA components
df = pd.DataFrame(pca.components_, columns=columns)

# Plotting a heatmap of the PCA components
fig = plt.figure(figsize=(25, 10))
sns.heatmap(df, cmap='YlGnBu', annot=True, fmt=".2f")
plt.title('Principal Components Correlation with the Features')
plt.xlabel('Features')
plt.ylabel('Principal Components')
plt.show()

# Feature selection using VarianceThreshold
selector = VarianceThreshold(0.5)
reduced_data = selector.fit_transform(batter_for_clustering_scaled)

# Displaying which features were selected
selected_features = selector.get_support()
print(selected_features)
# Out:
# (1302, 7)
# (1302, 2)
# [ True  True  True  True  True  True  True]

# %%
pca.explained_variance_
# Out:
# array([4.02851588, 1.29694627])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.57506025, 0.18513574])

# %%
dict_pca = dict(zip(columns,np.round(pca.components_[0],3)))
dict_pca
# Out:
# {'average': 0.429,
#  'strike_rate': 0.381,
#  'boundary_per_ball': 0.38,
#  'boundary_index': 0.475,
#  'finishing_index': -0.115,
#  'runs_without_boundary_index': 0.345,
#  'big_match_index': 0.41}

# %%
final_index['pca_score'] = 0
for i in columns:
  final_index['pca_score'] = np.round(final_index['pca_score'] + (final_index[i] * dict_pca.get(i)),3)

# %%
final_index[final_index.country.isin(top10countries)].sort_values('pca_score',ascending = False).head(10).drop(['rfc_score','xgb_score','voting_score','rbml_score'],axis=1)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 318        ML Hayden     AUS    3.140        1.232              1.911
# 5         Babar Azam     PAK    2.575        0.719              0.520
# 2            V Kohli   INDIA    3.157        1.011              0.676
# 20          KL Rahul   INDIA    2.104        1.181              1.042
# 58          DJ Malan     ENG    2.164        0.994              1.094
# 30   Mohammad Rizwan     PAK    3.046        0.698              0.520
# 420       MN van Wyk      SA    1.794        1.210              1.494
# 271         SA Yadav   INDIA    1.940        1.998              2.102
# 148        DP Conway      NZ    3.026        1.070              0.937
# 284        A Symonds     AUS    2.830        2.132              1.598
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 318           3.142            0.655                        0.626
# 5             2.388           -0.349                        3.512
# 2             2.178            0.377                        3.018
# 20            2.323           -0.402                        2.080
# 58            2.545           -0.359                        1.956
# 30            2.211            0.302                        2.924
# 420           2.451           -0.359                        0.676
# 271           2.138            0.212                        0.474
# 148           2.299            0.447                        2.469
# 284           1.790            0.820                        1.795
#
#      big_match_index  kmeans  pca_score
# 318            4.114       3      5.862
# 5              3.713       3      5.485
# 2              2.984       3      5.252
# 20             3.491       3      5.047
# 58             3.343       3      5.019
# 30             2.942       3      5.001
# 420            3.956       3      4.859
# 271            2.942       3      4.754
# 148            1.906       3      4.736
# 284            1.347       3      4.560

# %%
train_index = final_index[['name','country','kmeans','rfc_score','xgb_score','voting_score','rbml_score','pca_score']][final_index.country.isin(top10countries)]

# %%
train_index['kmeans_role'] = train_index['kmeans'].map({0:'FL',1:'LCB',2:'F',3:'SB'})

# %%
train_index.drop('kmeans',axis=1)[(train_index.country.isin(top10countries)) & (train_index['kmeans_role']=='SB')].sort_values('rbml_score',ascending=False).head(10)
# Out:
#                 name country  rfc_score  xgb_score  voting_score  rbml_score  \
# 318        ML Hayden     AUS      2.193      2.291         2.239       2.903
# 5         Babar Azam     PAK      1.859      2.031         1.995       2.569
# 2            V Kohli   INDIA      1.914      1.974         1.978       2.494
# 30   Mohammad Rizwan     PAK      1.805      1.857         1.865       2.421
# 58          DJ Malan     ENG      1.752      1.917         1.866       2.324
# 20          KL Rahul   INDIA      1.738      1.941         1.872       2.310
# 420       MN van Wyk      SA      1.667      1.907         1.801       2.285
# 148        DP Conway      NZ      1.825      1.797         1.837       2.193
# 271         SA Yadav   INDIA      1.791      1.939         1.859       2.080
# 284        A Symonds     AUS      1.869      1.844         1.862       1.939
#
#      pca_score kmeans_role
# 318      5.862          SB
# 5        5.485          SB
# 2        5.252          SB
# 30       5.001          SB
# 58       5.019          SB
# 20       5.047          SB
# 420      4.859          SB
# 148      4.736          SB
# 271      4.754          SB
# 284      4.560          SB

# %%
train_index.drop('kmeans',axis=1)[(train_index.country.isin(top10countries)) & (train_index['kmeans_role']=='LCB')].sort_values('rbml_score').head(10)
# Out:
#                 name country  rfc_score  xgb_score  voting_score  rbml_score  \
# 1293    VD Philander      SA     -1.523     -1.470        -1.479      -1.786
# 1229  Shapoor Zadran     AFG     -1.308     -1.430        -1.394      -1.684
# 1289       R Rampaul      WI     -1.199     -1.305        -1.255      -1.622
# 1117    Abdur Razzak     BAN     -1.280     -1.326        -1.303      -1.603
# 1259   Rubel Hossain     BAN     -1.196     -1.293        -1.258      -1.541
# 1098        S Badree      WI     -1.047     -1.125        -1.092      -1.323
# 1265     SS Cottrell      WI     -1.044     -1.161        -1.131      -1.296
# 1253    MR Gillespie      NZ     -0.995     -1.047        -1.010      -1.283
# 1247   Shafiul Islam     BAN     -1.132     -1.128        -1.138      -1.245
# 1269        D Bishoo      WI     -0.947     -1.082        -1.039      -1.239
#
#       pca_score kmeans_role
# 1293     -3.388         LCB
# 1229     -3.655         LCB
# 1289     -3.771         LCB
# 1117     -3.648         LCB
# 1259     -3.731         LCB
# 1098     -3.292         LCB
# 1265     -3.265         LCB
# 1253     -3.203         LCB
# 1247     -2.777         LCB
# 1269     -2.844         LCB

# %%
plt.figure(figsize=(17,8)) 
sns.boxplot(data=train_index[['rfc_score','xgb_score','voting_score','rbml_score','pca_score']])
plt.show()

# %% [markdown]
# # Training Evaluation

# %%
from pathlib import Path

# %%
final_training_evaluation = batter.copy()

# %%
final_training_evaluation = pd.merge(final_training_evaluation,final_index[['name','country','kmeans','rbml_score','pca_score']],on=['name','country'],how='left')

# %%
final_training_evaluation
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 0           RG Sharma   INDIA    32.48       139.55              0.189
# 1          MJ Guptill      NZ    32.66       136.71              0.187
# 2             V Kohli   INDIA    51.50       137.67              0.163
# 3         PR Stirling     IRE    29.84       134.69              0.201
# 4            AJ Finch     AUS    34.69       144.87              0.204
# ...               ...     ...      ...          ...                ...
# 1297          H Helva     TKY     3.00        48.00              0.080
# 1298  Apon Mustafizur     SRB     2.75        29.72              0.054
# 1299          W Uisuk    THAI     2.75        27.50              0.025
# 1300      I Katzarski     BUL     2.25        32.14              0.000
# 1301       JD Freyone    GIBR     2.00        27.58              0.000
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 0              3.829            0.128                       10.350
# 1              4.185            0.065                       10.750
# 2              4.382            0.281                       17.438
# 3              4.109            0.079                        9.149
# 4              4.337            0.112                       10.910
# ...              ...              ...                          ...
# 1297           0.500            0.000                        1.000
# 1298           0.500            0.000                        0.750
# 1299           0.250            0.000                        1.750
# 1300           0.000            0.000                        2.250
# 1301           0.000            0.000                        2.000
#
#       big_match_index  prelim_metric pre-rank  kmeans  rbml_score  pca_score
# 0               0.291         45.326     Best       3       1.605      3.632
# 1               0.222         44.649     Best       3       1.491      3.506
# 2               0.337         70.900     Best       3       2.494      5.252
# 3               0.218         40.191     Best       3       1.365      3.240
# 4               0.225         50.255     Best       3       1.629      3.872
# ...               ...            ...      ...     ...         ...        ...
# 1297            0.000          1.440     Poor       1      -1.517     -2.960
# 1298            0.000          0.817     Poor       1      -1.863     -3.414
# 1299            0.000          0.756     Poor       1      -2.010     -3.634
# 1300            0.000          0.723     Poor       1      -2.067     -3.805
# 1301            0.000          0.552     Poor       1      -2.136     -3.903
#
# [1302 rows x 14 columns]

# %% [markdown]
# ## Analysis

# %%
final_training_evaluation['kmeans_role'] = final_training_evaluation['kmeans'].map({0:'FL',1:'LCB',2:'F',3:'SB'})

# %%
cols_final = final_training_evaluation.columns.tolist()
cols_final = ['name','country','average','strike_rate','boundary_per_ball','boundary_index','finishing_index','runs_without_boundary_index','big_match_index','prelim_metric','pre-rank','kmeans','kmeans_role', 'rbml_score','pca_score']

# %%
final_training_evaluation = final_training_evaluation[cols_final]

# %%
final_training_evaluation[(final_training_evaluation.kmeans == 3)].sort_values('rbml_score',ascending = False).head(10)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 361  Zeeshan Kukikhel     HUN    65.75       175.33              0.313
# 343      Azhar Andani    PORT    69.00       154.18              0.184
# 478          M Spoors     CAN    64.66       137.58              0.206
# 138   Taranjeet Singh     ROM    52.75       182.42              0.314
# 369      Saim Hussain     BUL    51.40       161.63              0.201
# 184   Muhammad Waseem     UAE    46.00       153.33              0.218
# 440         LA Dunbar     SRB    53.50       168.50              0.268
# 376       Dylan Steyn   CZK-R    42.00       152.72              0.224
# 318         ML Hayden     AUS    51.33       143.92              0.234
# 102          S Davizi   CZK-R    45.82       149.23              0.215
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 361          11.750            0.000                       13.750
# 343           8.250            0.000                       33.000
# 478           5.800            0.400                       13.600
# 138           7.786            0.143                        9.786
# 369           5.333            0.167                       18.167
# 184           6.000            0.083                       12.833
# 440           5.667            0.333                        6.667
# 376           6.167            0.000                       15.333
# 318           5.556            0.333                        9.111
# 102           5.895            0.105                       14.368
#
#      big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 361            0.750        115.279     Good       3          SB       5.548
# 343            0.750        106.384     Good       3          SB       5.217
# 478            0.600         88.959     Good       3          SB       3.785
# 138            0.500         96.227     Best       3          SB       3.697
# 369            0.667         83.078     Good       3          SB       3.654
# 184            0.583         70.532     Best       3          SB       3.282
# 440            0.500         90.148     Good       3          SB       3.163
# 376            0.500         64.142     Good       3          SB       3.045
# 318            0.444         73.874     Good       3          SB       2.903
# 102            0.421         68.377     Best       3          SB       2.855
#
#      pca_score
# 361     11.816
# 343     11.357
# 478      7.323
# 138      8.266
# 369      7.765
# 184      6.959
# 440      6.554
# 376      6.827
# 318      5.862
# 102      6.273

# %%
final_training_evaluation[(final_training_evaluation.country.isin(top10countries)) & (final_training_evaluation.kmeans == 3)].sort_values('rbml_score',ascending = False).head(10)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 318        ML Hayden     AUS    51.33       143.92              0.234
# 5         Babar Azam     PAK    45.52       129.44              0.154
# 2            V Kohli   INDIA    51.50       137.67              0.163
# 30   Mohammad Rizwan     PAK    50.36       128.83              0.154
# 58          DJ Malan     ENG    41.30       137.20              0.187
# 20          KL Rahul   INDIA    40.68       142.49              0.184
# 420       MN van Wyk      SA    37.50       143.31              0.210
# 148        DP Conway      NZ    50.16       139.35              0.178
# 271         SA Yadav   INDIA    39.00       165.56              0.245
# 284        A Symonds     AUS    48.14       169.34              0.216
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 318           5.556            0.333                        9.111
# 5             4.638            0.145                       19.159
# 2             4.382            0.281                       17.438
# 30            4.422            0.267                       17.111
# 58            4.829            0.143                       13.743
# 20            4.558            0.135                       14.173
# 420           4.714            0.143                        9.286
# 148           4.529            0.294                       15.529
# 271           4.333            0.250                        8.583
# 284           3.909            0.364                       13.182
#
#      big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 318            0.444         73.874     Good       3          SB       2.903
# 5              0.406         58.921     Best       3          SB       2.569
# 2              0.337         70.900     Best       3          SB       2.494
# 30             0.333         64.879     Best       3          SB       2.421
# 58             0.371         56.664     Best       3          SB       2.324
# 20             0.385         57.965     Best       3          SB       2.310
# 420            0.429         53.741     Good       3          SB       2.285
# 148            0.235         69.898     Best       3          SB       2.193
# 271            0.333         64.568     Good       3          SB       2.080
# 284            0.182         81.520     Good       3          SB       1.939
#
#      pca_score
# 318      5.862
# 5        5.485
# 2        5.252
# 30       5.001
# 58       5.019
# 20       5.047
# 420      4.859
# 148      4.736
# 271      4.754
# 284      4.560

# %%
final_training_evaluation[(final_training_evaluation.country.isin(top10countries)) & (final_training_evaluation.kmeans == 2)].sort_values('rbml_score',ascending = False).head(10)
# Out:
#                name country  average  strike_rate  boundary_per_ball  \
# 876   SC Kuggeleijn      NZ    19.75       213.51              0.324
# 591      R Shepherd      WI    48.66       155.31              0.202
# 631         VR Iyer   INDIA    33.25       162.19              0.244
# 922         DR Sams     AUS    24.00       189.47              0.263
# 1002      Abu Hider     BAN    58.00       134.88              0.209
# 938       SN Thakur   INDIA    23.00       181.57              0.237
# 643       Hasan Ali     PAK    16.12       192.53              0.269
# 241      KD Karthik   INDIA    33.25       143.52              0.205
# 540     D Pretorius      SA    24.28       161.90              0.200
# 1120    KA Jamieson      NZ    20.50       151.85              0.259
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 876            1.500            0.500                        2.125
# 591            3.167            0.500                        7.333
# 631            2.857            0.429                        6.143
# 922            2.000            0.400                        4.800
# 1002           1.800            0.800                        2.800
# 938            1.500            0.500                        4.167
# 643            1.000            0.556                        1.944
# 241            2.192            0.538                        5.423
# 540            1.909            0.364                        6.364
# 1120           1.750            0.500                        3.250
#
#       big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 876             0.000         42.168     Poor       2           F       1.307
# 591             0.000         75.574     Good       2           F       1.222
# 631             0.000         53.928     Good       2           F       1.110
# 922             0.000         45.473     Poor       2           F       1.097
# 1002            0.000         78.230     Poor       2           F       1.020
# 938             0.000         41.761     Poor       2           F       0.946
# 643             0.000         31.036     Good       2           F       0.939
# 241             0.000         47.720     Good       2           F       0.832
# 540             0.091         39.309     Good       2           F       0.802
# 1120            0.000         31.129     Poor       2           F       0.750
#
#       pca_score
# 876       1.778
# 591       2.560
# 631       2.091
# 922       1.750
# 1002      1.552
# 938       1.110
# 643       0.732
# 241       1.184
# 540       1.510
# 1120      0.756

# %%
final_training_evaluation[(final_training_evaluation.country.isin(top10countries)) & (final_training_evaluation.kmeans == 0)].sort_values('rbml_score',ascending = False).head(10)
# Out:
#               name country  average  strike_rate  boundary_per_ball  \
# 516      JP Inglis     AUS    35.80       145.52              0.171
# 116      MK Pandey   INDIA    44.31       126.15              0.121
# 50   KC Sangakkara      SL    31.40       119.55              0.138
# 90        MR Marsh     AUS    31.60       125.00              0.148
# 267   Anamul Haque     BAN    32.27       117.94              0.166
# 23        S Dhawan   INDIA    27.92       126.36              0.173
# 83       G Gambhir   INDIA    27.41       119.02              0.152
# 390     UT Khawaja     AUS    26.77       132.41              0.198
# 69    RR Hendricks      SA    26.89       121.55              0.159
# 19      TM Dilshan      SL    28.19       120.54              0.163
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 516           3.500            0.167                       14.833
# 116           2.061            0.515                       12.091
# 50            3.000            0.170                       13.321
# 90            3.000            0.200                       11.286
# 267           3.846            0.154                       10.077
# 23            3.652            0.045                       10.530
# 83            3.306            0.056                       12.111
# 390           4.000            0.000                        9.667
# 69            3.425            0.025                       11.675
# 19            3.241            0.152                       10.114
#
#      big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 516            0.000         52.096     Good       0          FL       1.167
# 116            0.091         55.897     Best       0          FL       1.015
# 50             0.151         37.539     Best       0          FL       0.983
# 90             0.171         39.500     Best       0          FL       0.948
# 267            0.077         38.059     Good       0          FL       0.945
# 23             0.167         35.280     Best       0          FL       0.944
# 83             0.194         32.623     Best       0          FL       0.936
# 390            0.111         35.446     Good       0          FL       0.910
# 69             0.175         32.685     Best       0          FL       0.905
# 19             0.190         33.980     Best       0          FL       0.890
#
#      pca_score
# 516      2.765
# 116      1.874
# 50       2.319
# 90       2.332
# 267      2.218
# 23       2.620
# 83       2.494
# 390      2.654
# 69       2.493
# 19       2.319

# %%
final_training_evaluation[(final_training_evaluation.country.isin(top10countries)) & (final_training_evaluation.kmeans == 1)].sort_values('rbml_score',ascending = False).head(10)
# Out:
#                   name country  average  strike_rate  boundary_per_ball  \
# 474         Fawad Alam     PAK    17.63       114.79              0.083
# 1104     SE Rutherford      WI    10.75       119.44              0.111
# 463   Mosaddek Hossain     BAN    20.00       105.82              0.090
# 994           DR Flynn      NZ    11.80       115.68              0.098
# 564        JP Faulkner     AUS    14.45       115.21              0.087
# 399        Nurul Hasan     BAN    12.47       112.32              0.104
# 538         GD Elliott      NZ    15.54       108.91              0.089
# 404           AT Carey     AUS    11.09       108.37              0.121
# 862           TD Paine     AUS    10.25       106.49              0.130
# 525          LPC Silva      SL    13.46        98.87              0.124
#
#       boundary_index  finishing_index  runs_without_boundary_index  \
# 474            0.824            0.353                        7.294
# 1104           1.000            0.000                        5.250
# 463            1.133            0.333                        8.000
# 994            1.000            0.000                        6.200
# 564            0.667            0.389                        5.611
# 399            0.846            0.269                        5.423
# 538            0.933            0.267                        7.400
# 404            1.000            0.192                        4.423
# 862            1.111            0.111                        4.000
# 525            1.467            0.133                        5.400
#
#       big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 474               0.0         20.237     Good       1         LCB      -0.193
# 1104              0.0         12.840     Poor       1         LCB      -0.195
# 463               0.0         21.164     Good       1         LCB      -0.207
# 994               0.0         13.650     Poor       1         LCB      -0.260
# 564               0.0         16.648  Average       1         LCB      -0.263
# 399               0.0         14.006  Average       1         LCB      -0.268
# 538               0.0         16.925  Average       1         LCB      -0.280
# 404               0.0         12.018  Average       1         LCB      -0.292
# 862               0.0         10.915     Poor       1         LCB      -0.301
# 525               0.0         13.308  Average       1         LCB      -0.306
#
#       pca_score
# 474      -0.896
# 1104     -0.854
# 463      -0.669
# 994      -0.852
# 564      -1.247
# 399      -1.132
# 538      -0.918
# 404      -1.122
# 862      -1.071
# 525      -0.816

# %%
final_training_evaluation[(final_training_evaluation.country.isin(top10countries))].sort_values('pca_score',ascending = False).drop(['rbml_score','kmeans'],axis=1).head(15)
# Out:
#                 name country  average  strike_rate  boundary_per_ball  \
# 318        ML Hayden     AUS    51.33       143.92              0.234
# 5         Babar Azam     PAK    45.52       129.44              0.154
# 2            V Kohli   INDIA    51.50       137.67              0.163
# 20          KL Rahul   INDIA    40.68       142.49              0.184
# 58          DJ Malan     ENG    41.30       137.20              0.187
# 30   Mohammad Rizwan     PAK    50.36       128.83              0.154
# 420       MN van Wyk      SA    37.50       143.31              0.210
# 271         SA Yadav   INDIA    39.00       165.56              0.245
# 148        DP Conway      NZ    50.16       139.35              0.178
# 284        A Symonds     AUS    48.14       169.34              0.216
# 481    Mukhtar Ahmed     PAK    32.00       143.28              0.209
# 458         DS Smith      WI    33.83       126.08              0.168
# 680        DR Martyn     AUS    30.00       162.16              0.216
# 47           E Lewis      WI    30.93       155.51              0.236
# 63      KP Pietersen     ENG    37.93       141.51              0.182
#
#      boundary_index  finishing_index  runs_without_boundary_index  \
# 318           5.556            0.333                        9.111
# 5             4.638            0.145                       19.159
# 2             4.382            0.281                       17.438
# 20            4.558            0.135                       14.173
# 58            4.829            0.143                       13.743
# 30            4.422            0.267                       17.111
# 420           4.714            0.143                        9.286
# 271           4.333            0.250                        8.583
# 148           4.529            0.294                       15.529
# 284           3.909            0.364                       13.182
# 481           4.667            0.000                       11.667
# 458           4.500            0.000                       14.167
# 680           4.000            0.000                       11.500
# 47            4.408            0.061                        6.918
# 63            4.194            0.139                       14.111
#
#      big_match_index  prelim_metric pre-rank kmeans_role  pca_score
# 318            0.444         73.874     Good          SB      5.862
# 5              0.406         58.921     Best          SB      5.485
# 2              0.337         70.900     Best          SB      5.252
# 20             0.385         57.965     Best          SB      5.047
# 58             0.371         56.664     Best          SB      5.019
# 30             0.333         64.879     Best          SB      5.001
# 420            0.429         53.741     Good          SB      4.859
# 271            0.333         64.568     Good          SB      4.754
# 148            0.235         69.898     Best          SB      4.736
# 284            0.182         81.520     Good          SB      4.560
# 481            0.333         45.850     Good          SB      4.512
# 458            0.333         42.653     Good          SB      4.268
# 680            0.250         48.648     Good          SB      4.094
# 47             0.286         48.099     Best          SB      3.998
# 63             0.194         53.675     Best          SB      3.928

# %%
fig = plt.figure(figsize=(15, 8))
sns.scatterplot(x='average', y='strike_rate',data=final_training_evaluation,hue=results['kmeans'].map({0:'FL',1:'LCB',2:'F',3:'SB'}),palette='Dark2')
plt.xlabel('Average')
plt.ylabel('Strike Rate')
plt.show()

# %%
filepath_batter_evaluation_train = Path('final_training_evaluation_batter.csv') 
final_training_evaluation.drop('kmeans',axis=1).to_csv(filepath_batter_evaluation_train,index=False)

# %% [markdown]
# # Test Evaluation

# %%
batter_test = pd.read_csv('batter_test.csv')

# %%
 batter_test
# Out:
#              name  country  average  strike_rate  boundary_per_ball  \
# 0        B Mavuta      ZIM    17.66       147.22              0.167
# 1    NJ Maddinson      AUS    11.25       128.57              0.200
# 2     JW Dernbach  ENG/ITA     5.16        96.87              0.125
# 3    Taskin Ahmed      BAN     9.71        93.15              0.110
# 4      GJ Maxwell      AUS    30.96       154.00              0.203
# ..            ...      ...      ...          ...                ...
# 93  Nasir Hossain      BAN    18.50       113.49              0.113
# 94      LJ Wright      ENG    18.97       137.00              0.179
# 95   Faisal Javed      QAT    22.00       155.66              0.264
# 96      D Uwimana      RWN    23.50        68.11              0.072
# 97  Soumya Sarkar      BAN    18.03       122.15              0.168
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 0            0.857            0.571                        3.286
# 1            1.750            0.000                        3.750
# 2            0.400            0.400                        1.500
# 3            0.533            0.533                        2.133
# 4            3.390            0.169                        9.662
# ..             ...              ...                          ...
# 93           1.542            0.167                        8.667
# 94           2.200            0.111                        6.689
# 95           3.733            0.000                        5.600
# 96           1.000            0.600                        5.400
# 97           2.364            0.045                        6.455
#
#     big_match_index  prelim_metric pre-rank
# 0             0.000         25.999     Poor
# 1             0.000         14.464     Poor
# 2             0.000          4.998     Poor
# 3             0.000          9.045     Poor
# 4             0.195         47.678     Best
# ..              ...            ...      ...
# 93            0.083         20.996     Good
# 94            0.089         25.989     Good
# 95            0.133         34.245     Good
# 96            0.000         16.006     Poor
# 97            0.076         22.024     Good
#
# [98 rows x 11 columns]

# %%
batter_test['pre-rank'].value_counts()
# Out:
# pre-rank
# Poor       50
# Good       29
# Best       10
# Average     9
# Name: count, dtype: int64

# %%
batter_test_for_clustering = batter_test.copy().drop(['name','country','prelim_metric','pre-rank'],axis=1)
batter_test_for_clustering
# Out:
#     average  strike_rate  boundary_per_ball  boundary_index  finishing_index  \
# 0     17.66       147.22              0.167           0.857            0.571
# 1     11.25       128.57              0.200           1.750            0.000
# 2      5.16        96.87              0.125           0.400            0.400
# 3      9.71        93.15              0.110           0.533            0.533
# 4     30.96       154.00              0.203           3.390            0.169
# ..      ...          ...                ...             ...              ...
# 93    18.50       113.49              0.113           1.542            0.167
# 94    18.97       137.00              0.179           2.200            0.111
# 95    22.00       155.66              0.264           3.733            0.000
# 96    23.50        68.11              0.072           1.000            0.600
# 97    18.03       122.15              0.168           2.364            0.045
#
#     runs_without_boundary_index  big_match_index
# 0                         3.286            0.000
# 1                         3.750            0.000
# 2                         1.500            0.000
# 3                         2.133            0.000
# 4                         9.662            0.195
# ..                          ...              ...
# 93                        8.667            0.083
# 94                        6.689            0.089
# 95                        5.600            0.133
# 96                        5.400            0.000
# 97                        6.455            0.076
#
# [98 rows x 7 columns]

# %%
scaler = StandardScaler()
batter_test_for_clustering_scaled= scaler.fit_transform(batter_test_for_clustering)

# %%
batter_test_for_clustering_scaled = pd.DataFrame(batter_test_for_clustering_scaled,columns = columns)
batter_test_for_clustering_scaled
# Out:
#      average  strike_rate  boundary_per_ball  boundary_index  finishing_index  \
# 0   0.006278     1.263624           0.647861       -0.644028         1.774903
# 1  -0.677181     0.621015           1.204793        0.115049        -1.180434
# 2  -1.326520    -0.471249          -0.060963       -1.032492         0.889854
# 3  -0.841382    -0.599427          -0.314114       -0.919438         1.578225
# 4   1.424375     1.497238           1.255424        1.509099        -0.305737
# ..       ...          ...                ...             ...              ...
# 93  0.095842     0.101414          -0.263484       -0.061757        -0.316089
# 94  0.145955     0.911481           0.850382        0.497563        -0.605929
# 95  0.469025     1.554435           2.284905        1.800660        -1.180434
# 96  0.628961    -1.462212          -0.955431       -0.522474         1.924999
# 97  0.045729     0.399805           0.664737        0.636968        -0.947527
#
#     runs_without_boundary_index  big_match_index
# 0                     -0.951211        -0.561409
# 1                     -0.799427        -0.561409
# 2                     -1.535449        -0.561409
# 3                     -1.328382        -0.561409
# 4                      1.134512         1.663504
# ..                          ...              ...
# 93                     0.809027         0.385605
# 94                     0.161982         0.454064
# 95                    -0.194253         0.956096
# 96                    -0.259677        -0.561409
# 97                     0.085435         0.305736
#
# [98 rows x 7 columns]

# %%
batter_test_scaled = batter_test_for_clustering_scaled.copy()
batter_test_scaled['name'] = batter_test['name']
batter_test_scaled['country'] = batter_test['country']

cols = batter_test_scaled.columns.tolist()
cols = cols[-2:] + cols[:-2]


batter_test_scaled = batter_test_scaled [cols]
batter_test_scaled
# Out:
#              name  country   average  strike_rate  boundary_per_ball  \
# 0        B Mavuta      ZIM  0.006278     1.263624           0.647861
# 1    NJ Maddinson      AUS -0.677181     0.621015           1.204793
# 2     JW Dernbach  ENG/ITA -1.326520    -0.471249          -0.060963
# 3    Taskin Ahmed      BAN -0.841382    -0.599427          -0.314114
# 4      GJ Maxwell      AUS  1.424375     1.497238           1.255424
# ..            ...      ...       ...          ...                ...
# 93  Nasir Hossain      BAN  0.095842     0.101414          -0.263484
# 94      LJ Wright      ENG  0.145955     0.911481           0.850382
# 95   Faisal Javed      QAT  0.469025     1.554435           2.284905
# 96      D Uwimana      RWN  0.628961    -1.462212          -0.955431
# 97  Soumya Sarkar      BAN  0.045729     0.399805           0.664737
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 0        -0.644028         1.774903                    -0.951211
# 1         0.115049        -1.180434                    -0.799427
# 2        -1.032492         0.889854                    -1.535449
# 3        -0.919438         1.578225                    -1.328382
# 4         1.509099        -0.305737                     1.134512
# ..             ...              ...                          ...
# 93       -0.061757        -0.316089                     0.809027
# 94        0.497563        -0.605929                     0.161982
# 95        1.800660        -1.180434                    -0.194253
# 96       -0.522474         1.924999                    -0.259677
# 97        0.636968        -0.947527                     0.085435
#
#     big_match_index
# 0         -0.561409
# 1         -0.561409
# 2         -0.561409
# 3         -0.561409
# 4          1.663504
# ..              ...
# 93         0.385605
# 94         0.454064
# 95         0.956096
# 96        -0.561409
# 97         0.305736
#
# [98 rows x 9 columns]

# %%
ypred_test = kmodel.predict(batter_test_for_clustering_scaled)
results_test = batter_test_scaled
results_test['kmeans'] = ypred_test

# %%
results_mid = results_test.copy()
final_test_index = results_test.copy()
middle_ovr = pd.DataFrame()

# %%
results_0 = results_mid[results_mid['kmeans'] == 0]
results_1 = results_mid[results_mid['kmeans'] == 1]
results_2 = results_mid[results_mid['kmeans'] == 2]
results_3 = results_mid[results_mid['kmeans'] == 3]

# %% [markdown]
# ### For 0

# %%
results_0['rbml_score'] = 0
for i in columns:
  results_0['rbml_score'] = np.round(results_0['rbml_score'] + (results_0[i] * dict_0.get(i)),3)

# %%
middle_ovr = results_0.copy()

# %% [markdown]
# ### For 1

# %%
results_1['rbml_score'] = 0
for i in columns:
  results_1['rbml_score'] = np.round(results_1['rbml_score'] + (results_1[i] * dict_1.get(i)),3)

# %%
middle_ovr = pd.concat([middle_ovr, results_1], ignore_index=True)

# %% [markdown]
# ### For 2

# %%
results_2['rbml_score'] = 0
for i in columns:
  results_2['rbml_score'] = np.round(results_2['rbml_score'] + (results_2[i] * dict_2.get(i)),3)

# %%
middle_ovr = pd.concat([middle_ovr, results_2], ignore_index=True)

# %% [markdown]
# ### For 3

# %%
results_3['rbml_score'] = 0
for i in columns:
  results_3['rbml_score'] = np.round(results_3['rbml_score'] + (results_3[i] * dict_3.get(i)),3)

# %%
middle_ovr = pd.concat([middle_ovr, results_3], ignore_index=True)

# %%
middle_ovr
# Out:
#                name country   average  strike_rate  boundary_per_ball  \
# 0     DAS Gunaratne      SL  0.788897     0.546245           0.192188
# 1     Rohan Mustafa     UAE  0.354938     0.371551           0.597230
# 2    Imran Ali Butt     BHR  0.031867    -0.528447          -0.550389
# 3   Mohammad Hafeez     PAK  0.944568     0.395671           0.512847
# 4    Rizwan Mahmood     DEN  0.103305     0.498006          -0.060963
# ..              ...     ...       ...          ...                ...
# 93         ED Silva     KUW  0.184340     2.637396           3.280634
# 94       NG Collins     FIN  1.215392    -0.385109          -0.601019
# 95         R Pathan     CAN  3.608032     1.749458           1.879863
# 96      Usman Patel     KUW  0.504211     0.313320           1.137286
# 97     Faisal Javed     QAT  0.469025     1.554435           2.284905
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 0         0.398109         0.113496                     1.054368
# 1         0.844375        -0.776728                     0.526722
# 2         0.157551        -1.180434                     0.950670
# 3         1.201388        -0.559348                     1.166243
# 4         0.008795        -0.533469                     0.754398
# ..             ...              ...                          ...
# 93        0.752572         0.113496                    -1.208328
# 94        0.752572        -0.750849                     3.289585
# 95        3.959737        -0.238453                     2.285978
# 96        1.299142        -0.440306                     0.123381
# 97        1.800660        -1.180434                    -0.194253
#
#     big_match_index  kmeans  rbml_score
# 0          1.344029       0       0.671
# 1          0.328556       0       0.429
# 2          1.720553       0       0.241
# 3          0.921866       0       0.837
# 4         -0.561409       0       0.073
# ..              ...     ...         ...
# 93         2.291043       3       1.079
# 94         2.291043       3       1.280
# 95         4.630055       3       3.505
# 96         2.701797       3       1.216
# 97         0.956096       3       0.995
#
# [98 rows x 11 columns]

# %%
final_test_index = pd.merge(final_test_index,middle_ovr[['name','country','rbml_score']],on=['name','country'],how='left')

# %%
final_test_index
# Out:
#              name  country   average  strike_rate  boundary_per_ball  \
# 0        B Mavuta      ZIM  0.006278     1.263624           0.647861
# 1    NJ Maddinson      AUS -0.677181     0.621015           1.204793
# 2     JW Dernbach  ENG/ITA -1.326520    -0.471249          -0.060963
# 3    Taskin Ahmed      BAN -0.841382    -0.599427          -0.314114
# 4      GJ Maxwell      AUS  1.424375     1.497238           1.255424
# ..            ...      ...       ...          ...                ...
# 93  Nasir Hossain      BAN  0.095842     0.101414          -0.263484
# 94      LJ Wright      ENG  0.145955     0.911481           0.850382
# 95   Faisal Javed      QAT  0.469025     1.554435           2.284905
# 96      D Uwimana      RWN  0.628961    -1.462212          -0.955431
# 97  Soumya Sarkar      BAN  0.045729     0.399805           0.664737
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 0        -0.644028         1.774903                    -0.951211
# 1         0.115049        -1.180434                    -0.799427
# 2        -1.032492         0.889854                    -1.535449
# 3        -0.919438         1.578225                    -1.328382
# 4         1.509099        -0.305737                     1.134512
# ..             ...              ...                          ...
# 93       -0.061757        -0.316089                     0.809027
# 94        0.497563        -0.605929                     0.161982
# 95        1.800660        -1.180434                    -0.194253
# 96       -0.522474         1.924999                    -0.259677
# 97        0.636968        -0.947527                     0.085435
#
#     big_match_index  kmeans  rbml_score
# 0         -0.561409       2       0.363
# 1         -0.561409       2      -0.067
# 2         -0.561409       1      -0.633
# 3         -0.561409       1      -0.612
# 4          1.663504       3       1.427
# ..              ...     ...         ...
# 93         0.385605       0       0.155
# 94         0.454064       0       0.320
# 95         0.956096       3       0.995
# 96        -0.561409       1      -0.714
# 97         0.305736       0       0.225
#
# [98 rows x 11 columns]

# %% [markdown]
# ### PCA Metric

# %%
final_test_index['pca_score'] = 0
for i in columns:
  final_test_index['pca_score'] = np.round(final_test_index['pca_score'] + (final_test_index[i] * dict_pca.get(i)),3)

# %%
final_test_index
# Out:
#              name  country   average  strike_rate  boundary_per_ball  \
# 0        B Mavuta      ZIM  0.006278     1.263624           0.647861
# 1    NJ Maddinson      AUS -0.677181     0.621015           1.204793
# 2     JW Dernbach  ENG/ITA -1.326520    -0.471249          -0.060963
# 3    Taskin Ahmed      BAN -0.841382    -0.599427          -0.314114
# 4      GJ Maxwell      AUS  1.424375     1.497238           1.255424
# ..            ...      ...       ...          ...                ...
# 93  Nasir Hossain      BAN  0.095842     0.101414          -0.263484
# 94      LJ Wright      ENG  0.145955     0.911481           0.850382
# 95   Faisal Javed      QAT  0.469025     1.554435           2.284905
# 96      D Uwimana      RWN  0.628961    -1.462212          -0.955431
# 97  Soumya Sarkar      BAN  0.045729     0.399805           0.664737
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 0        -0.644028         1.774903                    -0.951211
# 1         0.115049        -1.180434                    -0.799427
# 2        -1.032492         0.889854                    -1.535449
# 3        -0.919438         1.578225                    -1.328382
# 4         1.509099        -0.305737                     1.134512
# ..             ...              ...                          ...
# 93       -0.061757        -0.316089                     0.809027
# 94        0.497563        -0.605929                     0.161982
# 95        1.800660        -1.180434                    -0.194253
# 96       -0.522474         1.924999                    -0.259677
# 97        0.636968        -0.947527                     0.085435
#
#     big_match_index  kmeans  rbml_score  pca_score
# 0         -0.561409       2       0.363     -0.338
# 1         -0.561409       2      -0.067      0.089
# 2         -0.561409       1      -0.633     -2.124
# 3         -0.561409       1      -0.612     -2.014
# 4          1.663504       3       1.427      3.483
# ..              ...     ...         ...        ...
# 93         0.385605       0       0.155      0.424
# 94         0.454064       0       0.320      1.281
# 95         0.956096       3       0.995      2.977
# 96        -0.561409       1      -0.714     -1.439
# 97         0.305736       0       0.225      0.991
#
# [98 rows x 12 columns]

# %% [markdown]
# # Test Evaluation Final

# %%
final_evaluation_index = batter_test.copy()

# %%
final_evaluation_index = pd.merge(final_evaluation_index,final_test_index[['name','country','kmeans','rbml_score','pca_score']],on=['name','country'],how='left')

# %%
final_evaluation_index
# Out:
#              name  country  average  strike_rate  boundary_per_ball  \
# 0        B Mavuta      ZIM    17.66       147.22              0.167
# 1    NJ Maddinson      AUS    11.25       128.57              0.200
# 2     JW Dernbach  ENG/ITA     5.16        96.87              0.125
# 3    Taskin Ahmed      BAN     9.71        93.15              0.110
# 4      GJ Maxwell      AUS    30.96       154.00              0.203
# ..            ...      ...      ...          ...                ...
# 93  Nasir Hossain      BAN    18.50       113.49              0.113
# 94      LJ Wright      ENG    18.97       137.00              0.179
# 95   Faisal Javed      QAT    22.00       155.66              0.264
# 96      D Uwimana      RWN    23.50        68.11              0.072
# 97  Soumya Sarkar      BAN    18.03       122.15              0.168
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 0            0.857            0.571                        3.286
# 1            1.750            0.000                        3.750
# 2            0.400            0.400                        1.500
# 3            0.533            0.533                        2.133
# 4            3.390            0.169                        9.662
# ..             ...              ...                          ...
# 93           1.542            0.167                        8.667
# 94           2.200            0.111                        6.689
# 95           3.733            0.000                        5.600
# 96           1.000            0.600                        5.400
# 97           2.364            0.045                        6.455
#
#     big_match_index  prelim_metric pre-rank  kmeans  rbml_score  pca_score
# 0             0.000         25.999     Poor       2       0.363     -0.338
# 1             0.000         14.464     Poor       2      -0.067      0.089
# 2             0.000          4.998     Poor       1      -0.633     -2.124
# 3             0.000          9.045     Poor       1      -0.612     -2.014
# 4             0.195         47.678     Best       3       1.427      3.483
# ..              ...            ...      ...     ...         ...        ...
# 93            0.083         20.996     Good       0       0.155      0.424
# 94            0.089         25.989     Good       0       0.320      1.281
# 95            0.133         34.245     Good       3       0.995      2.977
# 96            0.000         16.006     Poor       1      -0.714     -1.439
# 97            0.076         22.024     Good       0       0.225      0.991
#
# [98 rows x 14 columns]

# %%
final_evaluation_index['kmeans_role'] = final_evaluation_index['kmeans'].map({0:'FL',1:'LCB',2:'F',3:'SB'})
final_evaluation_index = final_evaluation_index[cols_final]

# %%
final_evaluation_index[final_evaluation_index['pre-rank'] == 'Best']
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 4          GJ Maxwell     AUS    30.96       154.00              0.203
# 22         AK Markram      SA    39.20       147.00              0.182
# 24             TP Ura     PNG    36.38       148.27              0.191
# 28    Mohammad Hafeez     PAK    26.46       122.03              0.159
# 45     Sarfaraz Ahmed     PAK    27.26       125.26              0.144
# 63    Virandeep Singh     MAL    29.62       113.79              0.144
# 66        Salman Butt     PAK    28.33       107.98              0.138
# 67  Hazratullah Zazai     AFG    36.35       145.40              0.224
# 75            N Vanua     PNG    23.00       150.59              0.173
# 90        F Behardien      SA    32.37       128.21              0.131
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 4            3.390            0.169                        9.662
# 22           4.056            0.167                       13.333
# 24           3.812            0.188                       11.125
# 28           3.028            0.120                        9.759
# 45           2.238            0.286                        9.810
# 63           3.483            0.069                       11.862
# 66           3.304            0.087                       11.783
# 67           5.091            0.091                        8.045
# 75           1.871            0.290                        6.581
# 90           1.767            0.467                        9.133
#
#     big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 4             0.195         47.678     Best       3          SB       1.427
# 22            0.333         57.624     Best       3          SB       2.259
# 24            0.281         53.941     Best       3          SB       1.932
# 28            0.130         32.289     Best       0          FL       0.837
# 45            0.071         34.146     Best       0          FL       0.658
# 63            0.138         33.705     Best       0          FL       1.074
# 66            0.130         30.591     Best       0          FL       0.979
# 67            0.227         52.853     Best       3          SB       1.970
# 75            0.065         34.636     Best       2           F       0.580
# 90            0.033         41.502     Best       0          FL       0.629
#
#     pca_score
# 4       3.483
# 22      4.965
# 24      4.306
# 28      2.166
# 45      1.462
# 63      2.596
# 66      2.292
# 67      4.455
# 75      1.243
# 90      1.099

# %%
final_evaluation_index.sort_values('rbml_score',ascending=False)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 84           R Pathan     CAN    51.44       161.32              0.240
# 22         AK Markram      SA    39.20       147.00              0.182
# 67  Hazratullah Zazai     AFG    36.35       145.40              0.224
# 24             TP Ura     PNG    36.38       148.27              0.191
# 11            JM Kemp      SA    50.75       126.87              0.169
# ..                ...     ...      ...          ...                ...
# 92          RA Bhatti     CAN     8.33        67.56              0.027
# 53     PADLR Sandakan      SL     7.66        60.52              0.053
# 87              D Gim     NGA     7.45        61.19              0.022
# 76          AG Cremer     ZIM     5.23        66.66              0.020
# 23            E Haven     BHM     3.60        25.00              0.000
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 84           6.273            0.182                       13.182
# 22           4.056            0.167                       13.333
# 67           5.091            0.091                        8.045
# 24           3.812            0.188                       11.125
# 11           3.857            0.429                       10.714
# ..             ...              ...                          ...
# 92           0.250            0.250                        5.250
# 53           0.286            0.571                        2.143
# 87           0.231            0.154                        5.231
# 76           0.105            0.316                        3.158
# 23           0.000            0.167                        3.000
#
#     big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 84            0.455         82.983     Good       3          SB       3.505
# 22            0.333         57.624     Best       3          SB       2.259
# 67            0.227         52.853     Best       3          SB       1.970
# 24            0.281         53.941     Best       3          SB       1.932
# 11            0.143         64.387     Good       3          SB       1.907
# ..              ...            ...      ...     ...         ...         ...
# 92            0.000          5.628     Poor       1         LCB      -1.273
# 53            0.000          4.636     Poor       1         LCB      -1.295
# 87            0.000          4.559     Poor       1         LCB      -1.404
# 76            0.000          3.486     Poor       1         LCB      -1.407
# 23            0.000          0.900     Poor       1         LCB      -2.088
#
#     pca_score
# 84      7.524
# 22      4.965
# 67      4.455
# 24      4.306
# 11      3.723
# ..        ...
# 92     -2.541
# 53     -3.024
# 87     -2.650
# 76     -3.074
# 23     -3.794
#
# [98 rows x 15 columns]

# %%
final_evaluation_index['kmeans_role'].value_counts()
# Out:
# kmeans_role
# LCB    39
# FL     29
# F      19
# SB     11
# Name: count, dtype: int64

# %%
final_evaluation_index.sort_values('rbml_score',ascending=False)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 84           R Pathan     CAN    51.44       161.32              0.240
# 22         AK Markram      SA    39.20       147.00              0.182
# 67  Hazratullah Zazai     AFG    36.35       145.40              0.224
# 24             TP Ura     PNG    36.38       148.27              0.191
# 11            JM Kemp      SA    50.75       126.87              0.169
# ..                ...     ...      ...          ...                ...
# 92          RA Bhatti     CAN     8.33        67.56              0.027
# 53     PADLR Sandakan      SL     7.66        60.52              0.053
# 87              D Gim     NGA     7.45        61.19              0.022
# 76          AG Cremer     ZIM     5.23        66.66              0.020
# 23            E Haven     BHM     3.60        25.00              0.000
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 84           6.273            0.182                       13.182
# 22           4.056            0.167                       13.333
# 67           5.091            0.091                        8.045
# 24           3.812            0.188                       11.125
# 11           3.857            0.429                       10.714
# ..             ...              ...                          ...
# 92           0.250            0.250                        5.250
# 53           0.286            0.571                        2.143
# 87           0.231            0.154                        5.231
# 76           0.105            0.316                        3.158
# 23           0.000            0.167                        3.000
#
#     big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 84            0.455         82.983     Good       3          SB       3.505
# 22            0.333         57.624     Best       3          SB       2.259
# 67            0.227         52.853     Best       3          SB       1.970
# 24            0.281         53.941     Best       3          SB       1.932
# 11            0.143         64.387     Good       3          SB       1.907
# ..              ...            ...      ...     ...         ...         ...
# 92            0.000          5.628     Poor       1         LCB      -1.273
# 53            0.000          4.636     Poor       1         LCB      -1.295
# 87            0.000          4.559     Poor       1         LCB      -1.404
# 76            0.000          3.486     Poor       1         LCB      -1.407
# 23            0.000          0.900     Poor       1         LCB      -2.088
#
#     pca_score
# 84      7.524
# 22      4.965
# 67      4.455
# 24      4.306
# 11      3.723
# ..        ...
# 92     -2.541
# 53     -3.024
# 87     -2.650
# 76     -3.074
# 23     -3.794
#
# [98 rows x 15 columns]

# %%
final_evaluation_index[final_evaluation_index.country.isin(top10countries)]
# Out:
#              name country  average  strike_rate  boundary_per_ball  \
# 1    NJ Maddinson     AUS    11.25       128.57              0.200
# 3    Taskin Ahmed     BAN     9.71        93.15              0.110
# 4      GJ Maxwell     AUS    30.96       154.00              0.203
# 8     LE Plunkett     ENG     6.00       123.52              0.118
# 11        JM Kemp      SA    50.75       126.87              0.169
# ..            ...     ...      ...          ...                ...
# 82    SW Billings     ENG    17.07       129.89              0.155
# 90    F Behardien      SA    32.37       128.21              0.131
# 93  Nasir Hossain     BAN    18.50       113.49              0.113
# 94      LJ Wright     ENG    18.97       137.00              0.179
# 97  Soumya Sarkar     BAN    18.03       122.15              0.168
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 1            1.750            0.000                        3.750
# 3            0.533            0.533                        2.133
# 4            3.390            0.169                        9.662
# 8            0.364            0.364                        2.182
# 11           3.857            0.429                       10.714
# ..             ...              ...                          ...
# 82           1.727            0.152                        6.606
# 90           1.767            0.467                        9.133
# 93           1.542            0.167                        8.667
# 94           2.200            0.111                        6.689
# 97           2.364            0.045                        6.455
#
#     big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 1             0.000         14.464     Poor       2           F      -0.067
# 3             0.000          9.045     Poor       1         LCB      -0.612
# 4             0.195         47.678     Best       3          SB       1.427
# 8             0.000          7.411     Poor       2           F      -0.348
# 11            0.143         64.387     Good       3          SB       1.907
# ..              ...            ...      ...     ...         ...         ...
# 82            0.061         22.172     Good       0          FL       0.102
# 90            0.033         41.502     Best       0          FL       0.629
# 93            0.083         20.996     Good       0          FL       0.155
# 94            0.089         25.989     Good       0          FL       0.320
# 97            0.076         22.024     Good       0          FL       0.225
#
#     pca_score
# 1       0.089
# 3      -2.014
# 4       3.483
# 8      -1.698
# 11      3.723
# ..        ...
# 82      0.591
# 90      1.099
# 93      0.424
# 94      1.281
# 97      0.991
#
# [32 rows x 15 columns]

# %%
final_evaluation_index[(final_evaluation_index['kmeans_role']=='LCB') & (final_evaluation_index['pre-rank']!='Poor')]
# Out:
#                name country  average  strike_rate  boundary_per_ball  \
# 15  JN Loftie-Eaton     NAM    12.00        97.95              0.095
# 42       A Shreshta     NGA    13.75        85.49              0.083
# 44         HR Walsh  USA/WI    14.00        97.90              0.091
# 54          AC Agar     AUS    12.59       101.83              0.103
# 70       Ahmed Raza     UAE    12.20        82.99              0.054
# 80         AC Botha     IRE    13.00        92.19              0.092
# 85         K Doriga     PNG    13.07       106.39              0.070
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 15           1.000            0.143                        6.143
# 42           1.333            0.000                        7.917
# 44           0.867            0.333                        5.333
# 54           1.037            0.185                        5.444
# 70           0.400            0.500                        4.000
# 80           1.182            0.091                        6.909
# 85           0.750            0.125                        7.688
#
#     big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 15              0.0         11.754  Average       1         LCB      -0.481
# 42              0.0         11.755  Average       1         LCB      -0.601
# 44              0.0         13.706  Average       1         LCB      -0.467
# 54              0.0         12.820  Average       1         LCB      -0.394
# 70              0.0         10.125  Average       1         LCB      -0.884
# 80              0.0         11.985  Average       1         LCB      -0.519
# 85              0.0         13.905  Average       1         LCB      -0.445
#
#     pca_score
# 15     -1.070
# 42     -0.812
# 44     -1.263
# 54     -1.029
# 70     -2.218
# 80     -0.928
# 85     -0.987

# %%
final_evaluation_index[(final_evaluation_index['pre-rank']=='Best')].drop('kmeans',axis=1)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 4          GJ Maxwell     AUS    30.96       154.00              0.203
# 22         AK Markram      SA    39.20       147.00              0.182
# 24             TP Ura     PNG    36.38       148.27              0.191
# 28    Mohammad Hafeez     PAK    26.46       122.03              0.159
# 45     Sarfaraz Ahmed     PAK    27.26       125.26              0.144
# 63    Virandeep Singh     MAL    29.62       113.79              0.144
# 66        Salman Butt     PAK    28.33       107.98              0.138
# 67  Hazratullah Zazai     AFG    36.35       145.40              0.224
# 75            N Vanua     PNG    23.00       150.59              0.173
# 90        F Behardien      SA    32.37       128.21              0.131
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 4            3.390            0.169                        9.662
# 22           4.056            0.167                       13.333
# 24           3.812            0.188                       11.125
# 28           3.028            0.120                        9.759
# 45           2.238            0.286                        9.810
# 63           3.483            0.069                       11.862
# 66           3.304            0.087                       11.783
# 67           5.091            0.091                        8.045
# 75           1.871            0.290                        6.581
# 90           1.767            0.467                        9.133
#
#     big_match_index  prelim_metric pre-rank kmeans_role  rbml_score  pca_score
# 4             0.195         47.678     Best          SB       1.427      3.483
# 22            0.333         57.624     Best          SB       2.259      4.965
# 24            0.281         53.941     Best          SB       1.932      4.306
# 28            0.130         32.289     Best          FL       0.837      2.166
# 45            0.071         34.146     Best          FL       0.658      1.462
# 63            0.138         33.705     Best          FL       1.074      2.596
# 66            0.130         30.591     Best          FL       0.979      2.292
# 67            0.227         52.853     Best          SB       1.970      4.455
# 75            0.065         34.636     Best           F       0.580      1.243
# 90            0.033         41.502     Best          FL       0.629      1.099

# %%
final_evaluation_index[(final_evaluation_index['kmeans_role']=='SB')].drop('kmeans',axis=1)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 4          GJ Maxwell     AUS    30.96       154.00              0.203
# 11            JM Kemp      SA    50.75       126.87              0.169
# 22         AK Markram      SA    39.20       147.00              0.182
# 24             TP Ura     PNG    36.38       148.27              0.191
# 25           FH Allen      NZ    26.00       190.24              0.329
# 67  Hazratullah Zazai     AFG    36.35       145.40              0.224
# 72           ED Silva     KUW    19.33       187.09              0.323
# 83         NG Collins     FIN    29.00        99.37              0.093
# 84           R Pathan     CAN    51.44       161.32              0.240
# 86        Usman Patel     KUW    22.33       119.64              0.196
# 95       Faisal Javed     QAT    22.00       155.66              0.264
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 4            3.390            0.169                        9.662
# 11           3.857            0.429                       10.714
# 22           4.056            0.167                       13.333
# 24           3.812            0.188                       11.125
# 25           4.500            0.000                        5.333
# 67           5.091            0.091                        8.045
# 72           2.500            0.250                        2.500
# 83           2.500            0.083                       16.250
# 84           6.273            0.182                       13.182
# 86           3.143            0.143                        6.571
# 95           3.733            0.000                        5.600
#
#     big_match_index  prelim_metric pre-rank kmeans_role  rbml_score  pca_score
# 4             0.195         47.678     Best          SB       1.427      3.483
# 11            0.143         64.387     Good          SB       1.907      3.723
# 22            0.333         57.624     Best          SB       2.259      4.965
# 24            0.281         53.941     Best          SB       1.932      4.306
# 25            0.167         49.462     Good          SB       1.501      4.470
# 67            0.227         52.853     Best          SB       1.970      4.455
# 72            0.250         36.164     Poor          SB       1.079      3.197
# 83            0.250         28.817     Good          SB       1.280      2.663
# 84            0.455         82.983     Good          SB       3.505      7.524
# 86            0.286         26.716     Good          SB       1.216      2.586
# 95            0.133         34.245     Good          SB       0.995      2.977

# %%
final_evaluation_index[(final_evaluation_index.country.isin(top10countries)) & (final_evaluation_index['kmeans_role']=='LCB')]
# Out:
#               name country  average  strike_rate  boundary_per_ball  \
# 3     Taskin Ahmed     BAN     9.71        93.15              0.110
# 12        DW Steyn      SA     3.50        80.76              0.077
# 39      R Ravindra      NZ     9.00        98.18              0.127
# 53  PADLR Sandakan      SL     7.66        60.52              0.053
# 54         AC Agar     AUS    12.59       101.83              0.103
# 73     TA Blundell      NZ    14.75        78.66              0.053
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 3            0.533            0.533                        2.133
# 12           0.167            0.500                        1.083
# 39           1.167            0.000                        4.000
# 53           0.286            0.571                        2.143
# 54           1.037            0.185                        5.444
# 73           0.667            0.333                        7.167
#
#     big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 3               0.0          9.045     Poor       1         LCB      -0.612
# 12              0.0          2.827     Poor       1         LCB      -1.059
# 39              0.0          8.836     Poor       1         LCB      -0.453
# 53              0.0          4.636     Poor       1         LCB      -1.295
# 54              0.0         12.820  Average       1         LCB      -0.394
# 73              0.0         11.602     Poor       1         LCB      -0.833
#
#     pca_score
# 3      -2.014
# 12     -2.921
# 39     -1.088
# 53     -3.024
# 54     -1.029
# 73     -1.599

# %%
final_evaluation_index.sort_values('rbml_score',ascending=False)
# Out:
#                  name country  average  strike_rate  boundary_per_ball  \
# 84           R Pathan     CAN    51.44       161.32              0.240
# 22         AK Markram      SA    39.20       147.00              0.182
# 67  Hazratullah Zazai     AFG    36.35       145.40              0.224
# 24             TP Ura     PNG    36.38       148.27              0.191
# 11            JM Kemp      SA    50.75       126.87              0.169
# ..                ...     ...      ...          ...                ...
# 92          RA Bhatti     CAN     8.33        67.56              0.027
# 53     PADLR Sandakan      SL     7.66        60.52              0.053
# 87              D Gim     NGA     7.45        61.19              0.022
# 76          AG Cremer     ZIM     5.23        66.66              0.020
# 23            E Haven     BHM     3.60        25.00              0.000
#
#     boundary_index  finishing_index  runs_without_boundary_index  \
# 84           6.273            0.182                       13.182
# 22           4.056            0.167                       13.333
# 67           5.091            0.091                        8.045
# 24           3.812            0.188                       11.125
# 11           3.857            0.429                       10.714
# ..             ...              ...                          ...
# 92           0.250            0.250                        5.250
# 53           0.286            0.571                        2.143
# 87           0.231            0.154                        5.231
# 76           0.105            0.316                        3.158
# 23           0.000            0.167                        3.000
#
#     big_match_index  prelim_metric pre-rank  kmeans kmeans_role  rbml_score  \
# 84            0.455         82.983     Good       3          SB       3.505
# 22            0.333         57.624     Best       3          SB       2.259
# 67            0.227         52.853     Best       3          SB       1.970
# 24            0.281         53.941     Best       3          SB       1.932
# 11            0.143         64.387     Good       3          SB       1.907
# ..              ...            ...      ...     ...         ...         ...
# 92            0.000          5.628     Poor       1         LCB      -1.273
# 53            0.000          4.636     Poor       1         LCB      -1.295
# 87            0.000          4.559     Poor       1         LCB      -1.404
# 76            0.000          3.486     Poor       1         LCB      -1.407
# 23            0.000          0.900     Poor       1         LCB      -2.088
#
#     pca_score
# 84      7.524
# 22      4.965
# 67      4.455
# 24      4.306
# 11      3.723
# ..        ...
# 92     -2.541
# 53     -3.024
# 87     -2.650
# 76     -3.074
# 23     -3.794
#
# [98 rows x 15 columns]

# %%
filepath_batter_evaluation_test = Path('final_test_evaluation_batter.csv') 
final_evaluation_index.drop('kmeans',axis=1).to_csv(filepath_batter_evaluation_test,index=False)
